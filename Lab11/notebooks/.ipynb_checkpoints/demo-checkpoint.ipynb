# %% [markdown]
# ### Lab9 testbench
# Run this cell before running any other cells

# %%
# %load_ext autoreload
# %autoreload 2

from ble import get_ble_controller
from base_ble import LOG
from cmd_types import CMD


import time
import numpy as np

LOG.propagate = False
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       1 get_ipython().run_line_magic('load_ext', 'autoreload')
#       2 get_ipython().run_line_magic('autoreload', '2')
# ----> 4 from ble import get_ble_controller
#       5 from base_ble import LOG
#       6 from cmd_types import CMD
#
# File ~\Documents\Ece4160\IvannnHuang.github.io\Lab11\notebooks\ble.py:1
# ----> 1 from base_ble import *
#       2 import atexit
#       4 GLOBAL_BLE_DEVICE = None
#
# File ~\Documents\Ece4160\IvannnHuang.github.io\Lab11\notebooks\base_ble.py:18
#      15     import objc
#      16     IS_ATLEAST_MAC_OS_12 = objc.macos_available(12,0)
# ---> 18 from utils import setup_logging
#      19 LOG = setup_logging("ble.log")
# ...

# %%
LOG.debug("debug")
LOG.info("info")
LOG.warning("warning")
LOG.error("error")
LOG.critical("critical")

# %%
ble.disconnect()
# Out:
# 2025-04-11 17:30:12,597 | INFO     |: Disconnected from C0:C3:E4:25:23:51

# %%
ble = get_ble_controller()
ble.connect()
# Out:
# 2025-04-11 17:30:33,384 | INFO     |: Looking for Artemis Nano Peripheral Device: c0:c3:e4:25:23:51
# 2025-04-11 17:30:38,728 | INFO     |: Connected to c0:c3:e4:25:23:51

# %%
import re

sensor_data_index = 0
sensor_data = [[0.0 for _ in range(2)] for _ in range(2500)]

msg = None

def data_collect(uuid, byte_array):
    global sensor_data_index
    msg = ble.bytearray_to_string(byte_array)
    data = re.findall(r'-?\d+\.\d+', msg)
    sensor_data[sensor_data_index] = [float(num) for num in data]
    sensor_data_index += 1

ble.start_notify(ble.uuid['RX_STRING'], data_collect)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[281], line 15
#      12     sensor_data[sensor_data_index] = [float(num) for num in data]
#      13     sensor_data_index += 1
# ---> 15 ble.start_notify(ble.uuid['RX_STRING'], data_collect)
#
# NameError: name 'ble' is not defined

# %%
ble.send_command(CMD.MAP, f"18|3|0.005|200|1.25|90|85|600")  # duration|Kp|Ki|Kd|motor_pwm_diff|max_speed|min_speed|accel_gap

# %%
ble.send_command(CMD.STOP, "")

# %%
#new

# %%
import numpy as np
import matplotlib.pyplot as plt

def robot2global(tof1, x1, y1, theta):
    theta1 = np.linspace(theta, theta + 2*np.pi, len(tof1))  # global angles
    dist_m = tof1 / 304.8
    x_global = x1 + (dist_m) * np.cos(theta1)
    y_global = y1 + dist_m * np.sin(theta1)
    return [x_global, y_global]

# %%
sensor_data = [[10.0, 1335.0], [33.0, 1335.0], [53.0, 1335.0], [64.0, 1335.0], [81.0, 1335.0], [97.0, 1335.0], [114.0, 1337.0], [130.0, 1337.0], [141.0, 1337.0], [152.0, 1337.0], [174.0, 1337.0], [196.0, 1337.0], [212.0, 1335.0], [223.0, 1335.0], [239.0, 1335.0], [261.0, 1335.0], [283.0, 1335.0], [300.0, 1335.0], [317.0, 1336.0], [333.0, 1336.0], [355.0, 1336.0], [377.0, 1336.0], [393.0, 1336.0], [404.0, 1332.0], [420.0, 1332.0], [437.0, 1332.0], [453.0, 1332.0], [464.0, 1332.0], [490.0, 1332.0], [509.0, 1332.0], [520.0, 1336.0], [537.0, 1336.0], [551.0, 1336.0], [567.0, 1336.0], [583.0, 1336.0], [600.0, 1336.0], [616.0, 1336.0], [633.0, 1346.0], [643.0, 1346.0], [660.0, 1346.0], [676.0, 1346.0], [693.0, 1346.0], [704.0, 1346.0], [720.0, 1346.0], [731.0, 1365.0], [747.0, 1365.0], [758.0, 1365.0], [775.0, 1365.0], [791.0, 1365.0], [807.0, 1365.0], [818.0, 1365.0], [835.0, 1376.0], [851.0, 1376.0], [870.0, 1376.0], [880.0, 1376.0], [897.0, 1376.0], [912.0, 1376.0], [938.0, 1380.0], [957.0, 1380.0], [968.0, 1380.0], [985.0, 1380.0], [999.0, 1380.0], [1015.0, 1380.0], [1030.0, 1380.0], [1041.0, 1380.0], [1057.0, 1405.0], [1069.0, 1405.0], [1090.0, 1405.0], [1111.0, 1405.0], [1129.0, 1405.0], [1151.0, 1405.0], [1168.0, 1435.0], [1190.0, 1435.0], [1210.0, 1435.0], [1228.0, 1435.0], [1245.0, 1435.0], [1261.0, 1455.0], [1278.0, 1455.0], [1295.0, 1455.0], [1311.0, 1455.0], [1328.0, 1455.0], [1345.0, 1455.0], [1356.0, 1455.0], [1377.0, 1459.0], [1398.0, 1459.0], [1416.0, 1459.0], [1438.0, 1459.0], [1455.0, 1459.0], [1471.0, 1448.0], [1487.0, 1448.0], [1501.0, 1448.0], [1519.0, 1448.0], [1541.0, 1448.0], [1558.0, 1448.0], [1574.0, 1363.0], [1596.0, 1363.0], [1612.0, 1363.0], [1629.0, 1363.0], [1640.0, 1363.0], [1656.0, 1363.0], [1667.0, 1352.0], [1690.0, 1352.0], [1711.0, 1352.0], [1734.0, 1352.0], [1755.0, 1352.0], [1772.0, 1271.0], [1788.0, 1271.0], [1805.0, 1271.0], [1821.0, 1271.0], [1837.0, 1271.0], [1849.0, 1271.0], [1859.0, 1116.0], [1876.0, 1116.0], [1892.0, 1116.0], [1917.0, 1116.0], [1939.0, 1116.0], [1955.0, 1116.0], [1971.0, 1033.0], [1988.0, 1033.0], [2004.0, 1033.0], [2021.0, 1033.0], [2037.0, 1033.0], [2059.0, 1033.0], [2075.0, 1034.0], [2092.0, 1034.0], [2114.0, 1034.0], [2130.0, 1034.0], [2141.0, 1034.0], [2157.0, 1034.0], [2174.0, 999.0], [2185.0, 999.0], [2201.0, 999.0], [2224.0, 999.0], [2244.0, 999.0], [2255.0, 999.0], [2275.0, 944.0], [2296.0, 944.0], [2321.0, 944.0], [2343.0, 944.0], [2360.0, 944.0], [2376.0, 898.0], [2399.0, 898.0], [2420.0, 898.0], [2437.0, 898.0], [2453.0, 898.0], [2470.0, 900.0], [2486.0, 900.0], [2500.0, 900.0], [2518.0, 900.0], [2535.0, 900.0], [2546.0, 900.0], [2562.0, 900.0], [2579.0, 900.0], [2595.0, 875.0], [2606.0, 875.0], [2622.0, 875.0], [2633.0, 875.0], [2651.0, 875.0], [2671.0, 875.0], [2680.0, 875.0], [2696.0, 831.0], [2707.0, 831.0], [2724.0, 831.0], [2740.0, 831.0], [2762.0, 831.0], [2784.0, 831.0], [2800.0, 818.0], [2811.0, 818.0], [2828.0, 818.0], [2848.0, 818.0], [2866.0, 818.0], [2883.0, 818.0], [2901.0, 817.0], [2923.0, 817.0], [2947.0, 817.0], [2957.0, 817.0], [2974.0, 817.0], [2989.0, 817.0], [3010.0, 796.0], [3027.0, 796.0], [3049.0, 796.0], [3065.0, 796.0], [3084.0, 796.0], [3101.0, 754.0], [3117.0, 754.0], [3134.0, 754.0], [3150.0, 754.0], [3161.0, 754.0], [3177.0, 754.0], [3198.0, 749.0], [3209.0, 749.0], [3230.0, 749.0], [3247.0, 749.0], [3263.0, 749.0], [3274.0, 749.0], [3291.0, 749.0], [3307.0, 749.0], [3323.0, 749.0], [3340.0, 749.0], [3351.0, 749.0], [3367.0, 749.0], [3374.0, 749.0], [3391.0, 749.0], [3407.0, 749.0], [3417.0, 736.0], [3433.0, 736.0], [3444.0, 736.0], [3460.0, 736.0], [3477.0, 736.0], [3493.0, 736.0], [3504.0, 736.0], [3515.0, 738.0], [3535.0, 738.0], [3552.0, 738.0], [3568.0, 738.0], [3590.0, 738.0], [3610.0, 738.0], [3627.0, 751.0], [3643.0, 751.0], [3654.0, 751.0], [3671.0, 751.0], [3681.0, 751.0], [3698.0, 751.0], [3709.0, 751.0], [3720.0, 749.0], [3742.0, 749.0], [3763.0, 749.0], [3780.0, 749.0], [3789.0, 749.0], [3805.0, 749.0], [3816.0, 847.0], [3832.0, 847.0], [3848.0, 847.0], [3865.0, 847.0], [3876.0, 847.0], [3892.0, 847.0], [3903.0, 847.0], [3914.0, 1278.0], [3930.0, 1278.0], [3941.0, 1278.0], [3958.0, 1278.0], [3974.0, 1278.0], [3996.0, 1278.0], [4012.0, 1278.0], [4034.0, 1324.0], [4054.0, 1324.0], [4071.0, 1324.0], [4087.0, 1324.0], [4098.0, 1324.0], [4115.0, 1324.0], [4131.0, 1328.0], [4147.0, 1328.0], [4169.0, 1328.0], [4186.0, 1328.0], [4197.0, 1328.0], [4213.0, 1328.0], [4229.0, 1528.0], [4246.0, 1528.0], [4262.0, 1528.0], [4271.0, 1528.0], [4287.0, 1528.0], [4298.0, 1528.0], [4314.0, 1528.0], [4336.0, 1576.0], [4358.0, 1576.0], [4375.0, 1576.0], [4392.0, 1576.0], [4409.0, 1576.0], [4420.0, 1581.0], [4428.0, 1581.0], [4450.0, 1581.0], [4466.0, 1581.0], [4483.0, 1581.0], [4500.0, 1581.0], [4522.0, 1581.0], [4538.0, 1582.0], [4560.0, 1582.0], [4583.0, 1582.0], [4599.0, 1582.0], [4616.0, 1582.0], [4633.0, 1592.0], [4655.0, 1592.0], [4666.0, 1592.0], [4683.0, 1592.0], [4699.0, 1592.0], [4715.0, 1592.0], [4736.0, 1616.0], [4756.0, 1616.0], [4775.0, 1616.0], [4786.0, 1616.0], [4803.0, 1616.0], [4819.0, 1616.0], [4836.0, 1618.0], [4863.0, 1618.0], [4874.0, 1618.0], [4897.0, 1618.0], [4918.0, 1618.0], [4939.0, 1613.0], [4955.0, 1613.0], [4971.0, 1613.0], [4988.0, 1613.0], [5000.0, 1613.0], [5017.0, 1613.0], [5034.0, 1640.0], [5050.0, 1640.0], [5068.0, 1640.0], [5084.0, 1640.0], [5101.0, 1640.0], [5112.0, 1640.0], [5127.0, 1685.0], [5149.0, 1685.0], [5171.0, 1685.0], [5187.0, 1685.0], [5204.0, 1685.0], [5220.0, 1685.0], [5237.0, 1693.0], [5247.0, 1693.0], [5264.0, 1693.0], [5289.0, 1693.0], [5306.0, 1693.0], [5324.0, 1693.0], [5341.0, 1689.0], [5357.0, 1689.0], [5373.0, 1689.0], [5390.0, 1689.0], [5415.0, 1689.0], [5433.0, 1689.0], [5450.0, 1718.0], [5466.0, 1718.0], [5488.0, 1718.0], [5499.0, 1718.0], [5507.0, 1718.0], [5524.0, 1718.0], [5536.0, 1718.0], [5557.0, 1811.0], [5574.0, 1811.0], [5590.0, 1811.0], [5607.0, 1811.0], [5618.0, 1811.0], [5634.0, 1811.0], [5650.0, 1813.0], [5659.0, 1813.0], [5675.0, 1813.0], [5685.0, 1813.0], [5709.0, 1813.0], [5728.0, 1813.0], [5745.0, 1845.0], [5763.0, 1845.0], [5773.0, 1845.0], [5790.0, 1845.0], [5812.0, 1845.0], [5828.0, 1845.0], [5851.0, 1871.0], [5875.0, 1871.0], [5885.0, 1871.0], [5907.0, 1871.0], [5929.0, 1871.0], [5945.0, 1957.0], [5961.0, 1957.0], [5972.0, 1957.0], [5988.0, 1957.0], [6011.0, 1957.0], [6022.0, 1957.0], [6033.0, 1973.0], [6048.0, 1973.0], [6069.0, 1973.0], [6081.0, 1973.0], [6097.0, 1973.0], [6119.0, 1973.0], [6140.0, 1970.0], [6157.0, 1970.0], [6176.0, 1970.0], [6187.0, 1970.0], [6203.0, 1970.0], [6225.0, 1970.0], [6250.0, 1976.0], [6267.0, 1976.0], [6283.0, 1976.0], [6300.0, 1976.0], [6308.0, 1976.0], [6318.0, 1976.0], [6328.0, 1955.0], [6349.0, 1955.0], [6360.0, 1955.0], [6377.0, 1955.0], [6388.0, 1955.0], [6404.0, 1955.0], [6425.0, 1955.0], [6436.0, 1897.0], [6452.0, 1897.0], [6463.0, 1897.0], [6479.0, 1897.0], [6496.0, 1897.0], [6512.0, 1897.0], [6523.0, 1897.0], [6539.0, 1861.0], [6556.0, 1861.0], [6572.0, 1861.0], [6589.0, 1861.0], [6605.0, 1861.0], [6616.0, 1861.0], [6632.0, 1861.0], [6649.0, 1851.0], [6665.0, 1851.0], [6681.0, 1851.0], [6698.0, 1851.0], [6709.0, 1851.0], [6727.0, 1851.0], [6748.0, 1680.0], [6765.0, 1680.0], [6781.0, 1680.0], [6789.0, 1680.0], [6799.0, 1680.0], [6815.0, 1680.0], [6837.0, 1680.0], [6853.0, 1583.0], [6864.0, 1583.0], [6881.0, 1583.0], [6897.0, 1583.0], [6914.0, 1583.0], [6930.0, 1583.0], [6941.0, 1569.0], [6957.0, 1569.0], [6974.0, 1569.0], [6990.0, 1569.0], [7012.0, 1569.0], [7028.0, 1569.0], [7045.0, 1569.0], [7061.0, 1535.0], [7083.0, 1535.0], [7099.0, 1535.0], [7116.0, 1535.0], [7132.0, 1535.0], [7146.0, 1535.0], [7162.0, 1479.0], [7178.0, 1479.0], [7195.0, 1479.0], [7220.0, 1479.0], [7238.0, 1479.0], [7255.0, 1479.0], [7266.0, 1440.0], [7283.0, 1440.0], [7299.0, 1440.0], [7321.0, 1440.0], [7343.0, 1440.0], [7359.0, 1440.0], [7370.0, 1439.0], [7392.0, 1439.0], [7403.0, 1439.0], [7417.0, 1439.0], [7433.0, 1439.0], [7449.0, 1439.0], [7466.0, 1439.0], [7482.0, 1431.0], [7493.0, 1431.0], [7512.0, 1431.0], [7529.0, 1431.0], [7545.0, 1431.0], [7561.0, 1431.0], [7583.0, 1362.0], [7605.0, 1362.0], [7621.0, 1362.0], [7638.0, 1362.0], [7660.0, 1362.0], [7675.0, 911.0], [7686.0, 911.0], [7703.0, 911.0], [7719.0, 911.0], [7745.0, 911.0], [7767.0, 911.0], [7784.0, 828.0], [7806.0, 828.0], [7829.0, 828.0], [7846.0, 828.0], [7866.0, 828.0], [7882.0, 785.0], [7898.0, 785.0], [7918.0, 785.0], [7936.0, 785.0], [7953.0, 785.0], [7970.0, 785.0], [7986.0, 720.0], [8003.0, 720.0], [8020.0, 720.0], [8031.0, 720.0], [8047.0, 720.0], [8064.0, 720.0], [8087.0, 685.0], [8109.0, 685.0], [8131.0, 685.0], [8147.0, 685.0], [8164.0, 685.0], [8186.0, 685.0], [8202.0, 682.0], [8213.0, 682.0], [8229.0, 682.0], [8246.0, 682.0], [8257.0, 682.0], [8273.0, 682.0], [8294.0, 682.0], [8305.0, 675.0], [8322.0, 675.0], [8338.0, 675.0], [8360.0, 675.0], [8371.0, 675.0], [8387.0, 675.0], [8400.0, 672.0], [8420.0, 672.0], [8441.0, 672.0], [8463.0, 672.0], [8480.0, 672.0], [8497.0, 672.0], [8519.0, 675.0], [8530.0, 675.0], [8547.0, 675.0], [8563.0, 675.0], [8578.0, 675.0], [8599.0, 675.0], [8610.0, 675.0], [8627.0, 675.0], [8643.0, 675.0], [8660.0, 675.0], [8681.0, 675.0], [8698.0, 675.0], [8709.0, 676.0], [8725.0, 676.0], [8742.0, 676.0], [8763.0, 676.0], [8780.0, 676.0], [8791.0, 676.0], [8807.0, 676.0], [8823.0, 684.0], [8839.0, 684.0], [8857.0, 684.0], [8868.0, 684.0], [8888.0, 684.0], [8904.0, 684.0], [8921.0, 700.0], [8942.0, 700.0], [8964.0, 700.0], [8981.0, 700.0], [8997.0, 700.0], [9008.0, 700.0], [9024.0, 701.0], [9041.0, 701.0], [9057.0, 701.0], [9074.0, 701.0], [9090.0, 701.0], [9098.0, 701.0], [9115.0, 701.0], [9132.0, 770.0], [9153.0, 770.0], [9180.0, 770.0], [9197.0, 770.0], [9218.0, 770.0], [9235.0, 1160.0], [9257.0, 1160.0], [9273.0, 1160.0], [9295.0, 1160.0], [9317.0, 1160.0], [9333.0, 1283.0], [9344.0, 1283.0], [9360.0, 1283.0], [9377.0, 1283.0], [9399.0, 1283.0], [9415.0, 1283.0], [9426.0, 1288.0], [9448.0, 1288.0], [9459.0, 1288.0], [9475.0, 1288.0], [9486.0, 1288.0], [9503.0, 1288.0], [9526.0, 1288.0], [9537.0, 1323.0], [9553.0, 1323.0], [9564.0, 1323.0], [9580.0, 1323.0], [9601.0, 1323.0], [9612.0, 1323.0], [9628.0, 1323.0], [9639.0, 1358.0], [9655.0, 1358.0], [9676.0, 1358.0], [9687.0, 1358.0], [9703.0, 1358.0], [9714.0, 1358.0], [9730.0, 1358.0], [9747.0, 1356.0], [9763.0, 1356.0], [9774.0, 1356.0], [9790.0, 1356.0], [9807.0, 1356.0], [9825.0, 1356.0], [9843.0, 1359.0], [9864.0, 1359.0], [9885.0, 1359.0], [9903.0, 1359.0], [9920.0, 1359.0], [9931.0, 1390.0], [9947.0, 1390.0], [9964.0, 1390.0], [9989.0, 1390.0], [10008.0, 1390.0], [10019.0, 1390.0], [10040.0, 1441.0], [10062.0, 1441.0], [10078.0, 1441.0], [10094.0, 1441.0], [10118.0, 1441.0], [10140.0, 1457.0], [10157.0, 1457.0], [10168.0, 1457.0], [10179.0, 1457.0], [10189.0, 1457.0], [10206.0, 1457.0], [10222.0, 1457.0], [10239.0, 1470.0], [10250.0, 1470.0], [10276.0, 1470.0], [10294.0, 1470.0], [10315.0, 1470.0], [10337.0, 1469.0], [10354.0, 1469.0], [10370.0, 1469.0], [10381.0, 1469.0], [10397.0, 1469.0], [10418.0, 1469.0], [10437.0, 1469.0], [10459.0, 1571.0], [10481.0, 1571.0], [10488.0, 1571.0], [10504.0, 1571.0], [10521.0, 1571.0], [10532.0, 1571.0], [10548.0, 1661.0], [10564.0, 1661.0], [10575.0, 1661.0], [10592.0, 1661.0], [10608.0, 1661.0], [10624.0, 1661.0], [10641.0, 1661.0], [10652.0, 1671.0], [10668.0, 1671.0], [10679.0, 1671.0], [10701.0, 1671.0], [10717.0, 1671.0], [10739.0, 1671.0], [10750.0, 1755.0], [10767.0, 1755.0], [10788.0, 1755.0], [10806.0, 1755.0], [10827.0, 1755.0], [10848.0, 1755.0], [10866.0, 1960.0], [10888.0, 1960.0], [10912.0, 1960.0], [10922.0, 1960.0], [10944.0, 1960.0], [10968.0, 2005.0], [10990.0, 2005.0], [11016.0, 2005.0], [11033.0, 2005.0], [11055.0, 2005.0], [11078.0, 2010.0], [11100.0, 2010.0], [11117.0, 2010.0], [11133.0, 2010.0], [11155.0, 2010.0], [11179.0, 2059.0], [11199.0, 2059.0], [11219.0, 2059.0], [11235.0, 2059.0], [11252.0, 2059.0], [11263.0, 2100.0], [11279.0, 2100.0], [11296.0, 2100.0], [11312.0, 2100.0], [11334.0, 2100.0], [11350.0, 2100.0], [11372.0, 2090.0], [11389.0, 2090.0], [11410.0, 2090.0], [11431.0, 2090.0], [11448.0, 2090.0], [11464.0, 2089.0], [11486.0, 2089.0], [11506.0, 2089.0], [11526.0, 2089.0], [11548.0, 2089.0], [11565.0, 2096.0], [11576.0, 2096.0], [11597.0, 2096.0], [11614.0, 2096.0], [11628.0, 2096.0], [11639.0, 2096.0], [11656.0, 2096.0], [11672.0, 2059.0], [11694.0, 2059.0], [11716.0, 2059.0], [11732.0, 2059.0], [11743.0, 2059.0], [11759.0, 2059.0], [11776.0, 2053.0], [11792.0, 2053.0], [11803.0, 2053.0], [11820.0, 2053.0], [11836.0, 2053.0], [11858.0, 2053.0], [11874.0, 2048.0], [11885.0, 2048.0], [11902.0, 2048.0], [11918.0, 2048.0], [11929.0, 2048.0], [11945.0, 2048.0], [11962.0, 2048.0], [11978.0, 1918.0], [11994.0, 1918.0], [12009.0, 1918.0], [12025.0, 1918.0], [12042.0, 1918.0], [12052.0, 1918.0], [12069.0, 1918.0], [12085.0, 794.0], [12098.0, 794.0], [12119.0, 794.0], [12140.0, 794.0], [12156.0, 794.0], [12173.0, 794.0], [12194.0, 704.0], [12211.0, 704.0], [12229.0, 704.0], [12239.0, 704.0], [12256.0, 704.0], [12271.0, 704.0], [12289.0, 692.0], [12307.0, 692.0], [12317.0, 692.0], [12334.0, 692.0], [12349.0, 692.0], [12360.0, 692.0], [12376.0, 692.0], [12387.0, 693.0], [12403.0, 693.0], [12424.0, 693.0], [12435.0, 693.0], [12451.0, 693.0], [12462.0, 693.0], [12478.0, 693.0], [12489.0, 684.0], [12511.0, 684.0], [12527.0, 684.0], [12544.0, 684.0], [12566.0, 684.0], [12582.0, 684.0], [12602.0, 678.0], [12613.0, 678.0], [12627.0, 678.0], [12643.0, 678.0], [12660.0, 678.0], [12677.0, 678.0], [12693.0, 675.0], [12715.0, 675.0], [12742.0, 675.0], [12759.0, 675.0], [12775.0, 675.0], [12791.0, 674.0], [12808.0, 674.0], [12824.0, 674.0], [12846.0, 674.0], [12868.0, 674.0], [12886.0, 674.0], [12897.0, 673.0], [12911.0, 673.0], [12928.0, 673.0], [12944.0, 673.0], [12961.0, 673.0], [12972.0, 673.0], [12989.0, 673.0], [13005.0, 672.0], [13022.0, 672.0], [13036.0, 672.0], [13052.0, 672.0], [13069.0, 672.0], [13079.0, 672.0], [13096.0, 672.0], [13112.0, 669.0], [13123.0, 669.0], [13140.0, 669.0], [13156.0, 669.0], [13172.0, 669.0], [13183.0, 669.0], [13200.0, 669.0], [13216.0, 674.0], [13227.0, 674.0], [13243.0, 674.0], [13264.0, 674.0], [13275.0, 674.0], [13292.0, 674.0], [13308.0, 674.0], [13325.0, 683.0], [13339.0, 683.0], [13350.0, 683.0], [13367.0, 683.0], [13383.0, 683.0], [13405.0, 683.0], [13422.0, 694.0], [13442.0, 694.0], [13464.0, 694.0], [13478.0, 694.0], [13495.0, 694.0], [13511.0, 694.0], [13528.0, 716.0], [13548.0, 716.0], [13565.0, 716.0], [13581.0, 716.0], [13592.0, 716.0], [13609.0, 716.0], [13625.0, 735.0], [13641.0, 735.0], [13663.0, 735.0], [13680.0, 735.0], [13691.0, 735.0], [13707.0, 735.0], [13729.0, 757.0], [13745.0, 757.0], [13763.0, 757.0], [13773.0, 757.0], [13790.0, 757.0], [13805.0, 757.0], [13823.0, 775.0], [13843.0, 775.0], [13860.0, 775.0], [13880.0, 775.0], [13896.0, 775.0], [13913.0, 775.0], [13934.0, 781.0], [13955.0, 781.0], [13972.0, 781.0], [13988.0, 781.0], [14010.0, 781.0], [14026.0, 789.0], [14043.0, 789.0], [14060.0, 789.0], [14077.0, 789.0], [14088.0, 789.0], [14104.0, 789.0], [14115.0, 789.0], [14131.0, 804.0], [14142.0, 804.0], [14153.0, 804.0], [14170.0, 804.0], [14186.0, 804.0], [14202.0, 804.0], [14219.0, 804.0], [14227.0, 841.0], [14238.0, 841.0], [14258.0, 841.0], [14275.0, 841.0], [14291.0, 841.0], [14313.0, 841.0], [14333.0, 876.0], [14349.0, 876.0], [14371.0, 876.0], [14382.0, 876.0], [14398.0, 876.0], [14415.0, 876.0], [14430.0, 896.0], [14447.0, 896.0], [14460.0, 896.0], [14481.0, 896.0], [14502.0, 896.0], [14518.0, 896.0], [14535.0, 1012.0], [14556.0, 1012.0], [14577.0, 1012.0], [14593.0, 1012.0], [14615.0, 1012.0], [14626.0, 2005.0], [14648.0, 2005.0], [14662.0, 2005.0], [14683.0, 2005.0], [14700.0, 2005.0], [14716.0, 2005.0], [14727.0, 2113.0], [14738.0, 2113.0], [14754.0, 2113.0], [14771.0, 2113.0], [14787.0, 2113.0], [14804.0, 2113.0], [14820.0, 2113.0], [14831.0, 2053.0], [14853.0, 2053.0], [14864.0, 2053.0], [14880.0, 2053.0], [14891.0, 2053.0], [14908.0, 2053.0], [14931.0, 2053.0], [14948.0, 1842.0], [14963.0, 1842.0], [14980.0, 1842.0], [14991.0, 1842.0], [15007.0, 1842.0], [15032.0, 1842.0], [15049.0, 1756.0], [15069.0, 1756.0], [15080.0, 1756.0], [15100.0, 1756.0], [15116.0, 1756.0], [15132.0, 1756.0], [15143.0, 1759.0], [15160.0, 1759.0], [15176.0, 1759.0], [15198.0, 1759.0], [15214.0, 1759.0], [15236.0, 1759.0], [15258.0, 1726.0], [15274.0, 1726.0], [15292.0, 1726.0], [15302.0, 1726.0], [15324.0, 1726.0], [15343.0, 1726.0], [15361.0, 1628.0], [15371.0, 1628.0], [15388.0, 1628.0], [15399.0, 1628.0], [15409.0, 1628.0], [15430.0, 1628.0], [15447.0, 1628.0], [15463.0, 1602.0], [15480.0, 1602.0], [15496.0, 1602.0], [15510.0, 1602.0], [15527.0, 1602.0], [15538.0, 1602.0], [15554.0, 1602.0], [15571.0, 1596.0], [15592.0, 1596.0], [15609.0, 1596.0], [15625.0, 1596.0], [15636.0, 1596.0], [15653.0, 1596.0], [15669.0, 1577.0], [15680.0, 1577.0], [15696.0, 1577.0], [15717.0, 1577.0], [15737.0, 1577.0], [15758.0, 1577.0], [15774.0, 1524.0], [15791.0, 1524.0], [15808.0, 1524.0], [15819.0, 1524.0], [15836.0, 1524.0], [15852.0, 1524.0], [15874.0, 1519.0], [15896.0, 1519.0], [15920.0, 1519.0], [15942.0, 1519.0], [15954.0, 1519.0], [15975.0, 1519.0], [15996.0, 1519.0], [16013.0, 1519.0], [16029.0, 1519.0], [16051.0, 1519.0], [16067.0, 1507.0], [16086.0, 1507.0], [16104.0, 1507.0], [16122.0, 1507.0], [16133.0, 1507.0], [16157.0, 1507.0], [16178.0, 1448.0], [16195.0, 1448.0], [16215.0, 1448.0], [16226.0, 1448.0], [16242.0, 1448.0], [16253.0, 1448.0], [16269.0, 1425.0], [16290.0, 1425.0], [16307.0, 1425.0], [16318.0, 1425.0], [16334.0, 1425.0], [16351.0, 1425.0], [16372.0, 1421.0], [16392.0, 1421.0], [16414.0, 1421.0], [16428.0, 1421.0], [16444.0, 1421.0], [16466.0, 1416.0], [16477.0, 1416.0], [16499.0, 1416.0], [16519.0, 1416.0], [16535.0, 1416.0], [16552.0, 1416.0], [16573.0, 1416.0], [16594.0, 1396.0], [16611.0, 1396.0], [16631.0, 1396.0], [16647.0, 1396.0], [16664.0, 1396.0], [16680.0, 1396.0], [16696.0, 1386.0], [16707.0, 1386.0], [16724.0, 1386.0], [16740.0, 1386.0], [16756.0, 1386.0], [16768.0, 1386.0], [16784.0, 1386.0], [16804.0, 1390.0], [16822.0, 1390.0], [16840.0, 1390.0], [16850.0, 1390.0], [16872.0, 1390.0], [16890.0, 1390.0], [16911.0, 1390.0], [16932.0, 1390.0], [16948.0, 1390.0], [16964.0, 1390.0], [16986.0, 1390.0], [16997.0, 1398.0], [17019.0, 1398.0], [17029.0, 1398.0], [17051.0, 1398.0], [17067.0, 1398.0], [17084.0, 1398.0], [17100.0, 1410.0], [17117.0, 1410.0], [17130.0, 1410.0], [17146.0, 1410.0], [17163.0, 1410.0], [17180.0, 1410.0], [17197.0, 1405.0], [17208.0, 1405.0], [17224.0, 1405.0], [17241.0, 1405.0], [17257.0, 1405.0], [17279.0, 1405.0], [17304.0, 1411.0], [17315.0, 1411.0], [17332.0, 1411.0], [17346.0, 1411.0], [17370.0, 1411.0], [17380.0, 1411.0], [17397.0, 1421.0], [17412.0, 1421.0], [17429.0, 1421.0], [17445.0, 1421.0], [17462.0, 1421.0], [17478.0, 1421.0], [17494.0, 1426.0], [17511.0, 1426.0], [17527.0, 1426.0], [17538.0, 1426.0], [17561.0, 1426.0], [17571.0, 1426.0], [17593.0, 1432.0], [17604.0, 1432.0], [17625.0, 1432.0], [17636.0, 1432.0], [17650.0, 1432.0], [17666.0, 1432.0], [17685.0, 1432.0], [17704.0, 1432.0], [17721.0, 1471.0], [17732.0, 1471.0], [17748.0, 1471.0], [17765.0, 1471.0], [17781.0, 1471.0], [17792.0, 1471.0], [17809.0, 1471.0], [17825.0, 1488.0], [17842.0, 1488.0], [17858.0, 1488.0], [17869.0, 1488.0], [17885.0, 1488.0], [17902.0, 1488.0], [17913.0, 1488.0], [17929.0, 1481.0], [17945.0, 1481.0], [17956.0, 1481.0], [17967.0, 1481.0], [17989.0, 1481.0], [18016.0, 1481.0]]
x1 = 0
y1 = 0
start = 0
end = 1010
theta = 0.48*np.pi

data = np.array(sensor_data)
time = data[start:end, 0]
tof1 = data[start:end, 1]

data00 = robot2global(tof1, x1, y1, theta)

# %%
sensor_data = [[17.0, 1011.0], [33.0, 1011.0], [49.0, 1011.0], [71.0, 1011.0], [88.0, 1011.0], [99.0, 1011.0], [115.0, 1008.0], [137.0, 1008.0], [153.0, 1008.0], [164.0, 1008.0], [181.0, 1008.0], [197.0, 1008.0], [213.0, 956.0], [231.0, 956.0], [242.0, 956.0], [259.0, 956.0], [281.0, 956.0], [297.0, 956.0], [313.0, 887.0], [335.0, 887.0], [346.0, 887.0], [363.0, 887.0], [389.0, 887.0], [406.0, 887.0], [422.0, 955.0], [444.0, 955.0], [460.0, 955.0], [477.0, 955.0], [488.0, 955.0], [501.0, 955.0], [519.0, 1916.0], [536.0, 1916.0], [547.0, 1916.0], [554.0, 1916.0], [572.0, 1916.0], [592.0, 1916.0], [603.0, 1916.0], [625.0, 1928.0], [641.0, 1928.0], [652.0, 1928.0], [669.0, 1928.0], [685.0, 1928.0], [696.0, 1928.0], [707.0, 1928.0], [723.0, 1934.0], [734.0, 1934.0], [760.0, 1934.0], [776.0, 1934.0], [793.0, 1934.0], [803.0, 1934.0], [820.0, 1936.0], [836.0, 1936.0], [847.0, 1936.0], [860.0, 1936.0], [878.0, 1936.0], [899.0, 1936.0], [916.0, 1931.0], [932.0, 1931.0], [945.0, 1931.0], [963.0, 1931.0], [983.0, 1931.0], [994.0, 1931.0], [1013.0, 1920.0], [1024.0, 1920.0], [1041.0, 1920.0], [1048.0, 1920.0], [1064.0, 1920.0], [1081.0, 1920.0], [1096.0, 1920.0], [1107.0, 1871.0], [1118.0, 1871.0], [1129.0, 1871.0], [1144.0, 1871.0], [1155.0, 1871.0], [1172.0, 1871.0], [1183.0, 1871.0], [1194.0, 1871.0], [1209.0, 1861.0], [1229.0, 1861.0], [1246.0, 1861.0], [1257.0, 1861.0], [1268.0, 1861.0], [1284.0, 1861.0], [1299.0, 1861.0], [1316.0, 1864.0], [1332.0, 1864.0], [1354.0, 1864.0], [1370.0, 1864.0], [1387.0, 1864.0], [1409.0, 1864.0], [1425.0, 1757.0], [1442.0, 1757.0], [1466.0, 1757.0], [1477.0, 1757.0], [1494.0, 1757.0], [1511.0, 1757.0], [1523.0, 1196.0], [1540.0, 1196.0], [1551.0, 1196.0], [1562.0, 1196.0], [1584.0, 1196.0], [1607.0, 1196.0], [1623.0, 1013.0], [1634.0, 1013.0], [1656.0, 1013.0], [1683.0, 1013.0], [1694.0, 1013.0], [1716.0, 1013.0], [1732.0, 1016.0], [1743.0, 1016.0], [1754.0, 1016.0], [1770.0, 1016.0], [1785.0, 1016.0], [1801.0, 1016.0], [1817.0, 1016.0], [1839.0, 912.0], [1847.0, 912.0], [1869.0, 912.0], [1891.0, 912.0], [1907.0, 912.0], [1924.0, 912.0], [1946.0, 788.0], [1962.0, 788.0], [1978.0, 788.0], [1998.0, 788.0], [2018.0, 788.0], [2038.0, 784.0], [2056.0, 784.0], [2073.0, 784.0], [2084.0, 784.0], [2103.0, 784.0], [2120.0, 784.0], [2136.0, 775.0], [2154.0, 775.0], [2176.0, 775.0], [2198.0, 775.0], [2221.0, 775.0], [2237.0, 729.0], [2255.0, 729.0], [2275.0, 729.0], [2293.0, 729.0], [2313.0, 729.0], [2332.0, 729.0], [2349.0, 652.0], [2367.0, 652.0], [2378.0, 652.0], [2403.0, 652.0], [2424.0, 652.0], [2441.0, 637.0], [2463.0, 637.0], [2485.0, 637.0], [2495.0, 637.0], [2517.0, 637.0], [2534.0, 637.0], [2550.0, 637.0], [2567.0, 636.0], [2583.0, 636.0], [2599.0, 636.0], [2616.0, 636.0], [2638.0, 636.0], [2659.0, 636.0], [2676.0, 586.0], [2693.0, 586.0], [2704.0, 586.0], [2720.0, 586.0], [2729.0, 586.0], [2737.0, 586.0], [2759.0, 586.0], [2778.0, 535.0], [2800.0, 535.0], [2817.0, 535.0], [2833.0, 535.0], [2849.0, 535.0], [2871.0, 535.0], [2888.0, 532.0], [2904.0, 532.0], [2926.0, 532.0], [2948.0, 532.0], [2971.0, 532.0], [2990.0, 530.0], [3008.0, 530.0], [3029.0, 530.0], [3046.0, 530.0], [3062.0, 530.0], [3081.0, 530.0], [3092.0, 501.0], [3108.0, 501.0], [3127.0, 501.0], [3148.0, 501.0], [3172.0, 501.0], [3189.0, 501.0], [3200.0, 471.0], [3218.0, 471.0], [3238.0, 471.0], [3255.0, 471.0], [3266.0, 471.0], [3288.0, 471.0], [3310.0, 469.0], [3328.0, 469.0], [3345.0, 469.0], [3361.0, 469.0], [3373.0, 469.0], [3391.0, 469.0], [3408.0, 466.0], [3419.0, 466.0], [3430.0, 466.0], [3447.0, 466.0], [3458.0, 466.0], [3485.0, 466.0], [3509.0, 441.0], [3519.0, 441.0], [3543.0, 441.0], [3560.0, 441.0], [3576.0, 441.0], [3594.0, 441.0], [3616.0, 441.0], [3634.0, 436.0], [3656.0, 436.0], [3667.0, 436.0], [3684.0, 436.0], [3700.0, 436.0], [3716.0, 436.0], [3733.0, 436.0], [3744.0, 436.0], [3760.0, 436.0], [3771.0, 436.0], [3787.0, 436.0], [3798.0, 436.0], [3815.0, 436.0], [3826.0, 433.0], [3850.0, 433.0], [3860.0, 433.0], [3877.0, 433.0], [3886.0, 433.0], [3911.0, 433.0], [3920.0, 426.0], [3936.0, 426.0], [3958.0, 426.0], [3974.0, 426.0], [3985.0, 426.0], [4002.0, 426.0], [4012.0, 426.0], [4029.0, 425.0], [4040.0, 425.0], [4060.0, 425.0], [4077.0, 425.0], [4093.0, 425.0], [4104.0, 425.0], [4126.0, 425.0], [4142.0, 426.0], [4158.0, 426.0], [4169.0, 426.0], [4186.0, 426.0], [4197.0, 426.0], [4212.0, 426.0], [4223.0, 426.0], [4240.0, 426.0], [4251.0, 426.0], [4277.0, 426.0], [4288.0, 426.0], [4307.0, 426.0], [4324.0, 426.0], [4331.0, 414.0], [4347.0, 414.0], [4364.0, 414.0], [4380.0, 414.0], [4396.0, 414.0], [4414.0, 414.0], [4431.0, 414.0], [4444.0, 408.0], [4464.0, 408.0], [4475.0, 408.0], [4485.0, 408.0], [4507.0, 408.0], [4529.0, 408.0], [4542.0, 410.0], [4560.0, 410.0], [4577.0, 410.0], [4593.0, 410.0], [4609.0, 410.0], [4626.0, 410.0], [4637.0, 408.0], [4648.0, 408.0], [4673.0, 408.0], [4690.0, 408.0], [4701.0, 408.0], [4717.0, 408.0], [4725.0, 408.0], [4741.0, 406.0], [4757.0, 406.0], [4774.0, 406.0], [4790.0, 406.0], [4807.0, 406.0], [4824.0, 406.0], [4841.0, 408.0], [4852.0, 408.0], [4871.0, 408.0], [4888.0, 408.0], [4904.0, 408.0], [4922.0, 408.0], [4933.0, 408.0], [4950.0, 408.0], [4961.0, 408.0], [4985.0, 408.0], [4995.0, 408.0], [5012.0, 408.0], [5023.0, 408.0], [5045.0, 410.0], [5067.0, 410.0], [5076.0, 410.0], [5093.0, 410.0], [5113.0, 410.0], [5131.0, 410.0], [5150.0, 418.0], [5162.0, 418.0], [5184.0, 418.0], [5202.0, 418.0], [5220.0, 418.0], [5240.0, 418.0], [5251.0, 420.0], [5261.0, 420.0], [5278.0, 420.0], [5294.0, 420.0], [5311.0, 420.0], [5332.0, 420.0], [5354.0, 420.0], [5371.0, 420.0], [5382.0, 420.0], [5404.0, 420.0], [5428.0, 420.0], [5448.0, 420.0], [5469.0, 420.0], [5493.0, 426.0], [5504.0, 426.0], [5521.0, 426.0], [5528.0, 426.0], [5545.0, 426.0], [5561.0, 426.0], [5578.0, 426.0], [5599.0, 440.0], [5616.0, 440.0], [5632.0, 440.0], [5649.0, 440.0], [5665.0, 440.0], [5676.0, 440.0], [5687.0, 447.0], [5712.0, 447.0], [5723.0, 447.0], [5740.0, 447.0], [5762.0, 447.0], [5778.0, 447.0], [5794.0, 444.0], [5811.0, 444.0], [5827.0, 444.0], [5844.0, 444.0], [5860.0, 444.0], [5871.0, 444.0], [5882.0, 460.0], [5891.0, 460.0], [5913.0, 460.0], [5924.0, 460.0], [5935.0, 460.0], [5944.0, 460.0], [5960.0, 460.0], [5977.0, 460.0], [5988.0, 480.0], [6004.0, 480.0], [6026.0, 480.0], [6048.0, 480.0], [6065.0, 480.0], [6081.0, 480.0], [6097.0, 485.0], [6114.0, 485.0], [6136.0, 485.0], [6152.0, 485.0], [6168.0, 485.0], [6185.0, 485.0], [6201.0, 486.0], [6212.0, 486.0], [6223.0, 486.0], [6239.0, 486.0], [6250.0, 486.0], [6272.0, 486.0], [6289.0, 486.0], [6304.0, 495.0], [6315.0, 495.0], [6342.0, 495.0], [6358.0, 495.0], [6369.0, 495.0], [6391.0, 495.0], [6404.0, 523.0], [6415.0, 523.0], [6431.0, 523.0], [6450.0, 523.0], [6470.0, 523.0], [6492.0, 523.0], [6503.0, 545.0], [6520.0, 545.0], [6536.0, 545.0], [6558.0, 545.0], [6583.0, 545.0], [6600.0, 545.0], [6611.0, 544.0], [6622.0, 544.0], [6638.0, 544.0], [6649.0, 544.0], [6665.0, 544.0], [6676.0, 544.0], [6687.0, 544.0], [6698.0, 544.0], [6715.0, 560.0], [6731.0, 560.0], [6742.0, 560.0], [6766.0, 560.0], [6786.0, 560.0], [6802.0, 560.0], [6818.0, 599.0], [6840.0, 599.0], [6857.0, 599.0], [6864.0, 599.0], [6880.0, 599.0], [6897.0, 599.0], [6918.0, 649.0], [6929.0, 649.0], [6940.0, 649.0], [6951.0, 649.0], [6968.0, 649.0], [6989.0, 649.0], [7006.0, 649.0], [7017.0, 655.0], [7033.0, 655.0], [7055.0, 655.0], [7077.0, 655.0], [7093.0, 655.0], [7115.0, 655.0], [7140.0, 692.0], [7151.0, 692.0], [7168.0, 692.0], [7182.0, 692.0], [7203.0, 692.0], [7218.0, 692.0], [7234.0, 762.0], [7250.0, 762.0], [7272.0, 762.0], [7289.0, 762.0], [7300.0, 762.0], [7316.0, 762.0], [7338.0, 768.0], [7352.0, 768.0], [7368.0, 768.0], [7384.0, 768.0], [7401.0, 768.0], [7412.0, 768.0], [7428.0, 768.0], [7439.0, 768.0], [7450.0, 768.0], [7472.0, 768.0], [7495.0, 768.0], [7516.0, 768.0], [7533.0, 774.0], [7555.0, 774.0], [7577.0, 774.0], [7587.0, 774.0], [7598.0, 774.0], [7614.0, 774.0], [7637.0, 771.0], [7645.0, 771.0], [7656.0, 771.0], [7672.0, 771.0], [7692.0, 771.0], [7710.0, 771.0], [7732.0, 756.0], [7743.0, 756.0], [7767.0, 756.0], [7785.0, 756.0], [7802.0, 756.0], [7813.0, 756.0], [7823.0, 754.0], [7840.0, 754.0], [7862.0, 754.0], [7884.0, 754.0], [7902.0, 754.0], [7913.0, 754.0], [7930.0, 744.0], [7941.0, 744.0], [7965.0, 744.0], [7985.0, 744.0], [8001.0, 744.0], [8017.0, 744.0], [8034.0, 722.0], [8056.0, 722.0], [8070.0, 722.0], [8081.0, 722.0], [8098.0, 722.0], [8113.0, 722.0], [8129.0, 705.0], [8140.0, 705.0], [8162.0, 705.0], [8183.0, 705.0], [8194.0, 705.0], [8210.0, 705.0], [8226.0, 705.0], [8237.0, 705.0], [8248.0, 705.0], [8259.0, 705.0], [8278.0, 705.0], [8295.0, 705.0], [8311.0, 705.0], [8327.0, 701.0], [8347.0, 701.0], [8369.0, 701.0], [8386.0, 701.0], [8393.0, 701.0], [8409.0, 701.0], [8426.0, 687.0], [8442.0, 687.0], [8464.0, 687.0], [8478.0, 687.0], [8494.0, 687.0], [8521.0, 687.0], [8543.0, 683.0], [8557.0, 683.0], [8573.0, 683.0], [8589.0, 683.0], [8606.0, 683.0], [8622.0, 683.0], [8639.0, 684.0], [8665.0, 684.0], [8682.0, 684.0], [8698.0, 684.0], [8715.0, 684.0], [8736.0, 678.0], [8753.0, 678.0], [8769.0, 678.0], [8791.0, 678.0], [8810.0, 678.0], [8821.0, 678.0], [8831.0, 678.0], [8839.0, 677.0], [8862.0, 677.0], [8879.0, 677.0], [8895.0, 677.0], [8906.0, 677.0], [8917.0, 677.0], [8933.0, 677.0], [8944.0, 678.0], [8961.0, 678.0], [8971.0, 678.0], [8988.0, 678.0], [9010.0, 678.0], [9026.0, 678.0], [9037.0, 678.0], [9048.0, 676.0], [9073.0, 676.0], [9084.0, 676.0], [9101.0, 676.0], [9117.0, 676.0], [9134.0, 676.0], [9150.0, 680.0], [9157.0, 680.0], [9173.0, 680.0], [9184.0, 680.0], [9199.0, 680.0], [9210.0, 680.0], [9221.0, 680.0], [9232.0, 680.0], [9248.0, 688.0], [9256.0, 688.0], [9272.0, 688.0], [9288.0, 688.0], [9306.0, 688.0], [9326.0, 688.0], [9343.0, 691.0], [9359.0, 691.0], [9379.0, 691.0], [9397.0, 691.0], [9419.0, 691.0], [9436.0, 691.0], [9458.0, 688.0], [9479.0, 688.0], [9490.0, 688.0], [9501.0, 688.0], [9520.0, 688.0], [9541.0, 688.0], [9562.0, 688.0], [9578.0, 700.0], [9594.0, 700.0], [9614.0, 700.0], [9631.0, 700.0], [9647.0, 700.0], [9656.0, 700.0], [9678.0, 721.0], [9694.0, 721.0], [9714.0, 721.0], [9731.0, 721.0], [9747.0, 721.0], [9759.0, 721.0], [9777.0, 721.0], [9787.0, 720.0], [9804.0, 720.0], [9820.0, 720.0], [9843.0, 720.0], [9860.0, 720.0], [9882.0, 720.0], [9898.0, 719.0], [9914.0, 719.0], [9938.0, 719.0], [9949.0, 719.0], [9959.0, 719.0], [9976.0, 719.0], [9998.0, 738.0], [10014.0, 738.0], [10028.0, 738.0], [10050.0, 738.0], [10066.0, 738.0], [10088.0, 738.0], [10110.0, 772.0], [10127.0, 772.0], [10144.0, 772.0], [10160.0, 772.0], [10171.0, 772.0], [10188.0, 772.0], [10199.0, 782.0], [10210.0, 782.0], [10231.0, 782.0], [10255.0, 782.0], [10271.0, 782.0], [10287.0, 782.0], [10304.0, 781.0], [10326.0, 781.0], [10340.0, 781.0], [10351.0, 781.0], [10373.0, 781.0], [10390.0, 781.0], [10406.0, 809.0], [10428.0, 809.0], [10447.0, 809.0], [10454.0, 809.0], [10470.0, 809.0], [10492.0, 809.0], [10503.0, 858.0], [10519.0, 858.0], [10530.0, 858.0], [10547.0, 858.0], [10568.0, 858.0], [10594.0, 858.0], [10611.0, 862.0], [10627.0, 862.0], [10649.0, 862.0], [10665.0, 862.0], [10676.0, 862.0], [10693.0, 862.0], [10709.0, 863.0], [10720.0, 863.0], [10742.0, 863.0], [10765.0, 863.0], [10776.0, 863.0], [10786.0, 863.0], [10803.0, 888.0], [10819.0, 888.0], [10830.0, 888.0], [10841.0, 888.0], [10863.0, 888.0], [10870.0, 888.0], [10887.0, 888.0], [10905.0, 975.0], [10922.0, 975.0], [10933.0, 975.0], [10955.0, 975.0], [10978.0, 975.0], [10996.0, 975.0], [11016.0, 1003.0], [11027.0, 1003.0], [11037.0, 1003.0], [11059.0, 1003.0], [11076.0, 1003.0], [11087.0, 1003.0], [11103.0, 1003.0], [11114.0, 999.0], [11130.0, 999.0], [11141.0, 999.0], [11156.0, 999.0], [11173.0, 999.0], [11184.0, 999.0], [11195.0, 999.0], [11207.0, 999.0], [11229.0, 1292.0], [11246.0, 1292.0], [11267.0, 1292.0], [11283.0, 1292.0], [11300.0, 1292.0], [11324.0, 1292.0], [11341.0, 2465.0], [11352.0, 2465.0], [11363.0, 2465.0], [11379.0, 2465.0], [11390.0, 2465.0], [11406.0, 2465.0], [11426.0, 2465.0], [11443.0, 2435.0], [11459.0, 2435.0], [11475.0, 2435.0], [11501.0, 2435.0], [11518.0, 2435.0], [11529.0, 2435.0], [11540.0, 2451.0], [11562.0, 2451.0], [11579.0, 2451.0], [11596.0, 2451.0], [11612.0, 2451.0], [11628.0, 2451.0], [11645.0, 2561.0], [11667.0, 2561.0], [11675.0, 2561.0], [11686.0, 2561.0], [11705.0, 2561.0], [11722.0, 2561.0], [11738.0, 2612.0], [11749.0, 2612.0], [11764.0, 2612.0], [11790.0, 2612.0], [11810.0, 2612.0], [11821.0, 2612.0], [11838.0, 2612.0], [11854.0, 2557.0], [11871.0, 2557.0], [11887.0, 2557.0], [11898.0, 2557.0], [11909.0, 2557.0], [11920.0, 2557.0], [11936.0, 2557.0], [11953.0, 2572.0], [11969.0, 2572.0], [11995.0, 2572.0], [12006.0, 2572.0], [12016.0, 2572.0], [12033.0, 2572.0], [12044.0, 2464.0], [12060.0, 2464.0], [12071.0, 2464.0], [12082.0, 2464.0], [12106.0, 2464.0], [12116.0, 2464.0], [12137.0, 2464.0], [12153.0, 2313.0], [12171.0, 2313.0], [12191.0, 2313.0], [12202.0, 2313.0], [12219.0, 2313.0], [12230.0, 2313.0], [12246.0, 2313.0], [12257.0, 2282.0], [12268.0, 2282.0], [12279.0, 2282.0], [12290.0, 2282.0], [12306.0, 2282.0], [12324.0, 2282.0], [12335.0, 2282.0], [12346.0, 2282.0], [12363.0, 2304.0], [12379.0, 2304.0], [12395.0, 2304.0], [12406.0, 2304.0], [12417.0, 2304.0], [12439.0, 2304.0], [12456.0, 2250.0], [12472.0, 2250.0], [12494.0, 2250.0], [12513.0, 2250.0], [12531.0, 2250.0], [12542.0, 2250.0], [12559.0, 2141.0], [12570.0, 2141.0], [12594.0, 2141.0], [12604.0, 2141.0], [12621.0, 2141.0], [12632.0, 2141.0], [12654.0, 2141.0], [12676.0, 2135.0], [12692.0, 2135.0], [12714.0, 2135.0], [12730.0, 2135.0], [12747.0, 2135.0], [12768.0, 2135.0], [12785.0, 2118.0], [12807.0, 2118.0], [12823.0, 2118.0], [12834.0, 2118.0], [12854.0, 2118.0], [12865.0, 2118.0], [12882.0, 1962.0], [12893.0, 1962.0], [12909.0, 1962.0], [12920.0, 1962.0], [12936.0, 1962.0], [12964.0, 1962.0], [12980.0, 1699.0], [13000.0, 1699.0], [13012.0, 1699.0], [13029.0, 1699.0], [13040.0, 1699.0], [13062.0, 1699.0], [13078.0, 1648.0], [13094.0, 1648.0], [13111.0, 1648.0], [13128.0, 1648.0], [13144.0, 1648.0], [13160.0, 1648.0], [13177.0, 1659.0], [13188.0, 1659.0], [13199.0, 1659.0], [13215.0, 1659.0], [13229.0, 1659.0], [13245.0, 1659.0], [13261.0, 1659.0], [13278.0, 1647.0], [13294.0, 1647.0], [13305.0, 1647.0], [13314.0, 1647.0], [13325.0, 1647.0], [13342.0, 1647.0], [13358.0, 1647.0], [13375.0, 1684.0], [13393.0, 1684.0], [13415.0, 1684.0], [13432.0, 1684.0], [13451.0, 1684.0], [13471.0, 1694.0], [13488.0, 1694.0], [13504.0, 1694.0], [13526.0, 1694.0], [13543.0, 1694.0], [13554.0, 1694.0], [13565.0, 1694.0], [13590.0, 1687.0], [13601.0, 1687.0], [13618.0, 1687.0], [13629.0, 1687.0], [13645.0, 1687.0], [13656.0, 1687.0], [13672.0, 1687.0], [13683.0, 1687.0], [13700.0, 1687.0], [13722.0, 1778.0], [13743.0, 1778.0], [13762.0, 1778.0], [13784.0, 1778.0], [13795.0, 1778.0], [13812.0, 1924.0], [13828.0, 1924.0], [13844.0, 1924.0], [13861.0, 1924.0], [13872.0, 1924.0], [13894.0, 1924.0], [13905.0, 2149.0], [13922.0, 2149.0], [13938.0, 2149.0], [13960.0, 2149.0], [13976.0, 2149.0], [13998.0, 2149.0], [14023.0, 2219.0], [14034.0, 2219.0], [14051.0, 2219.0], [14073.0, 2219.0], [14089.0, 2219.0], [14105.0, 2219.0], [14125.0, 2200.0], [14142.0, 2200.0], [14153.0, 2200.0], [14172.0, 2200.0], [14193.0, 2200.0], [14210.0, 2200.0], [14226.0, 2263.0], [14244.0, 2263.0], [14266.0, 2263.0], [14281.0, 2263.0], [14297.0, 2263.0], [14308.0, 2263.0], [14325.0, 2263.0], [14336.0, 2263.0], [14347.0, 2263.0], [14358.0, 2263.0], [14374.0, 2263.0], [14390.0, 2263.0], [14407.0, 2263.0], [14429.0, 2290.0], [14450.0, 2290.0], [14467.0, 2290.0], [14478.0, 2290.0], [14494.0, 2290.0], [14516.0, 2290.0], [14538.0, 2300.0], [14554.0, 2300.0], [14571.0, 2300.0], [14587.0, 2300.0], [14594.0, 2300.0], [14605.0, 2300.0], [14619.0, 2300.0], [14641.0, 2047.0], [14663.0, 2047.0], [14679.0, 2047.0], [14695.0, 2047.0], [14717.0, 2047.0], [14734.0, 1722.0], [14750.0, 1722.0], [14772.0, 1722.0], [14783.0, 1722.0], [14794.0, 1722.0], [14809.0, 1722.0], [14831.0, 1722.0], [14845.0, 1655.0], [14861.0, 1655.0], [14877.0, 1655.0], [14894.0, 1655.0], [14910.0, 1655.0], [14921.0, 1655.0], [14943.0, 1655.0], [14965.0, 1268.0], [14981.0, 1268.0], [15000.0, 1268.0], [15010.0, 1268.0], [15026.0, 1268.0], [15042.0, 1268.0], [15058.0, 1100.0], [15080.0, 1100.0], [15102.0, 1100.0], [15118.0, 1100.0], [15135.0, 1100.0], [15154.0, 1100.0], [15171.0, 1078.0], [15182.0, 1078.0], [15198.0, 1078.0], [15215.0, 1078.0], [15235.0, 1078.0], [15246.0, 1078.0], [15267.0, 1077.0], [15289.0, 1077.0], [15306.0, 1077.0], [15322.0, 1077.0], [15333.0, 1077.0], [15349.0, 1077.0], [15357.0, 1077.0], [15367.0, 1077.0], [15384.0, 1007.0], [15406.0, 1007.0], [15425.0, 1007.0], [15445.0, 1007.0], [15467.0, 1007.0], [15489.0, 956.0], [15505.0, 956.0], [15527.0, 956.0], [15544.0, 956.0], [15556.0, 956.0], [15567.0, 956.0], [15584.0, 958.0], [15595.0, 958.0], [15611.0, 958.0], [15633.0, 958.0], [15655.0, 958.0], [15671.0, 958.0], [15693.0, 948.0], [15715.0, 948.0], [15731.0, 948.0], [15748.0, 948.0], [15765.0, 948.0], [15787.0, 888.0], [15796.0, 888.0], [15812.0, 888.0], [15831.0, 888.0], [15851.0, 888.0], [15862.0, 888.0], [15872.0, 841.0], [15883.0, 841.0], [15894.0, 841.0], [15911.0, 841.0], [15927.0, 841.0], [15938.0, 841.0], [15955.0, 841.0], [15972.0, 837.0], [15988.0, 837.0], [16004.0, 837.0], [16021.0, 837.0], [16037.0, 837.0], [16059.0, 837.0], [16075.0, 837.0], [16100.0, 839.0], [16122.0, 839.0], [16133.0, 839.0], [16150.0, 839.0], [16176.0, 839.0], [16193.0, 850.0], [16204.0, 850.0], [16222.0, 850.0], [16244.0, 850.0], [16261.0, 850.0], [16277.0, 850.0], [16293.0, 891.0], [16304.0, 891.0], [16321.0, 891.0], [16337.0, 891.0], [16354.0, 891.0], [16377.0, 891.0], [16394.0, 894.0], [16405.0, 894.0], [16427.0, 894.0], [16448.0, 894.0], [16465.0, 894.0], [16481.0, 894.0], [16498.0, 908.0], [16520.0, 908.0], [16536.0, 908.0], [16547.0, 908.0], [16565.0, 908.0], [16577.0, 908.0], [16593.0, 1439.0], [16609.0, 1439.0], [16627.0, 1439.0], [16644.0, 1439.0], [16655.0, 1439.0], [16664.0, 1439.0], [16675.0, 1439.0], [16697.0, 1890.0], [16714.0, 1890.0], [16730.0, 1890.0], [16741.0, 1890.0], [16757.0, 1890.0], [16768.0, 1890.0], [16783.0, 1890.0], [16794.0, 1900.0], [16811.0, 1900.0], [16822.0, 1900.0], [16846.0, 1900.0], [16856.0, 1900.0], [16873.0, 1900.0], [16884.0, 1900.0], [16900.0, 1903.0], [16917.0, 1903.0], [16933.0, 1903.0], [16951.0, 1903.0], [16973.0, 1903.0], [16990.0, 1923.0], [17002.0, 1923.0], [17024.0, 1923.0], [17041.0, 1923.0], [17057.0, 1923.0], [17081.0, 1923.0], [17092.0, 1923.0], [17109.0, 1921.0], [17125.0, 1921.0], [17142.0, 1921.0], [17152.0, 1921.0], [17174.0, 1921.0], [17191.0, 1921.0], [17211.0, 1918.0], [17231.0, 1918.0], [17253.0, 1918.0], [17264.0, 1918.0], [17289.0, 1918.0], [17311.0, 1918.0], [17322.0, 1918.0], [17347.0, 1918.0], [17364.0, 1918.0], [17386.0, 1918.0], [17408.0, 1909.0], [17430.0, 1909.0], [17452.0, 1909.0], [17468.0, 1909.0], [17479.0, 1909.0], [17498.0, 1909.0], [17514.0, 1909.0], [17531.0, 1909.0], [17547.0, 1909.0], [17565.0, 1909.0], [17582.0, 1909.0], [17593.0, 1909.0], [17615.0, 1910.0], [17631.0, 1910.0], [17647.0, 1910.0], [17658.0, 1910.0], [17669.0, 1910.0], [17686.0, 1910.0], [17700.0, 1910.0], [17716.0, 1911.0], [17741.0, 1911.0], [17761.0, 1911.0], [17777.0, 1911.0], [17793.0, 1911.0], [17810.0, 1921.0], [17831.0, 1921.0], [17848.0, 1921.0], [17870.0, 1921.0], [17886.0, 1921.0], [17902.0, 1921.0], [17919.0, 1917.0], [17935.0, 1917.0], [17956.0, 1917.0], [17967.0, 1917.0], [17983.0, 1917.0], [17999.0, 1917.0], [18035.0, 1914.0]]
x1 = 0
y1 = 3
start = 0
end = 1010
theta = -0.08*np.pi

data = np.array(sensor_data)
time = data[start:end, 0]
tof1 = data[start:end, 1]

data03 = robot2global(tof1, x1, y1, theta)

# %%
sensor_data = [[10.0, 1034.0], [26.0, 1034.0], [42.0, 1034.0], [59.0, 1034.0], [76.0, 1034.0], [98.0, 1034.0], [120.0, 593.0], [131.0, 593.0], [147.0, 593.0], [158.0, 593.0], [184.0, 593.0], [206.0, 593.0], [223.0, 1131.0], [245.0, 1131.0], [255.0, 1131.0], [273.0, 1131.0], [289.0, 1131.0], [300.0, 1131.0], [311.0, 1428.0], [327.0, 1428.0], [338.0, 1428.0], [355.0, 1428.0], [371.0, 1428.0], [393.0, 1428.0], [409.0, 1428.0], [420.0, 1445.0], [447.0, 1445.0], [468.0, 1445.0], [479.0, 1445.0], [489.0, 1445.0], [506.0, 1445.0], [517.0, 236.0], [542.0, 236.0], [553.0, 236.0], [570.0, 236.0], [586.0, 236.0], [603.0, 236.0], [625.0, 232.0], [649.0, 232.0], [666.0, 232.0], [673.0, 232.0], [689.0, 232.0], [696.0, 232.0], [713.0, 499.0], [724.0, 499.0], [741.0, 499.0], [763.0, 499.0], [779.0, 499.0], [796.0, 499.0], [817.0, 563.0], [839.0, 563.0], [853.0, 563.0], [869.0, 563.0], [885.0, 563.0], [907.0, 563.0], [924.0, 575.0], [940.0, 575.0], [956.0, 575.0], [974.0, 575.0], [985.0, 575.0], [1002.0, 575.0], [1013.0, 797.0], [1029.0, 797.0], [1045.0, 797.0], [1071.0, 797.0], [1091.0, 797.0], [1102.0, 797.0], [1118.0, 1214.0], [1128.0, 1214.0], [1145.0, 1214.0], [1155.0, 1214.0], [1172.0, 1214.0], [1183.0, 1214.0], [1199.0, 1214.0], [1210.0, 1280.0], [1221.0, 1280.0], [1239.0, 1280.0], [1260.0, 1280.0], [1282.0, 1280.0], [1304.0, 1280.0], [1326.0, 1662.0], [1342.0, 1662.0], [1353.0, 1662.0], [1364.0, 1662.0], [1375.0, 1662.0], [1392.0, 1662.0], [1413.0, 1662.0], [1435.0, 1516.0], [1443.0, 1516.0], [1465.0, 1516.0], [1484.0, 1516.0], [1506.0, 1516.0], [1523.0, 713.0], [1539.0, 713.0], [1555.0, 713.0], [1577.0, 713.0], [1594.0, 713.0], [1610.0, 713.0], [1621.0, 713.0], [1637.0, 716.0], [1648.0, 716.0], [1659.0, 716.0], [1681.0, 716.0], [1692.0, 716.0], [1703.0, 716.0], [1714.0, 716.0], [1730.0, 725.0], [1745.0, 725.0], [1767.0, 725.0], [1784.0, 725.0], [1795.0, 725.0], [1802.0, 725.0], [1818.0, 725.0], [1836.0, 673.0], [1858.0, 673.0], [1875.0, 673.0], [1882.0, 673.0], [1889.0, 673.0], [1906.0, 673.0], [1917.0, 673.0], [1934.0, 654.0], [1949.0, 654.0], [1965.0, 654.0], [1981.0, 654.0], [2003.0, 654.0], [2025.0, 654.0], [2041.0, 652.0], [2058.0, 652.0], [2074.0, 652.0], [2085.0, 652.0], [2102.0, 652.0], [2118.0, 652.0], [2129.0, 652.0], [2140.0, 652.0], [2162.0, 652.0], [2178.0, 652.0], [2200.0, 652.0], [2216.0, 652.0], [2229.0, 652.0], [2246.0, 648.0], [2262.0, 648.0], [2273.0, 648.0], [2284.0, 648.0], [2295.0, 648.0], [2311.0, 648.0], [2322.0, 648.0], [2339.0, 648.0], [2350.0, 647.0], [2366.0, 647.0], [2388.0, 647.0], [2404.0, 647.0], [2421.0, 647.0], [2437.0, 647.0], [2448.0, 647.0], [2465.0, 647.0], [2476.0, 647.0], [2487.0, 647.0], [2498.0, 647.0], [2508.0, 647.0], [2525.0, 647.0], [2541.0, 647.0], [2563.0, 646.0], [2577.0, 646.0], [2593.0, 646.0], [2609.0, 646.0], [2626.0, 646.0], [2648.0, 646.0], [2662.0, 649.0], [2678.0, 649.0], [2685.0, 649.0], [2701.0, 649.0], [2723.0, 649.0], [2748.0, 649.0], [2765.0, 657.0], [2776.0, 657.0], [2792.0, 657.0], [2809.0, 657.0], [2819.0, 657.0], [2836.0, 657.0], [2847.0, 657.0], [2858.0, 658.0], [2874.0, 658.0], [2891.0, 658.0], [2907.0, 658.0], [2929.0, 658.0], [2945.0, 658.0], [2962.0, 661.0], [2978.0, 661.0], [2989.0, 661.0], [3015.0, 661.0], [3032.0, 661.0], [3043.0, 661.0], [3064.0, 671.0], [3086.0, 671.0], [3112.0, 671.0], [3132.0, 671.0], [3148.0, 671.0], [3158.0, 680.0], [3175.0, 680.0], [3185.0, 680.0], [3207.0, 680.0], [3224.0, 680.0], [3235.0, 680.0], [3246.0, 680.0], [3257.0, 687.0], [3284.0, 687.0], [3300.0, 687.0], [3311.0, 687.0], [3328.0, 687.0], [3349.0, 687.0], [3366.0, 687.0], [3377.0, 687.0], [3388.0, 687.0], [3406.0, 687.0], [3427.0, 687.0], [3444.0, 687.0], [3460.0, 710.0], [3477.0, 710.0], [3495.0, 710.0], [3512.0, 710.0], [3523.0, 710.0], [3535.0, 710.0], [3553.0, 710.0], [3563.0, 710.0], [3580.0, 731.0], [3591.0, 731.0], [3602.0, 731.0], [3613.0, 731.0], [3629.0, 731.0], [3651.0, 731.0], [3673.0, 731.0], [3689.0, 732.0], [3709.0, 732.0], [3730.0, 732.0], [3747.0, 732.0], [3758.0, 732.0], [3774.0, 732.0], [3785.0, 741.0], [3811.0, 741.0], [3828.0, 741.0], [3844.0, 741.0], [3861.0, 741.0], [3878.0, 741.0], [3900.0, 799.0], [3916.0, 799.0], [3932.0, 799.0], [3954.0, 799.0], [3974.0, 799.0], [3991.0, 816.0], [4007.0, 816.0], [4026.0, 816.0], [4046.0, 816.0], [4066.0, 816.0], [4077.0, 816.0], [4094.0, 819.0], [4105.0, 819.0], [4121.0, 819.0], [4143.0, 819.0], [4159.0, 819.0], [4176.0, 819.0], [4187.0, 830.0], [4212.0, 830.0], [4223.0, 830.0], [4240.0, 830.0], [4251.0, 830.0], [4266.0, 830.0], [4287.0, 830.0], [4308.0, 876.0], [4319.0, 876.0], [4329.0, 876.0], [4340.0, 876.0], [4352.0, 876.0], [4370.0, 876.0], [4391.0, 876.0], [4402.0, 880.0], [4413.0, 880.0], [4424.0, 880.0], [4438.0, 880.0], [4456.0, 880.0], [4478.0, 880.0], [4493.0, 880.0], [4509.0, 884.0], [4525.0, 884.0], [4547.0, 884.0], [4569.0, 884.0], [4585.0, 884.0], [4605.0, 884.0], [4627.0, 881.0], [4646.0, 881.0], [4656.0, 881.0], [4673.0, 881.0], [4684.0, 881.0], [4696.0, 881.0], [4719.0, 845.0], [4739.0, 845.0], [4756.0, 845.0], [4767.0, 845.0], [4774.0, 845.0], [4790.0, 845.0], [4808.0, 845.0], [4828.0, 845.0], [4845.0, 805.0], [4861.0, 805.0], [4878.0, 805.0], [4899.0, 805.0], [4917.0, 805.0], [4938.0, 805.0], [4949.0, 806.0], [4960.0, 806.0], [4977.0, 806.0], [4991.0, 806.0], [5009.0, 806.0], [5030.0, 806.0], [5047.0, 788.0], [5063.0, 788.0], [5080.0, 788.0], [5096.0, 788.0], [5114.0, 788.0], [5125.0, 788.0], [5134.0, 788.0], [5150.0, 788.0], [5161.0, 752.0], [5184.0, 752.0], [5195.0, 752.0], [5205.0, 752.0], [5216.0, 752.0], [5227.0, 752.0], [5244.0, 752.0], [5260.0, 745.0], [5277.0, 745.0], [5287.0, 745.0], [5303.0, 745.0], [5315.0, 745.0], [5339.0, 745.0], [5357.0, 742.0], [5375.0, 742.0], [5395.0, 742.0], [5417.0, 742.0], [5432.0, 742.0], [5448.0, 742.0], [5464.0, 729.0], [5486.0, 729.0], [5508.0, 729.0], [5530.0, 729.0], [5557.0, 729.0], [5579.0, 707.0], [5601.0, 707.0], [5617.0, 707.0], [5639.0, 707.0], [5653.0, 707.0], [5669.0, 707.0], [5685.0, 700.0], [5707.0, 700.0], [5732.0, 700.0], [5749.0, 700.0], [5765.0, 700.0], [5787.0, 700.0], [5803.0, 700.0], [5825.0, 700.0], [5842.0, 700.0], [5858.0, 700.0], [5875.0, 700.0], [5896.0, 694.0], [5918.0, 694.0], [5944.0, 694.0], [5964.0, 694.0], [5975.0, 694.0], [5992.0, 688.0], [6008.0, 688.0], [6023.0, 688.0], [6040.0, 688.0], [6051.0, 688.0], [6062.0, 688.0], [6078.0, 688.0], [6089.0, 688.0], [6111.0, 688.0], [6133.0, 688.0], [6149.0, 688.0], [6169.0, 688.0], [6187.0, 688.0], [6213.0, 687.0], [6231.0, 687.0], [6249.0, 687.0], [6270.0, 687.0], [6292.0, 687.0], [6309.0, 684.0], [6320.0, 684.0], [6331.0, 684.0], [6347.0, 684.0], [6358.0, 684.0], [6383.0, 684.0], [6394.0, 684.0], [6411.0, 684.0], [6422.0, 684.0], [6438.0, 684.0], [6449.0, 684.0], [6465.0, 684.0], [6482.0, 684.0], [6493.0, 684.0], [6505.0, 686.0], [6525.0, 686.0], [6542.0, 686.0], [6558.0, 686.0], [6569.0, 686.0], [6585.0, 686.0], [6602.0, 686.0], [6613.0, 689.0], [6634.0, 689.0], [6645.0, 689.0], [6656.0, 689.0], [6673.0, 689.0], [6689.0, 689.0], [6700.0, 689.0], [6716.0, 690.0], [6733.0, 690.0], [6745.0, 690.0], [6766.0, 690.0], [6788.0, 690.0], [6808.0, 690.0], [6819.0, 693.0], [6836.0, 693.0], [6863.0, 693.0], [6879.0, 693.0], [6895.0, 693.0], [6907.0, 693.0], [6918.0, 699.0], [6934.0, 699.0], [6949.0, 699.0], [6971.0, 699.0], [6982.0, 699.0], [6999.0, 699.0], [7020.0, 699.0], [7043.0, 708.0], [7059.0, 708.0], [7075.0, 708.0], [7092.0, 708.0], [7108.0, 708.0], [7119.0, 708.0], [7135.0, 725.0], [7152.0, 725.0], [7168.0, 725.0], [7179.0, 725.0], [7195.0, 725.0], [7215.0, 725.0], [7235.0, 740.0], [7246.0, 740.0], [7262.0, 740.0], [7284.0, 740.0], [7300.0, 740.0], [7317.0, 740.0], [7333.0, 746.0], [7344.0, 746.0], [7360.0, 746.0], [7377.0, 746.0], [7393.0, 746.0], [7409.0, 746.0], [7420.0, 746.0], [7446.0, 747.0], [7468.0, 747.0], [7479.0, 747.0], [7496.0, 747.0], [7512.0, 747.0], [7528.0, 747.0], [7545.0, 761.0], [7556.0, 761.0], [7574.0, 761.0], [7594.0, 761.0], [7610.0, 761.0], [7628.0, 761.0], [7638.0, 781.0], [7655.0, 781.0], [7667.0, 781.0], [7683.0, 781.0], [7694.0, 781.0], [7705.0, 781.0], [7721.0, 781.0], [7736.0, 798.0], [7758.0, 798.0], [7775.0, 798.0], [7791.0, 798.0], [7806.0, 798.0], [7817.0, 798.0], [7834.0, 801.0], [7845.0, 801.0], [7856.0, 801.0], [7867.0, 801.0], [7885.0, 801.0], [7896.0, 801.0], [7913.0, 801.0], [7929.0, 817.0], [7946.0, 817.0], [7956.0, 817.0], [7967.0, 817.0], [7989.0, 817.0], [8006.0, 817.0], [8028.0, 817.0], [8044.0, 849.0], [8068.0, 849.0], [8089.0, 849.0], [8106.0, 849.0], [8117.0, 849.0], [8128.0, 849.0], [8147.0, 873.0], [8167.0, 873.0], [8184.0, 873.0], [8195.0, 873.0], [8206.0, 873.0], [8222.0, 873.0], [8238.0, 871.0], [8249.0, 871.0], [8271.0, 871.0], [8282.0, 871.0], [8293.0, 871.0], [8310.0, 871.0], [8326.0, 871.0], [8348.0, 913.0], [8364.0, 913.0], [8371.0, 913.0], [8388.0, 913.0], [8399.0, 913.0], [8424.0, 913.0], [8435.0, 962.0], [8452.0, 962.0], [8463.0, 962.0], [8479.0, 962.0], [8490.0, 962.0], [8510.0, 962.0], [8527.0, 962.0], [8538.0, 967.0], [8549.0, 967.0], [8565.0, 967.0], [8580.0, 967.0], [8598.0, 967.0], [8615.0, 967.0], [8626.0, 967.0], [8645.0, 968.0], [8665.0, 968.0], [8685.0, 968.0], [8696.0, 968.0], [8713.0, 968.0], [8729.0, 968.0], [8746.0, 971.0], [8762.0, 971.0], [8784.0, 971.0], [8799.0, 971.0], [8815.0, 971.0], [8831.0, 971.0], [8841.0, 943.0], [8865.0, 943.0], [8885.0, 943.0], [8896.0, 943.0], [8913.0, 943.0], [8924.0, 943.0], [8940.0, 943.0], [8951.0, 920.0], [8978.0, 920.0], [8995.0, 920.0], [9011.0, 920.0], [9028.0, 920.0], [9038.0, 920.0], [9064.0, 917.0], [9075.0, 917.0], [9092.0, 917.0], [9103.0, 917.0], [9114.0, 917.0], [9130.0, 917.0], [9148.0, 917.0], [9167.0, 860.0], [9184.0, 860.0], [9199.0, 860.0], [9210.0, 860.0], [9220.0, 860.0], [9237.0, 860.0], [9248.0, 860.0], [9264.0, 803.0], [9281.0, 803.0], [9292.0, 803.0], [9302.0, 803.0], [9313.0, 803.0], [9332.0, 803.0], [9343.0, 803.0], [9365.0, 806.0], [9382.0, 806.0], [9398.0, 806.0], [9409.0, 806.0], [9425.0, 806.0], [9442.0, 806.0], [9453.0, 807.0], [9479.0, 807.0], [9496.0, 807.0], [9512.0, 807.0], [9529.0, 807.0], [9545.0, 807.0], [9556.0, 777.0], [9572.0, 777.0], [9594.0, 777.0], [9601.0, 777.0], [9623.0, 777.0], [9640.0, 777.0], [9656.0, 737.0], [9672.0, 737.0], [9689.0, 737.0], [9706.0, 737.0], [9717.0, 737.0], [9728.0, 737.0], [9744.0, 737.0], [9759.0, 736.0], [9776.0, 736.0], [9792.0, 736.0], [9809.0, 736.0], [9830.0, 736.0], [9852.0, 736.0], [9869.0, 734.0], [9887.0, 734.0], [9905.0, 734.0], [9922.0, 734.0], [9938.0, 734.0], [9949.0, 734.0], [9960.0, 734.0], [9986.0, 722.0], [10008.0, 722.0], [10019.0, 722.0], [10044.0, 722.0], [10055.0, 722.0], [10072.0, 713.0], [10083.0, 713.0], [10099.0, 713.0], [10110.0, 713.0], [10126.0, 713.0], [10143.0, 713.0], [10154.0, 713.0], [10165.0, 704.0], [10178.0, 704.0], [10199.0, 704.0], [10216.0, 704.0], [10232.0, 704.0], [10249.0, 704.0], [10265.0, 703.0], [10287.0, 703.0], [10310.0, 703.0], [10326.0, 703.0], [10342.0, 703.0], [10364.0, 703.0], [10392.0, 698.0], [10413.0, 698.0], [10430.0, 698.0], [10447.0, 698.0], [10468.0, 698.0], [10490.0, 691.0], [10504.0, 691.0], [10520.0, 691.0], [10536.0, 691.0], [10553.0, 691.0], [10575.0, 691.0], [10591.0, 686.0], [10602.0, 686.0], [10616.0, 686.0], [10638.0, 686.0], [10660.0, 686.0], [10676.0, 686.0], [10692.0, 680.0], [10709.0, 680.0], [10731.0, 680.0], [10747.0, 680.0], [10758.0, 680.0], [10769.0, 680.0], [10791.0, 680.0], [10813.0, 682.0], [10835.0, 682.0], [10856.0, 682.0], [10873.0, 682.0], [10889.0, 682.0], [10908.0, 682.0], [10918.0, 682.0], [10935.0, 682.0], [10946.0, 682.0], [10962.0, 682.0], [10979.0, 682.0], [10995.0, 682.0], [11006.0, 682.0], [11017.0, 682.0], [11044.0, 682.0], [11061.0, 682.0], [11072.0, 682.0], [11082.0, 682.0], [11099.0, 682.0], [11110.0, 681.0], [11136.0, 681.0], [11147.0, 681.0], [11158.0, 681.0], [11169.0, 681.0], [11186.0, 681.0], [11204.0, 681.0], [11224.0, 688.0], [11235.0, 688.0], [11252.0, 688.0], [11268.0, 688.0], [11285.0, 688.0], [11306.0, 688.0], [11328.0, 692.0], [11345.0, 692.0], [11361.0, 692.0], [11383.0, 692.0], [11399.0, 692.0], [11410.0, 692.0], [11422.0, 692.0], [11440.0, 692.0], [11461.0, 692.0], [11478.0, 692.0], [11494.0, 692.0], [11511.0, 692.0], [11527.0, 694.0], [11549.0, 694.0], [11571.0, 694.0], [11590.0, 694.0], [11607.0, 694.0], [11623.0, 704.0], [11640.0, 704.0], [11654.0, 704.0], [11671.0, 704.0], [11691.0, 704.0], [11708.0, 704.0], [11730.0, 720.0], [11752.0, 720.0], [11774.0, 720.0], [11790.0, 720.0], [11807.0, 720.0], [11829.0, 720.0], [11851.0, 720.0], [11872.0, 720.0], [11889.0, 720.0], [11905.0, 720.0], [11916.0, 720.0], [11932.0, 720.0], [11946.0, 720.0], [11956.0, 720.0], [11978.0, 720.0], [12000.0, 720.0], [12017.0, 735.0], [12033.0, 735.0], [12050.0, 735.0], [12061.0, 735.0], [12078.0, 735.0], [12093.0, 735.0], [12109.0, 735.0], [12125.0, 750.0], [12142.0, 750.0], [12159.0, 750.0], [12170.0, 750.0], [12192.0, 750.0], [12204.0, 750.0], [12221.0, 788.0], [12237.0, 788.0], [12259.0, 788.0], [12281.0, 788.0], [12303.0, 788.0], [12319.0, 807.0], [12335.0, 807.0], [12352.0, 807.0], [12375.0, 807.0], [12395.0, 807.0], [12415.0, 807.0], [12432.0, 826.0], [12443.0, 826.0], [12459.0, 826.0], [12476.0, 826.0], [12497.0, 826.0], [12514.0, 826.0], [12525.0, 844.0], [12542.0, 844.0], [12561.0, 844.0], [12583.0, 844.0], [12600.0, 844.0], [12616.0, 844.0], [12630.0, 848.0], [12641.0, 848.0], [12652.0, 848.0], [12669.0, 848.0], [12682.0, 848.0], [12698.0, 848.0], [12709.0, 848.0], [12725.0, 862.0], [12736.0, 862.0], [12753.0, 862.0], [12769.0, 862.0], [12791.0, 862.0], [12805.0, 862.0], [12821.0, 862.0], [12837.0, 863.0], [12854.0, 863.0], [12876.0, 863.0], [12892.0, 863.0], [12919.0, 863.0], [12941.0, 860.0], [12958.0, 860.0], [12969.0, 860.0], [12985.0, 860.0], [12996.0, 860.0], [13007.0, 860.0], [13018.0, 860.0], [13034.0, 845.0], [13045.0, 845.0], [13061.0, 845.0], [13072.0, 845.0], [13083.0, 845.0], [13094.0, 845.0], [13111.0, 845.0], [13127.0, 821.0], [13139.0, 821.0], [13159.0, 821.0], [13181.0, 821.0], [13192.0, 821.0], [13220.0, 821.0], [13236.0, 779.0], [13252.0, 779.0], [13269.0, 779.0], [13280.0, 779.0], [13305.0, 779.0], [13322.0, 779.0], [13338.0, 779.0], [13355.0, 739.0], [13371.0, 739.0], [13393.0, 739.0], [13407.0, 739.0], [13423.0, 739.0], [13439.0, 739.0], [13456.0, 727.0], [13467.0, 727.0], [13483.0, 727.0], [13500.0, 727.0], [13510.0, 727.0], [13521.0, 727.0], [13543.0, 727.0], [13560.0, 713.0], [13581.0, 713.0], [13598.0, 713.0], [13620.0, 713.0], [13642.0, 713.0], [13658.0, 697.0], [13674.0, 697.0], [13691.0, 697.0], [13713.0, 697.0], [13729.0, 697.0], [13740.0, 697.0], [13751.0, 681.0], [13769.0, 681.0], [13790.0, 681.0], [13807.0, 681.0], [13823.0, 681.0], [13840.0, 681.0], [13856.0, 666.0], [13872.0, 666.0], [13889.0, 666.0], [13913.0, 666.0], [13933.0, 666.0], [13949.0, 666.0], [13965.0, 651.0], [13987.0, 651.0], [14013.0, 651.0], [14032.0, 651.0], [14054.0, 651.0], [14071.0, 638.0], [14087.0, 638.0], [14098.0, 638.0], [14111.0, 638.0], [14129.0, 638.0], [14146.0, 638.0], [14157.0, 638.0], [14168.0, 633.0], [14179.0, 633.0], [14201.0, 633.0], [14217.0, 633.0], [14234.0, 633.0], [14256.0, 633.0], [14272.0, 628.0], [14289.0, 628.0], [14305.0, 628.0], [14322.0, 628.0], [14344.0, 628.0], [14359.0, 628.0], [14375.0, 625.0], [14391.0, 625.0], [14408.0, 625.0], [14419.0, 625.0], [14445.0, 625.0], [14462.0, 625.0], [14478.0, 625.0], [14498.0, 625.0], [14516.0, 625.0], [14536.0, 625.0], [14558.0, 625.0], [14575.0, 626.0], [14591.0, 626.0], [14608.0, 626.0], [14624.0, 626.0], [14640.0, 626.0], [14657.0, 626.0], [14668.0, 628.0], [14679.0, 628.0], [14690.0, 628.0], [14706.0, 628.0], [14717.0, 628.0], [14728.0, 628.0], [14750.0, 628.0], [14772.0, 628.0], [14788.0, 626.0], [14814.0, 626.0], [14831.0, 626.0], [14847.0, 626.0], [14858.0, 626.0], [14869.0, 626.0], [14895.0, 627.0], [14906.0, 627.0], [14923.0, 627.0], [14934.0, 627.0], [14950.0, 627.0], [14961.0, 627.0], [14977.0, 627.0], [14988.0, 637.0], [15005.0, 637.0], [15016.0, 637.0], [15032.0, 637.0], [15043.0, 637.0], [15054.0, 637.0], [15065.0, 637.0], [15081.0, 637.0], [15093.0, 637.0], [15103.0, 637.0], [15120.0, 637.0], [15145.0, 637.0], [15156.0, 637.0], [15173.0, 637.0], [15184.0, 637.0], [15195.0, 309.0], [15210.0, 309.0], [15232.0, 309.0], [15247.0, 309.0], [15263.0, 309.0], [15274.0, 309.0], [15296.0, 309.0], [15313.0, 449.0], [15324.0, 449.0], [15340.0, 449.0], [15356.0, 449.0], [15367.0, 449.0], [15384.0, 449.0], [15395.0, 449.0], [15411.0, 735.0], [15427.0, 735.0], [15444.0, 735.0], [15455.0, 735.0], [15466.0, 735.0], [15477.0, 735.0], [15493.0, 735.0], [15504.0, 753.0], [15520.0, 753.0], [15540.0, 753.0], [15557.0, 753.0], [15573.0, 753.0], [15589.0, 753.0], [15615.0, 612.0], [15635.0, 612.0], [15646.0, 612.0], [15671.0, 612.0], [15691.0, 612.0], [15708.0, 842.0], [15719.0, 842.0], [15730.0, 842.0], [15752.0, 842.0], [15762.0, 842.0], [15779.0, 842.0], [15790.0, 842.0], [15816.0, 1422.0], [15833.0, 1422.0], [15844.0, 1422.0], [15855.0, 1422.0], [15877.0, 1422.0], [15893.0, 1422.0], [15909.0, 839.0], [15920.0, 839.0], [15946.0, 839.0], [15963.0, 839.0], [15974.0, 839.0], [15991.0, 839.0], [16006.0, 1547.0], [16022.0, 1547.0], [16042.0, 1547.0], [16064.0, 1547.0], [16081.0, 1547.0], [16100.0, 1547.0], [16111.0, 1378.0], [16132.0, 1378.0], [16149.0, 1378.0], [16165.0, 1378.0], [16182.0, 1378.0], [16198.0, 1378.0], [16214.0, 1459.0], [16225.0, 1459.0], [16236.0, 1459.0], [16247.0, 1459.0], [16264.0, 1459.0], [16285.0, 1459.0], [16307.0, 1459.0], [16324.0, 1464.0], [16340.0, 1464.0], [16357.0, 1464.0], [16373.0, 1464.0], [16389.0, 1464.0], [16406.0, 1464.0], [16422.0, 1422.0], [16447.0, 1422.0], [16467.0, 1422.0], [16484.0, 1422.0], [16495.0, 1422.0], [16514.0, 1422.0], [16531.0, 1498.0], [16547.0, 1498.0], [16563.0, 1498.0], [16580.0, 1498.0], [16596.0, 1498.0], [16607.0, 1498.0], [16623.0, 1480.0], [16640.0, 1480.0], [16658.0, 1480.0], [16680.0, 1480.0], [16691.0, 1480.0], [16702.0, 1480.0], [16713.0, 1480.0], [16729.0, 1480.0], [16744.0, 1420.0], [16766.0, 1420.0], [16788.0, 1420.0], [16808.0, 1420.0], [16829.0, 1420.0], [16851.0, 1476.0], [16868.0, 1476.0], [16879.0, 1476.0], [16903.0, 1476.0], [16924.0, 1476.0], [16941.0, 1449.0], [16952.0, 1449.0], [16963.0, 1449.0], [16982.0, 1449.0], [17002.0, 1449.0], [17019.0, 1449.0], [17030.0, 1493.0], [17041.0, 1493.0], [17057.0, 1493.0], [17079.0, 1493.0], [17101.0, 1493.0], [17117.0, 1493.0], [17134.0, 1516.0], [17145.0, 1516.0], [17161.0, 1516.0], [17183.0, 1516.0], [17199.0, 1516.0], [17216.0, 1516.0], [17233.0, 1495.0], [17255.0, 1495.0], [17266.0, 1495.0], [17283.0, 1495.0], [17309.0, 1495.0], [17329.0, 856.0], [17349.0, 856.0], [17367.0, 856.0], [17378.0, 856.0], [17390.0, 856.0], [17400.0, 856.0], [17417.0, 856.0], [17428.0, 613.0], [17450.0, 613.0], [17472.0, 613.0], [17488.0, 613.0], [17507.0, 613.0], [17528.0, 613.0], [17545.0, 282.0], [17561.0, 282.0], [17572.0, 282.0], [17583.0, 282.0], [17602.0, 282.0], [17622.0, 282.0], [17639.0, 170.0], [17650.0, 170.0], [17661.0, 170.0], [17677.0, 170.0], [17699.0, 170.0], [17721.0, 170.0], [17741.0, 135.0], [17761.0, 135.0], [17772.0, 135.0], [17789.0, 135.0], [17800.0, 135.0], [17814.0, 135.0], [17832.0, 135.0], [17854.0, 160.0], [17876.0, 160.0], [17901.0, 160.0], [17912.0, 160.0], [17929.0, 160.0], [17940.0, 214.0], [17956.0, 214.0], [17972.0, 214.0], [17988.0, 214.0], [18016.0, 214.0]]
x1 = -3
y1 = -2
start = 40
end = 1104
theta = 0.31*np.pi

data = np.array(sensor_data)
time = data[start:end, 0]
tof1 = data[start:end, 1]

data_3_2 = robot2global(tof1, x1, y1, theta)

# %%
sensor_data = [[19.0, 378.0], [35.0, 378.0], [52.0, 378.0], [68.0, 378.0], [95.0, 378.0], [117.0, 378.0], [139.0, 380.0], [161.0, 380.0], [188.0, 380.0], [205.0, 380.0], [220.0, 380.0], [240.0, 380.0], [258.0, 380.0], [274.0, 380.0], [293.0, 380.0], [313.0, 380.0], [333.0, 380.0], [343.0, 397.0], [364.0, 397.0], [380.0, 397.0], [397.0, 397.0], [413.0, 397.0], [429.0, 397.0], [442.0, 427.0], [464.0, 427.0], [486.0, 427.0], [505.0, 427.0], [523.0, 427.0], [542.0, 427.0], [552.0, 445.0], [570.0, 445.0], [586.0, 445.0], [608.0, 445.0], [628.0, 445.0], [645.0, 445.0], [661.0, 475.0], [683.0, 475.0], [705.0, 475.0], [727.0, 475.0], [749.0, 475.0], [767.0, 477.0], [789.0, 477.0], [810.0, 477.0], [830.0, 477.0], [841.0, 477.0], [851.0, 477.0], [868.0, 477.0], [895.0, 477.0], [914.0, 477.0], [930.0, 477.0], [952.0, 477.0], [968.0, 490.0], [990.0, 490.0], [1006.0, 490.0], [1032.0, 490.0], [1043.0, 490.0], [1060.0, 490.0], [1077.0, 536.0], [1099.0, 536.0], [1125.0, 536.0], [1137.0, 536.0], [1145.0, 536.0], [1163.0, 536.0], [1183.0, 550.0], [1205.0, 550.0], [1218.0, 550.0], [1239.0, 550.0], [1261.0, 550.0], [1281.0, 554.0], [1301.0, 554.0], [1321.0, 554.0], [1338.0, 554.0], [1348.0, 554.0], [1374.0, 554.0], [1385.0, 569.0], [1401.0, 569.0], [1417.0, 569.0], [1439.0, 569.0], [1449.0, 569.0], [1465.0, 569.0], [1481.0, 569.0], [1498.0, 635.0], [1520.0, 635.0], [1542.0, 635.0], [1563.0, 635.0], [1583.0, 635.0], [1594.0, 651.0], [1610.0, 651.0], [1621.0, 651.0], [1637.0, 651.0], [1648.0, 651.0], [1665.0, 651.0], [1681.0, 651.0], [1697.0, 655.0], [1719.0, 655.0], [1732.0, 655.0], [1750.0, 655.0], [1770.0, 655.0], [1781.0, 655.0], [1798.0, 679.0], [1820.0, 679.0], [1843.0, 679.0], [1862.0, 679.0], [1872.0, 679.0], [1898.0, 772.0], [1916.0, 772.0], [1936.0, 772.0], [1958.0, 772.0], [1969.0, 772.0], [1989.0, 772.0], [2009.0, 772.0], [2020.0, 830.0], [2037.0, 830.0], [2053.0, 830.0], [2075.0, 830.0], [2091.0, 830.0], [2117.0, 830.0], [2137.0, 830.0], [2159.0, 830.0], [2181.0, 830.0], [2198.0, 830.0], [2214.0, 830.0], [2230.0, 929.0], [2248.0, 929.0], [2267.0, 929.0], [2283.0, 929.0], [2303.0, 929.0], [2323.0, 929.0], [2341.0, 1084.0], [2361.0, 1084.0], [2383.0, 1084.0], [2396.0, 1084.0], [2414.0, 1084.0], [2433.0, 1084.0], [2443.0, 1147.0], [2466.0, 1147.0], [2482.0, 1147.0], [2504.0, 1147.0], [2529.0, 1147.0], [2539.0, 1138.0], [2565.0, 1138.0], [2585.0, 1138.0], [2603.0, 1138.0], [2614.0, 1138.0], [2631.0, 1138.0], [2653.0, 1350.0], [2678.0, 1350.0], [2696.0, 1350.0], [2713.0, 1350.0], [2723.0, 1350.0], [2739.0, 1350.0], [2761.0, 2051.0], [2783.0, 2051.0], [2805.0, 2051.0], [2826.0, 2051.0], [2843.0, 2051.0], [2865.0, 2128.0], [2881.0, 2128.0], [2907.0, 2128.0], [2927.0, 2128.0], [2938.0, 2128.0], [2954.0, 2136.0], [2965.0, 2136.0], [2992.0, 2136.0], [3014.0, 2136.0], [3033.0, 2136.0], [3044.0, 2195.0], [3060.0, 2195.0], [3071.0, 2195.0], [3087.0, 2195.0], [3098.0, 2195.0], [3115.0, 2195.0], [3131.0, 2195.0], [3147.0, 2252.0], [3169.0, 2252.0], [3182.0, 2252.0], [3200.0, 2252.0], [3220.0, 2252.0], [3242.0, 2252.0], [3255.0, 2274.0], [3273.0, 2274.0], [3292.0, 2274.0], [3302.0, 2274.0], [3328.0, 2274.0], [3348.0, 2274.0], [3366.0, 2291.0], [3383.0, 2291.0], [3405.0, 2291.0], [3431.0, 2291.0], [3449.0, 2291.0], [3468.0, 2288.0], [3478.0, 2288.0], [3506.0, 2288.0], [3528.0, 2288.0], [3544.0, 2288.0], [3566.0, 2293.0], [3577.0, 2293.0], [3588.0, 2293.0], [3605.0, 2293.0], [3627.0, 2293.0], [3648.0, 2293.0], [3667.0, 2329.0], [3677.0, 2329.0], [3694.0, 2329.0], [3710.0, 2329.0], [3727.0, 2329.0], [3738.0, 2329.0], [3765.0, 2326.0], [3787.0, 2326.0], [3803.0, 2326.0], [3825.0, 2326.0], [3847.0, 2326.0], [3858.0, 2326.0], [3884.0, 2326.0], [3906.0, 2330.0], [3923.0, 2330.0], [3950.0, 2330.0], [3975.0, 2330.0], [3995.0, 2330.0], [4017.0, 2399.0], [4027.0, 2399.0], [4049.0, 2399.0], [4075.0, 2399.0], [4095.0, 2399.0], [4117.0, 2459.0], [4139.0, 2459.0], [4165.0, 2459.0], [4185.0, 2459.0], [4206.0, 2459.0], [4228.0, 2457.0], [4250.0, 2457.0], [4275.0, 2457.0], [4295.0, 2457.0], [4316.0, 2457.0], [4333.0, 2728.0], [4355.0, 2728.0], [4377.0, 2728.0], [4398.0, 2728.0], [4418.0, 2728.0], [4427.0, 3156.0], [4449.0, 3156.0], [4465.0, 3156.0], [4481.0, 3156.0], [4498.0, 3156.0], [4513.0, 3156.0], [4533.0, 3017.0], [4555.0, 3017.0], [4577.0, 3017.0], [4603.0, 3017.0], [4623.0, 3017.0], [4644.0, 2690.0], [4661.0, 2690.0], [4683.0, 2690.0], [4696.0, 2690.0], [4714.0, 2690.0], [4734.0, 2690.0], [4745.0, 1000.0], [4762.0, 1000.0], [4778.0, 1000.0], [4795.0, 1000.0], [4816.0, 1000.0], [4834.0, 1000.0], [4855.0, 764.0], [4875.0, 764.0], [4886.0, 764.0], [4902.0, 764.0], [4918.0, 764.0], [4929.0, 764.0], [4946.0, 743.0], [4961.0, 743.0], [4979.0, 743.0], [4999.0, 743.0], [5021.0, 743.0], [5038.0, 743.0], [5049.0, 736.0], [5065.0, 736.0], [5087.0, 736.0], [5109.0, 736.0], [5132.0, 736.0], [5151.0, 694.0], [5161.0, 694.0], [5177.0, 694.0], [5199.0, 694.0], [5209.0, 694.0], [5225.0, 694.0], [5236.0, 651.0], [5253.0, 651.0], [5269.0, 651.0], [5291.0, 651.0], [5313.0, 651.0], [5335.0, 651.0], [5351.0, 645.0], [5370.0, 645.0], [5390.0, 645.0], [5407.0, 645.0], [5423.0, 645.0], [5445.0, 645.0], [5467.0, 635.0], [5493.0, 635.0], [5513.0, 635.0], [5533.0, 635.0], [5554.0, 635.0], [5565.0, 573.0], [5587.0, 573.0], [5611.0, 573.0], [5632.0, 573.0], [5654.0, 573.0], [5671.0, 547.0], [5686.0, 547.0], [5708.0, 547.0], [5734.0, 547.0], [5754.0, 547.0], [5773.0, 549.0], [5783.0, 549.0], [5809.0, 549.0], [5829.0, 549.0], [5850.0, 549.0], [5872.0, 536.0], [5889.0, 536.0], [5909.0, 536.0], [5927.0, 536.0], [5947.0, 536.0], [5967.0, 500.0], [5989.0, 500.0], [6011.0, 500.0], [6032.0, 500.0], [6052.0, 500.0], [6074.0, 485.0], [6096.0, 485.0], [6113.0, 485.0], [6134.0, 485.0], [6156.0, 485.0], [6180.0, 489.0], [6199.0, 489.0], [6209.0, 489.0], [6235.0, 489.0], [6255.0, 489.0], [6273.0, 477.0], [6285.0, 477.0], [6297.0, 477.0], [6319.0, 477.0], [6336.0, 477.0], [6352.0, 477.0], [6374.0, 455.0], [6386.0, 455.0], [6411.0, 455.0], [6429.0, 455.0], [6445.0, 455.0], [6464.0, 455.0], [6484.0, 448.0], [6504.0, 448.0], [6524.0, 448.0], [6544.0, 448.0], [6564.0, 448.0], [6584.0, 450.0], [6595.0, 450.0], [6611.0, 450.0], [6622.0, 450.0], [6649.0, 450.0], [6671.0, 450.0], [6695.0, 448.0], [6715.0, 448.0], [6737.0, 448.0], [6754.0, 448.0], [6771.0, 448.0], [6788.0, 459.0], [6809.0, 459.0], [6831.0, 459.0], [6850.0, 459.0], [6861.0, 459.0], [6882.0, 459.0], [6907.0, 465.0], [6917.0, 465.0], [6934.0, 465.0], [6956.0, 465.0], [6978.0, 465.0], [6996.0, 464.0], [7014.0, 464.0], [7033.0, 464.0], [7043.0, 464.0], [7071.0, 464.0], [7093.0, 464.0], [7112.0, 477.0], [7130.0, 477.0], [7150.0, 477.0], [7162.0, 477.0], [7184.0, 477.0], [7206.0, 477.0], [7217.0, 612.0], [7239.0, 612.0], [7261.0, 612.0], [7277.0, 612.0], [7299.0, 612.0], [7315.0, 676.0], [7337.0, 676.0], [7359.0, 676.0], [7381.0, 676.0], [7397.0, 676.0], [7419.0, 676.0], [7436.0, 690.0], [7452.0, 690.0], [7463.0, 690.0], [7490.0, 690.0], [7507.0, 690.0], [7518.0, 690.0], [7534.0, 847.0], [7546.0, 847.0], [7557.0, 847.0], [7568.0, 847.0], [7578.0, 847.0], [7594.0, 847.0], [7610.0, 847.0], [7629.0, 847.0], [7647.0, 2084.0], [7663.0, 2084.0], [7682.0, 2084.0], [7703.0, 2084.0], [7725.0, 2084.0], [7745.0, 2069.0], [7756.0, 2069.0], [7772.0, 2069.0], [7783.0, 2069.0], [7799.0, 2069.0], [7810.0, 2069.0], [7821.0, 2069.0], [7832.0, 2077.0], [7848.0, 2077.0], [7860.0, 2077.0], [7870.0, 2077.0], [7881.0, 2077.0], [7898.0, 2077.0], [7925.0, 2077.0], [7943.0, 2174.0], [7963.0, 2174.0], [7983.0, 2174.0], [8002.0, 2174.0], [8024.0, 2174.0], [8040.0, 2171.0], [8057.0, 2171.0], [8073.0, 2171.0], [8084.0, 2171.0], [8100.0, 2171.0], [8111.0, 2171.0], [8122.0, 2171.0], [8144.0, 2190.0], [8165.0, 2190.0], [8183.0, 2190.0], [8199.0, 2190.0], [8218.0, 2190.0], [8236.0, 2168.0], [8252.0, 2168.0], [8268.0, 2168.0], [8279.0, 2168.0], [8296.0, 2168.0], [8307.0, 2168.0], [8322.0, 2115.0], [8338.0, 2115.0], [8356.0, 2115.0], [8370.0, 2115.0], [8388.0, 2115.0], [8405.0, 2115.0], [8427.0, 2115.0], [8443.0, 1690.0], [8459.0, 1690.0], [8476.0, 1690.0], [8487.0, 1690.0], [8503.0, 1690.0], [8514.0, 1690.0], [8531.0, 1690.0], [8541.0, 1726.0], [8569.0, 1726.0], [8582.0, 1726.0], [8599.0, 1726.0], [8609.0, 1726.0], [8626.0, 1726.0], [8637.0, 1658.0], [8648.0, 1658.0], [8664.0, 1658.0], [8681.0, 1658.0], [8701.0, 1658.0], [8721.0, 1658.0], [8741.0, 1444.0], [8759.0, 1444.0], [8778.0, 1444.0], [8785.0, 1444.0], [8807.0, 1444.0], [8823.0, 1444.0], [8837.0, 1108.0], [8855.0, 1108.0], [8875.0, 1108.0], [8886.0, 1108.0], [8903.0, 1108.0], [8919.0, 1108.0], [8941.0, 1016.0], [8957.0, 1016.0], [8977.0, 1016.0], [8987.0, 1016.0], [9013.0, 1016.0], [9033.0, 1023.0], [9051.0, 1023.0], [9067.0, 1023.0], [9086.0, 1023.0], [9104.0, 1023.0], [9124.0, 1023.0], [9144.0, 1023.0], [9166.0, 977.0], [9179.0, 977.0], [9199.0, 977.0], [9210.0, 977.0], [9221.0, 977.0], [9239.0, 977.0], [9250.0, 828.0], [9266.0, 828.0], [9277.0, 828.0], [9293.0, 828.0], [9304.0, 828.0], [9315.0, 828.0], [9342.0, 828.0], [9359.0, 802.0], [9375.0, 802.0], [9397.0, 802.0], [9416.0, 802.0], [9432.0, 802.0], [9454.0, 802.0], [9476.0, 807.0], [9498.0, 807.0], [9514.0, 807.0], [9531.0, 807.0], [9547.0, 807.0], [9564.0, 754.0], [9574.0, 754.0], [9591.0, 754.0], [9607.0, 754.0], [9624.0, 754.0], [9646.0, 754.0], [9672.0, 754.0], [9695.0, 661.0], [9723.0, 661.0], [9739.0, 661.0], [9750.0, 661.0], [9766.0, 661.0], [9788.0, 661.0], [9814.0, 631.0], [9834.0, 631.0], [9856.0, 631.0], [9873.0, 631.0], [9895.0, 631.0], [9916.0, 628.0], [9937.0, 628.0], [9957.0, 628.0], [9978.0, 628.0], [9995.0, 628.0], [10017.0, 605.0], [10030.0, 605.0], [10050.0, 605.0], [10070.0, 605.0], [10088.0, 605.0], [10107.0, 605.0], [10117.0, 576.0], [10145.0, 576.0], [10167.0, 576.0], [10191.0, 576.0], [10211.0, 576.0], [10233.0, 554.0], [10255.0, 554.0], [10272.0, 554.0], [10294.0, 554.0], [10316.0, 554.0], [10340.0, 531.0], [10350.0, 531.0], [10367.0, 531.0], [10383.0, 531.0], [10394.0, 531.0], [10422.0, 531.0], [10438.0, 512.0], [10449.0, 512.0], [10471.0, 512.0], [10487.0, 512.0], [10509.0, 512.0], [10520.0, 512.0], [10536.0, 490.0], [10555.0, 490.0], [10573.0, 490.0], [10590.0, 490.0], [10612.0, 490.0], [10628.0, 490.0], [10644.0, 471.0], [10661.0, 471.0], [10683.0, 471.0], [10699.0, 471.0], [10724.0, 471.0], [10735.0, 466.0], [10751.0, 466.0], [10762.0, 466.0], [10789.0, 466.0], [10811.0, 466.0], [10827.0, 466.0], [10844.0, 458.0], [10855.0, 458.0], [10871.0, 458.0], [10888.0, 458.0], [10901.0, 458.0], [10917.0, 458.0], [10934.0, 458.0], [10950.0, 444.0], [10967.0, 444.0], [10977.0, 444.0], [10993.0, 444.0], [11010.0, 444.0], [11032.0, 444.0], [11043.0, 438.0], [11059.0, 438.0], [11076.0, 438.0], [11092.0, 438.0], [11109.0, 438.0], [11125.0, 438.0], [11144.0, 438.0], [11155.0, 438.0], [11171.0, 438.0], [11182.0, 438.0], [11209.0, 438.0], [11231.0, 438.0], [11250.0, 438.0], [11261.0, 431.0], [11277.0, 431.0], [11288.0, 431.0], [11304.0, 431.0], [11315.0, 431.0], [11332.0, 431.0], [11348.0, 431.0], [11370.0, 420.0], [11386.0, 420.0], [11408.0, 420.0], [11433.0, 420.0], [11443.0, 420.0], [11471.0, 418.0], [11496.0, 418.0], [11506.0, 418.0], [11532.0, 418.0], [11552.0, 418.0], [11570.0, 416.0], [11591.0, 416.0], [11605.0, 416.0], [11627.0, 416.0], [11649.0, 416.0], [11666.0, 411.0], [11687.0, 411.0], [11709.0, 411.0], [11735.0, 411.0], [11755.0, 411.0], [11775.0, 408.0], [11786.0, 408.0], [11805.0, 408.0], [11826.0, 408.0], [11848.0, 408.0], [11868.0, 408.0], [11889.0, 401.0], [11906.0, 401.0], [11928.0, 401.0], [11950.0, 401.0], [11976.0, 401.0], [11996.0, 400.0], [12018.0, 400.0], [12040.0, 400.0], [12062.0, 400.0], [12081.0, 400.0], [12102.0, 395.0], [12124.0, 395.0], [12141.0, 395.0], [12163.0, 395.0], [12188.0, 395.0], [12198.0, 389.0], [12224.0, 389.0], [12245.0, 389.0], [12267.0, 389.0], [12283.0, 389.0], [12305.0, 386.0], [12322.0, 386.0], [12337.0, 386.0], [12359.0, 386.0], [12381.0, 386.0], [12405.0, 385.0], [12425.0, 385.0], [12447.0, 385.0], [12464.0, 385.0], [12475.0, 385.0], [12502.0, 387.0], [12528.0, 387.0], [12547.0, 387.0], [12563.0, 387.0], [12584.0, 387.0], [12601.0, 387.0], [12623.0, 390.0], [12636.0, 390.0], [12654.0, 390.0], [12673.0, 390.0], [12683.0, 390.0], [12707.0, 390.0], [12718.0, 391.0], [12735.0, 391.0], [12751.0, 391.0], [12773.0, 391.0], [12795.0, 391.0], [12817.0, 391.0], [12835.0, 390.0], [12856.0, 390.0], [12878.0, 390.0], [12895.0, 390.0], [12911.0, 390.0], [12927.0, 403.0], [12954.0, 403.0], [12974.0, 403.0], [12994.0, 403.0], [13016.0, 403.0], [13038.0, 403.0], [13064.0, 407.0], [13084.0, 407.0], [13105.0, 407.0], [13122.0, 407.0], [13144.0, 407.0], [13155.0, 409.0], [13171.0, 409.0], [13187.0, 409.0], [13204.0, 409.0], [13215.0, 409.0], [13231.0, 409.0], [13242.0, 409.0], [13258.0, 412.0], [13275.0, 412.0], [13291.0, 412.0], [13313.0, 412.0], [13326.0, 412.0], [13344.0, 412.0], [13363.0, 428.0], [13373.0, 428.0], [13399.0, 428.0], [13410.0, 428.0], [13431.0, 428.0], [13453.0, 428.0], [13475.0, 432.0], [13497.0, 432.0], [13515.0, 432.0], [13537.0, 432.0], [13554.0, 432.0], [13576.0, 432.0], [13592.0, 432.0], [13608.0, 432.0], [13625.0, 432.0], [13636.0, 432.0], [13652.0, 432.0], [13663.0, 434.0], [13679.0, 434.0], [13696.0, 434.0], [13712.0, 434.0], [13734.0, 434.0], [13750.0, 434.0], [13778.0, 456.0], [13794.0, 456.0], [13820.0, 456.0], [13840.0, 456.0], [13862.0, 456.0], [13878.0, 484.0], [13900.0, 484.0], [13913.0, 484.0], [13933.0, 484.0], [13951.0, 484.0], [13972.0, 484.0], [13984.0, 484.0], [14004.0, 484.0], [14024.0, 484.0], [14035.0, 484.0], [14052.0, 484.0], [14068.0, 484.0], [14090.0, 493.0], [14106.0, 493.0], [14123.0, 493.0], [14139.0, 493.0], [14156.0, 493.0], [14172.0, 493.0], [14183.0, 515.0], [14206.0, 515.0], [14216.0, 515.0], [14233.0, 515.0], [14249.0, 515.0], [14271.0, 515.0], [14284.0, 518.0], [14302.0, 518.0], [14318.0, 518.0], [14340.0, 518.0], [14356.0, 518.0], [14373.0, 518.0], [14387.0, 521.0], [14403.0, 521.0], [14421.0, 521.0], [14442.0, 521.0], [14456.0, 521.0], [14477.0, 521.0], [14499.0, 522.0], [14516.0, 522.0], [14538.0, 522.0], [14554.0, 522.0], [14577.0, 522.0], [14594.0, 506.0], [14612.0, 506.0], [14633.0, 506.0], [14655.0, 506.0], [14680.0, 506.0], [14700.0, 472.0], [14722.0, 472.0], [14744.0, 472.0], [14769.0, 472.0], [14779.0, 472.0], [14796.0, 473.0], [14818.0, 473.0], [14838.0, 473.0], [14858.0, 473.0], [14878.0, 473.0], [14896.0, 458.0], [14915.0, 458.0], [14925.0, 458.0], [14951.0, 458.0], [14971.0, 458.0], [14989.0, 458.0], [15005.0, 422.0], [15016.0, 422.0], [15042.0, 422.0], [15064.0, 422.0], [15077.0, 422.0], [15095.0, 422.0], [15114.0, 414.0], [15124.0, 414.0], [15148.0, 414.0], [15169.0, 414.0], [15181.0, 414.0], [15197.0, 414.0], [15216.0, 414.0], [15233.0, 414.0], [15243.0, 414.0], [15260.0, 414.0], [15276.0, 414.0], [15293.0, 414.0], [15319.0, 404.0], [15341.0, 404.0], [15363.0, 404.0], [15380.0, 404.0], [15402.0, 404.0], [15422.0, 391.0], [15438.0, 391.0], [15449.0, 391.0], [15471.0, 391.0], [15490.0, 391.0], [15507.0, 391.0], [15523.0, 390.0], [15539.0, 390.0], [15556.0, 390.0], [15574.0, 390.0], [15590.0, 390.0], [15612.0, 390.0], [15639.0, 387.0], [15650.0, 387.0], [15666.0, 387.0], [15683.0, 387.0], [15699.0, 387.0], [15721.0, 387.0], [15741.0, 383.0], [15759.0, 383.0], [15775.0, 383.0], [15786.0, 383.0], [15796.0, 383.0], [15818.0, 383.0], [15834.0, 383.0], [15845.0, 374.0], [15862.0, 374.0], [15878.0, 374.0], [15891.0, 374.0], [15907.0, 374.0], [15918.0, 374.0], [15940.0, 374.0], [15959.0, 369.0], [15977.0, 369.0], [15993.0, 369.0], [16015.0, 369.0], [16031.0, 369.0], [16053.0, 369.0], [16069.0, 371.0], [16093.0, 371.0], [16115.0, 371.0], [16132.0, 371.0], [16143.0, 371.0], [16159.0, 366.0], [16170.0, 366.0], [16186.0, 366.0], [16203.0, 366.0], [16219.0, 366.0], [16241.0, 366.0], [16254.0, 366.0], [16272.0, 359.0], [16291.0, 359.0], [16301.0, 359.0], [16325.0, 359.0], [16341.0, 359.0], [16358.0, 359.0], [16374.0, 359.0], [16393.0, 361.0], [16414.0, 361.0], [16431.0, 361.0], [16454.0, 361.0], [16470.0, 361.0], [16486.0, 361.0], [16497.0, 361.0], [16514.0, 361.0], [16530.0, 361.0], [16552.0, 361.0], [16574.0, 361.0], [16599.0, 357.0], [16619.0, 357.0], [16636.0, 357.0], [16647.0, 357.0], [16663.0, 357.0], [16674.0, 357.0], [16685.0, 362.0], [16696.0, 362.0], [16703.0, 362.0], [16725.0, 362.0], [16747.0, 362.0], [16763.0, 362.0], [16781.0, 362.0], [16802.0, 364.0], [16824.0, 364.0], [16850.0, 364.0], [16870.0, 364.0], [16892.0, 364.0], [16905.0, 365.0], [16923.0, 365.0], [16939.0, 365.0], [16950.0, 365.0], [16966.0, 365.0], [16983.0, 365.0], [16994.0, 365.0], [17010.0, 369.0], [17026.0, 369.0], [17043.0, 369.0], [17059.0, 369.0], [17069.0, 369.0], [17077.0, 369.0], [17093.0, 369.0], [17115.0, 372.0], [17132.0, 372.0], [17154.0, 372.0], [17176.0, 372.0], [17202.0, 372.0], [17222.0, 376.0], [17243.0, 376.0], [17267.0, 376.0], [17278.0, 376.0], [17306.0, 376.0], [17328.0, 378.0], [17352.0, 378.0], [17371.0, 378.0], [17382.0, 378.0], [17399.0, 378.0], [17415.0, 378.0], [17428.0, 385.0], [17444.0, 385.0], [17463.0, 385.0], [17481.0, 385.0], [17491.0, 385.0], [17499.0, 385.0], [17510.0, 385.0], [17533.0, 395.0], [17548.0, 395.0], [17570.0, 395.0], [17586.0, 395.0], [17597.0, 395.0], [17613.0, 395.0], [17630.0, 395.0], [17643.0, 398.0], [17659.0, 398.0], [17670.0, 398.0], [17692.0, 398.0], [17709.0, 398.0], [17728.0, 398.0], [17750.0, 405.0], [17772.0, 405.0], [17798.0, 405.0], [17817.0, 405.0], [17827.0, 405.0], [17844.0, 420.0], [17853.0, 420.0], [17870.0, 420.0], [17880.0, 420.0], [17897.0, 420.0], [17908.0, 420.0], [17924.0, 420.0], [17941.0, 433.0], [17957.0, 433.0], [17973.0, 433.0], [17990.0, 433.0], [18013.0, 433.0]]
x1 = 5
y1 = 3
start = 40
end = 999
theta = 0.69*np.pi

data = np.array(sensor_data)
time = data[start:end, 0]
tof1 = data[start:end, 1]

data53 = robot2global(tof1, x1, y1, theta)

# %%
sensor_data = [[13.0, 2207.0], [35.0, 2207.0], [54.0, 2207.0], [72.0, 2207.0], [88.0, 2207.0], [104.0, 2207.0], [121.0, 2241.0], [139.0, 2241.0], [150.0, 2241.0], [167.0, 2241.0], [183.0, 2241.0], [194.0, 2241.0], [216.0, 2241.0], [227.0, 2262.0], [243.0, 2262.0], [260.0, 2262.0], [276.0, 2262.0], [292.0, 2262.0], [314.0, 2262.0], [331.0, 2270.0], [342.0, 2270.0], [367.0, 2270.0], [389.0, 2270.0], [411.0, 2270.0], [433.0, 2236.0], [452.0, 2236.0], [474.0, 2236.0], [491.0, 2236.0], [513.0, 2236.0], [535.0, 2295.0], [555.0, 2295.0], [567.0, 2295.0], [577.0, 2295.0], [594.0, 2295.0], [610.0, 2295.0], [627.0, 2269.0], [643.0, 2269.0], [659.0, 2269.0], [681.0, 2269.0], [698.0, 2269.0], [710.0, 2269.0], [730.0, 2275.0], [741.0, 2275.0], [758.0, 2275.0], [771.0, 2275.0], [787.0, 2275.0], [809.0, 2275.0], [821.0, 2229.0], [840.0, 2229.0], [861.0, 2229.0], [882.0, 2229.0], [899.0, 2229.0], [921.0, 2229.0], [943.0, 2224.0], [959.0, 2224.0], [976.0, 2224.0], [997.0, 2224.0], [1016.0, 2224.0], [1026.0, 988.0], [1043.0, 988.0], [1059.0, 988.0], [1074.0, 988.0], [1090.0, 988.0], [1107.0, 988.0], [1123.0, 988.0], [1139.0, 739.0], [1156.0, 739.0], [1172.0, 739.0], [1183.0, 739.0], [1200.0, 739.0], [1216.0, 739.0], [1232.0, 731.0], [1243.0, 731.0], [1260.0, 731.0], [1282.0, 731.0], [1307.0, 731.0], [1324.0, 731.0], [1344.0, 723.0], [1366.0, 723.0], [1383.0, 723.0], [1399.0, 723.0], [1421.0, 723.0], [1437.0, 710.0], [1459.0, 710.0], [1468.0, 710.0], [1481.0, 710.0], [1503.0, 710.0], [1524.0, 710.0], [1546.0, 720.0], [1557.0, 720.0], [1568.0, 720.0], [1584.0, 720.0], [1601.0, 720.0], [1617.0, 720.0], [1634.0, 721.0], [1650.0, 721.0], [1666.0, 721.0], [1680.0, 721.0], [1700.0, 721.0], [1717.0, 721.0], [1739.0, 721.0], [1755.0, 724.0], [1773.0, 724.0], [1794.0, 724.0], [1810.0, 724.0], [1827.0, 724.0], [1849.0, 724.0], [1871.0, 749.0], [1893.0, 749.0], [1909.0, 749.0], [1926.0, 749.0], [1948.0, 749.0], [1959.0, 779.0], [1981.0, 779.0], [1993.0, 779.0], [2013.0, 779.0], [2029.0, 779.0], [2041.0, 779.0], [2057.0, 779.0], [2079.0, 792.0], [2090.0, 792.0], [2112.0, 792.0], [2134.0, 792.0], [2150.0, 792.0], [2172.0, 792.0], [2197.0, 804.0], [2214.0, 804.0], [2236.0, 804.0], [2258.0, 804.0], [2274.0, 804.0], [2283.0, 837.0], [2294.0, 837.0], [2316.0, 837.0], [2333.0, 837.0], [2353.0, 837.0], [2369.0, 837.0], [2381.0, 869.0], [2397.0, 869.0], [2419.0, 869.0], [2435.0, 869.0], [2452.0, 869.0], [2468.0, 869.0], [2485.0, 869.0], [2506.0, 869.0], [2523.0, 869.0], [2537.0, 869.0], [2554.0, 869.0], [2570.0, 869.0], [2592.0, 880.0], [2610.0, 880.0], [2620.0, 880.0], [2637.0, 880.0], [2653.0, 880.0], [2670.0, 880.0], [2692.0, 910.0], [2708.0, 910.0], [2718.0, 910.0], [2735.0, 910.0], [2751.0, 910.0], [2763.0, 910.0], [2779.0, 953.0], [2796.0, 953.0], [2812.0, 953.0], [2828.0, 953.0], [2840.0, 953.0], [2850.0, 953.0], [2872.0, 953.0], [2897.0, 962.0], [2914.0, 962.0], [2940.0, 962.0], [2957.0, 962.0], [2973.0, 962.0], [2990.0, 975.0], [3006.0, 975.0], [3022.0, 975.0], [3039.0, 975.0], [3055.0, 975.0], [3072.0, 975.0], [3083.0, 1039.0], [3096.0, 1039.0], [3112.0, 1039.0], [3129.0, 1039.0], [3139.0, 1039.0], [3150.0, 1039.0], [3166.0, 1039.0], [3174.0, 1908.0], [3190.0, 1908.0], [3206.0, 1908.0], [3223.0, 1908.0], [3245.0, 1908.0], [3262.0, 1908.0], [3279.0, 2705.0], [3295.0, 2705.0], [3311.0, 2705.0], [3328.0, 2705.0], [3354.0, 2705.0], [3371.0, 2705.0], [3387.0, 2647.0], [3404.0, 2647.0], [3415.0, 2647.0], [3436.0, 2647.0], [3458.0, 2647.0], [3475.0, 2647.0], [3497.0, 2669.0], [3518.0, 2669.0], [3540.0, 2669.0], [3551.0, 2669.0], [3572.0, 2669.0], [3583.0, 2776.0], [3594.0, 2776.0], [3605.0, 2776.0], [3622.0, 2776.0], [3638.0, 2776.0], [3650.0, 2776.0], [3667.0, 2776.0], [3687.0, 2799.0], [3708.0, 2799.0], [3725.0, 2799.0], [3747.0, 2799.0], [3758.0, 2799.0], [3774.0, 2861.0], [3790.0, 2861.0], [3801.0, 2861.0], [3823.0, 2861.0], [3845.0, 2861.0], [3861.0, 2861.0], [3880.0, 2861.0], [3897.0, 3057.0], [3905.0, 3057.0], [3913.0, 3057.0], [3929.0, 3057.0], [3951.0, 3057.0], [3976.0, 3057.0], [3995.0, 3168.0], [4013.0, 3168.0], [4029.0, 3168.0], [4041.0, 3168.0], [4057.0, 3168.0], [4074.0, 3168.0], [4090.0, 3148.0], [4101.0, 3148.0], [4123.0, 3148.0], [4139.0, 3148.0], [4154.0, 3148.0], [4171.0, 3148.0], [4187.0, 3178.0], [4210.0, 3178.0], [4226.0, 3178.0], [4248.0, 3178.0], [4264.0, 3178.0], [4296.0, 3193.0], [4322.0, 3193.0], [4339.0, 3193.0], [4355.0, 3193.0], [4372.0, 3193.0], [4383.0, 2430.0], [4400.0, 2430.0], [4418.0, 2430.0], [4435.0, 2430.0], [4453.0, 2430.0], [4469.0, 2430.0], [4486.0, 1496.0], [4502.0, 1496.0], [4520.0, 1496.0], [4536.0, 1496.0], [4548.0, 1496.0], [4559.0, 1496.0], [4581.0, 1496.0], [4597.0, 1493.0], [4611.0, 1493.0], [4628.0, 1493.0], [4641.0, 1493.0], [4662.0, 1493.0], [4670.0, 1493.0], [4686.0, 1493.0], [4702.0, 1371.0], [4719.0, 1371.0], [4730.0, 1371.0], [4746.0, 1371.0], [4768.0, 1371.0], [4779.0, 1371.0], [4790.0, 1358.0], [4812.0, 1358.0], [4836.0, 1358.0], [4847.0, 1358.0], [4864.0, 1358.0], [4888.0, 1358.0], [4904.0, 1353.0], [4916.0, 1353.0], [4932.0, 1353.0], [4949.0, 1353.0], [4964.0, 1353.0], [4981.0, 1353.0], [4997.0, 1353.0], [5008.0, 1346.0], [5019.0, 1346.0], [5035.0, 1346.0], [5052.0, 1346.0], [5069.0, 1346.0], [5079.0, 1346.0], [5091.0, 1346.0], [5108.0, 1343.0], [5130.0, 1343.0], [5152.0, 1343.0], [5169.0, 1343.0], [5189.0, 1343.0], [5211.0, 1340.0], [5228.0, 1340.0], [5239.0, 1340.0], [5255.0, 1340.0], [5271.0, 1340.0], [5288.0, 1340.0], [5310.0, 1339.0], [5327.0, 1339.0], [5347.0, 1339.0], [5369.0, 1339.0], [5386.0, 1339.0], [5404.0, 1342.0], [5422.0, 1342.0], [5444.0, 1342.0], [5461.0, 1342.0], [5474.0, 1342.0], [5483.0, 1342.0], [5499.0, 1350.0], [5521.0, 1350.0], [5543.0, 1350.0], [5554.0, 1350.0], [5576.0, 1350.0], [5583.0, 1319.0], [5599.0, 1319.0], [5615.0, 1319.0], [5640.0, 1319.0], [5651.0, 1319.0], [5668.0, 1319.0], [5684.0, 1319.0], [5706.0, 1295.0], [5728.0, 1295.0], [5750.0, 1295.0], [5766.0, 1295.0], [5788.0, 1295.0], [5812.0, 1299.0], [5828.0, 1299.0], [5840.0, 1299.0], [5856.0, 1299.0], [5873.0, 1299.0], [5880.0, 1299.0], [5889.0, 1299.0], [5905.0, 1165.0], [5927.0, 1165.0], [5939.0, 1165.0], [5949.0, 1165.0], [5971.0, 1165.0], [5989.0, 1165.0], [6009.0, 913.0], [6025.0, 913.0], [6037.0, 913.0], [6064.0, 913.0], [6075.0, 913.0], [6095.0, 913.0], [6117.0, 911.0], [6131.0, 911.0], [6151.0, 911.0], [6168.0, 911.0], [6190.0, 911.0], [6213.0, 920.0], [6234.0, 920.0], [6255.0, 920.0], [6272.0, 920.0], [6294.0, 920.0], [6305.0, 762.0], [6325.0, 762.0], [6336.0, 762.0], [6353.0, 762.0], [6374.0, 762.0], [6394.0, 762.0], [6412.0, 635.0], [6428.0, 635.0], [6445.0, 635.0], [6464.0, 635.0], [6481.0, 635.0], [6498.0, 635.0], [6514.0, 631.0], [6531.0, 631.0], [6541.0, 631.0], [6563.0, 631.0], [6585.0, 631.0], [6596.0, 631.0], [6612.0, 632.0], [6629.0, 632.0], [6645.0, 632.0], [6662.0, 632.0], [6678.0, 632.0], [6694.0, 632.0], [6712.0, 564.0], [6734.0, 564.0], [6751.0, 564.0], [6764.0, 564.0], [6781.0, 564.0], [6803.0, 564.0], [6825.0, 523.0], [6842.0, 523.0], [6863.0, 523.0], [6888.0, 523.0], [6908.0, 523.0], [6925.0, 525.0], [6944.0, 525.0], [6961.0, 525.0], [6983.0, 525.0], [6999.0, 525.0], [7015.0, 525.0], [7037.0, 522.0], [7061.0, 522.0], [7081.0, 522.0], [7098.0, 522.0], [7114.0, 522.0], [7131.0, 481.0], [7156.0, 481.0], [7167.0, 481.0], [7185.0, 481.0], [7194.0, 481.0], [7210.0, 481.0], [7234.0, 439.0], [7250.0, 439.0], [7272.0, 439.0], [7294.0, 439.0], [7316.0, 439.0], [7328.0, 434.0], [7338.0, 434.0], [7360.0, 434.0], [7382.0, 434.0], [7393.0, 434.0], [7409.0, 434.0], [7426.0, 434.0], [7449.0, 433.0], [7467.0, 433.0], [7493.0, 433.0], [7510.0, 433.0], [7532.0, 433.0], [7554.0, 409.0], [7570.0, 409.0], [7592.0, 409.0], [7601.0, 409.0], [7626.0, 409.0], [7646.0, 409.0], [7668.0, 378.0], [7685.0, 378.0], [7697.0, 378.0], [7717.0, 378.0], [7737.0, 378.0], [7748.0, 378.0], [7759.0, 375.0], [7770.0, 375.0], [7792.0, 375.0], [7814.0, 375.0], [7832.0, 375.0], [7853.0, 375.0], [7869.0, 375.0], [7886.0, 375.0], [7903.0, 375.0], [7914.0, 375.0], [7930.0, 375.0], [7946.0, 375.0], [7957.0, 375.0], [7972.0, 362.0], [7990.0, 362.0], [8006.0, 362.0], [8023.0, 362.0], [8041.0, 362.0], [8052.0, 362.0], [8069.0, 348.0], [8085.0, 348.0], [8102.0, 348.0], [8118.0, 348.0], [8140.0, 348.0], [8158.0, 348.0], [8178.0, 345.0], [8189.0, 345.0], [8211.0, 345.0], [8228.0, 345.0], [8248.0, 345.0], [8268.0, 345.0], [8279.0, 344.0], [8296.0, 344.0], [8320.0, 344.0], [8331.0, 344.0], [8348.0, 344.0], [8371.0, 344.0], [8389.0, 333.0], [8409.0, 333.0], [8426.0, 333.0], [8442.0, 333.0], [8464.0, 333.0], [8486.0, 333.0], [8504.0, 328.0], [8523.0, 328.0], [8540.0, 328.0], [8562.0, 328.0], [8575.0, 328.0], [8595.0, 328.0], [8612.0, 325.0], [8634.0, 325.0], [8656.0, 325.0], [8673.0, 325.0], [8699.0, 325.0], [8726.0, 324.0], [8744.0, 324.0], [8766.0, 324.0], [8778.0, 324.0], [8788.0, 324.0], [8810.0, 324.0], [8832.0, 319.0], [8843.0, 319.0], [8869.0, 319.0], [8881.0, 319.0], [8888.0, 319.0], [8904.0, 319.0], [8926.0, 319.0], [8943.0, 313.0], [8959.0, 313.0], [8979.0, 313.0], [8999.0, 313.0], [9021.0, 313.0], [9033.0, 317.0], [9053.0, 317.0], [9069.0, 317.0], [9081.0, 317.0], [9097.0, 317.0], [9123.0, 317.0], [9134.0, 317.0], [9145.0, 317.0], [9167.0, 317.0], [9184.0, 317.0], [9198.0, 317.0], [9215.0, 317.0], [9231.0, 317.0], [9248.0, 318.0], [9269.0, 318.0], [9281.0, 318.0], [9303.0, 318.0], [9326.0, 318.0], [9342.0, 322.0], [9364.0, 322.0], [9381.0, 322.0], [9397.0, 322.0], [9423.0, 322.0], [9440.0, 322.0], [9462.0, 322.0], [9478.0, 322.0], [9494.0, 322.0], [9513.0, 322.0], [9534.0, 322.0], [9553.0, 323.0], [9573.0, 323.0], [9584.0, 323.0], [9595.0, 323.0], [9606.0, 323.0], [9628.0, 323.0], [9644.0, 323.0], [9663.0, 323.0], [9680.0, 323.0], [9691.0, 323.0], [9702.0, 323.0], [9718.0, 323.0], [9740.0, 323.0], [9756.0, 324.0], [9778.0, 324.0], [9795.0, 324.0], [9811.0, 324.0], [9827.0, 324.0], [9844.0, 324.0], [9860.0, 329.0], [9877.0, 329.0], [9895.0, 329.0], [9916.0, 329.0], [9933.0, 329.0], [9955.0, 329.0], [9977.0, 327.0], [9998.0, 327.0], [10015.0, 327.0], [10026.0, 327.0], [10042.0, 327.0], [10059.0, 327.0], [10069.0, 333.0], [10091.0, 333.0], [10108.0, 333.0], [10123.0, 333.0], [10140.0, 333.0], [10150.0, 333.0], [10166.0, 333.0], [10188.0, 340.0], [10205.0, 340.0], [10224.0, 340.0], [10244.0, 340.0], [10263.0, 340.0], [10280.0, 343.0], [10290.0, 343.0], [10307.0, 343.0], [10323.0, 343.0], [10340.0, 343.0], [10356.0, 343.0], [10372.0, 343.0], [10389.0, 345.0], [10400.0, 345.0], [10423.0, 345.0], [10439.0, 345.0], [10446.0, 345.0], [10455.0, 345.0], [10463.0, 345.0], [10479.0, 345.0], [10505.0, 357.0], [10522.0, 357.0], [10538.0, 357.0], [10555.0, 357.0], [10566.0, 357.0], [10576.0, 357.0], [10587.0, 366.0], [10609.0, 366.0], [10626.0, 366.0], [10642.0, 366.0], [10658.0, 366.0], [10675.0, 366.0], [10691.0, 365.0], [10708.0, 365.0], [10724.0, 365.0], [10744.0, 365.0], [10755.0, 365.0], [10772.0, 365.0], [10796.0, 368.0], [10814.0, 368.0], [10830.0, 368.0], [10842.0, 368.0], [10858.0, 368.0], [10875.0, 368.0], [10891.0, 390.0], [10914.0, 390.0], [10937.0, 390.0], [10958.0, 390.0], [10984.0, 390.0], [11001.0, 399.0], [11017.0, 399.0], [11042.0, 399.0], [11059.0, 399.0], [11070.0, 399.0], [11085.0, 399.0], [11107.0, 399.0], [11128.0, 399.0], [11145.0, 399.0], [11162.0, 399.0], [11183.0, 399.0], [11200.0, 406.0], [11211.0, 406.0], [11233.0, 406.0], [11251.0, 406.0], [11271.0, 406.0], [11282.0, 406.0], [11302.0, 440.0], [11324.0, 440.0], [11345.0, 440.0], [11367.0, 440.0], [11384.0, 440.0], [11402.0, 454.0], [11413.0, 454.0], [11430.0, 454.0], [11446.0, 454.0], [11468.0, 454.0], [11490.0, 454.0], [11506.0, 453.0], [11523.0, 453.0], [11545.0, 453.0], [11561.0, 453.0], [11581.0, 453.0], [11601.0, 453.0], [11612.0, 468.0], [11623.0, 468.0], [11633.0, 468.0], [11641.0, 468.0], [11657.0, 468.0], [11673.0, 468.0], [11690.0, 468.0], [11701.0, 468.0], [11718.0, 503.0], [11734.0, 503.0], [11745.0, 503.0], [11766.0, 503.0], [11787.0, 503.0], [11804.0, 503.0], [11826.0, 505.0], [11842.0, 505.0], [11859.0, 505.0], [11876.0, 505.0], [11898.0, 505.0], [11909.0, 505.0], [11925.0, 503.0], [11941.0, 503.0], [11958.0, 503.0], [11974.0, 503.0], [11996.0, 503.0], [12015.0, 503.0], [12035.0, 504.0], [12056.0, 504.0], [12079.0, 504.0], [12087.0, 504.0], [12109.0, 504.0], [12130.0, 504.0], [12152.0, 480.0], [12163.0, 480.0], [12182.0, 480.0], [12203.0, 480.0], [12223.0, 480.0], [12243.0, 480.0], [12264.0, 471.0], [12283.0, 471.0], [12303.0, 471.0], [12314.0, 471.0], [12336.0, 471.0], [12353.0, 470.0], [12370.0, 470.0], [12388.0, 470.0], [12404.0, 470.0], [12426.0, 470.0], [12448.0, 470.0], [12471.0, 451.0], [12491.0, 451.0], [12509.0, 451.0], [12525.0, 451.0], [12537.0, 451.0], [12553.0, 451.0], [12575.0, 430.0], [12583.0, 430.0], [12594.0, 430.0], [12605.0, 430.0], [12627.0, 430.0], [12644.0, 430.0], [12665.0, 430.0], [12684.0, 415.0], [12704.0, 415.0], [12715.0, 415.0], [12732.0, 415.0], [12748.0, 415.0], [12770.0, 415.0], [12788.0, 414.0], [12804.0, 414.0], [12816.0, 414.0], [12827.0, 414.0], [12849.0, 414.0], [12865.0, 414.0], [12881.0, 399.0], [12900.0, 399.0], [12925.0, 399.0], [12942.0, 399.0], [12958.0, 399.0], [12975.0, 399.0], [12991.0, 394.0], [13002.0, 394.0], [13019.0, 394.0], [13041.0, 394.0], [13063.0, 394.0], [13075.0, 394.0], [13092.0, 389.0], [13108.0, 389.0], [13125.0, 389.0], [13141.0, 389.0], [13163.0, 389.0], [13189.0, 389.0], [13211.0, 388.0], [13233.0, 388.0], [13250.0, 388.0], [13272.0, 388.0], [13282.0, 388.0], [13304.0, 388.0], [13326.0, 379.0], [13343.0, 379.0], [13360.0, 379.0], [13376.0, 379.0], [13398.0, 379.0], [13420.0, 372.0], [13436.0, 372.0], [13458.0, 372.0], [13482.0, 372.0], [13502.0, 372.0], [13519.0, 372.0], [13541.0, 372.0], [13566.0, 372.0], [13586.0, 372.0], [13608.0, 372.0], [13620.0, 370.0], [13640.0, 370.0], [13656.0, 370.0], [13673.0, 370.0], [13690.0, 370.0], [13708.0, 370.0], [13725.0, 368.0], [13748.0, 368.0], [13760.0, 368.0], [13768.0, 368.0], [13784.0, 368.0], [13800.0, 368.0], [13817.0, 368.0], [13842.0, 371.0], [13859.0, 371.0], [13881.0, 371.0], [13903.0, 371.0], [13919.0, 371.0], [13937.0, 371.0], [13959.0, 371.0], [13971.0, 371.0], [13981.0, 371.0], [14003.0, 371.0], [14028.0, 371.0], [14050.0, 372.0], [14072.0, 372.0], [14080.0, 372.0], [14097.0, 372.0], [14105.0, 372.0], [14126.0, 372.0], [14148.0, 378.0], [14170.0, 378.0], [14188.0, 378.0], [14209.0, 378.0], [14225.0, 378.0], [14242.0, 380.0], [14259.0, 380.0], [14270.0, 380.0], [14286.0, 380.0], [14302.0, 380.0], [14319.0, 380.0], [14335.0, 380.0], [14357.0, 381.0], [14373.0, 381.0], [14395.0, 381.0], [14412.0, 381.0], [14432.0, 381.0], [14454.0, 382.0], [14471.0, 382.0], [14487.0, 382.0], [14507.0, 382.0], [14523.0, 382.0], [14535.0, 382.0], [14559.0, 393.0], [14570.0, 393.0], [14581.0, 393.0], [14592.0, 393.0], [14614.0, 393.0], [14630.0, 393.0], [14649.0, 399.0], [14666.0, 399.0], [14676.0, 399.0], [14698.0, 399.0], [14726.0, 399.0], [14747.0, 401.0], [14773.0, 401.0], [14793.0, 401.0], [14815.0, 401.0], [14827.0, 401.0], [14847.0, 404.0], [14863.0, 404.0], [14875.0, 404.0], [14891.0, 404.0], [14917.0, 404.0], [14928.0, 404.0], [14939.0, 419.0], [14950.0, 419.0], [14961.0, 419.0], [14974.0, 419.0], [14991.0, 419.0], [15007.0, 419.0], [15023.0, 419.0], [15049.0, 441.0], [15066.0, 441.0], [15082.0, 441.0], [15099.0, 441.0], [15118.0, 441.0], [15135.0, 441.0], [15145.0, 441.0], [15167.0, 441.0], [15184.0, 441.0], [15200.0, 441.0], [15216.0, 441.0], [15243.0, 441.0], [15255.0, 450.0], [15271.0, 450.0], [15288.0, 450.0], [15297.0, 450.0], [15313.0, 450.0], [15324.0, 450.0], [15341.0, 450.0], [15357.0, 477.0], [15379.0, 477.0], [15401.0, 477.0], [15417.0, 477.0], [15434.0, 477.0], [15456.0, 477.0], [15472.0, 486.0], [15494.0, 486.0], [15519.0, 486.0], [15539.0, 486.0], [15561.0, 486.0], [15573.0, 487.0], [15593.0, 487.0], [15604.0, 487.0], [15621.0, 487.0], [15637.0, 487.0], [15659.0, 487.0], [15681.0, 500.0], [15697.0, 500.0], [15714.0, 500.0], [15736.0, 500.0], [15752.0, 500.0], [15768.0, 500.0], [15785.0, 532.0], [15797.0, 532.0], [15811.0, 532.0], [15827.0, 532.0], [15846.0, 532.0], [15863.0, 532.0], [15879.0, 532.0], [15896.0, 571.0], [15917.0, 571.0], [15934.0, 571.0], [15948.0, 571.0], [15968.0, 571.0], [15985.0, 571.0], [16007.0, 570.0], [16029.0, 570.0], [16045.0, 570.0], [16063.0, 570.0], [16074.0, 570.0], [16096.0, 570.0], [16113.0, 592.0], [16140.0, 592.0], [16166.0, 592.0], [16183.0, 592.0], [16205.0, 592.0], [16227.0, 632.0], [16244.0, 632.0], [16256.0, 632.0], [16266.0, 632.0], [16288.0, 632.0], [16314.0, 632.0], [16331.0, 678.0], [16341.0, 678.0], [16358.0, 678.0], [16380.0, 678.0], [16402.0, 678.0], [16424.0, 683.0], [16441.0, 683.0], [16467.0, 683.0], [16484.0, 683.0], [16506.0, 683.0], [16528.0, 683.0], [16544.0, 735.0], [16566.0, 735.0], [16583.0, 735.0], [16599.0, 735.0], [16614.0, 735.0], [16631.0, 735.0], [16648.0, 813.0], [16670.0, 813.0], [16693.0, 813.0], [16703.0, 813.0], [16725.0, 813.0], [16747.0, 858.0], [16758.0, 858.0], [16774.0, 858.0], [16802.0, 858.0], [16824.0, 858.0], [16835.0, 868.0], [16852.0, 868.0], [16863.0, 868.0], [16879.0, 868.0], [16895.0, 868.0], [16908.0, 868.0], [16927.0, 868.0], [16948.0, 927.0], [16973.0, 927.0], [16984.0, 927.0], [16995.0, 927.0], [17017.0, 927.0], [17034.0, 927.0], [17055.0, 1018.0], [17073.0, 1018.0], [17085.0, 1018.0], [17095.0, 1018.0], [17117.0, 1018.0], [17134.0, 1018.0], [17154.0, 1176.0], [17176.0, 1176.0], [17193.0, 1176.0], [17204.0, 1176.0], [17215.0, 1176.0], [17236.0, 1176.0], [17253.0, 1208.0], [17275.0, 1208.0], [17292.0, 1208.0], [17312.0, 1208.0], [17334.0, 1208.0], [17351.0, 1593.0], [17364.0, 1593.0], [17381.0, 1593.0], [17400.0, 1593.0], [17411.0, 1593.0], [17428.0, 1593.0], [17444.0, 2192.0], [17461.0, 2192.0], [17472.0, 2192.0], [17491.0, 2192.0], [17501.0, 2192.0], [17518.0, 2192.0], [17534.0, 2192.0], [17551.0, 2192.0], [17562.0, 2192.0], [17585.0, 2192.0], [17601.0, 2192.0], [17618.0, 2192.0], [17638.0, 2192.0], [17654.0, 2192.0], [17671.0, 2192.0], [17693.0, 2192.0], [17717.0, 2192.0], [17737.0, 2192.0], [17754.0, 2192.0], [17762.0, 2192.0], [17789.0, 2192.0], [17811.0, 2192.0], [17833.0, 2192.0], [17849.0, 2192.0], [17871.0, 2192.0], [17889.0, 2192.0], [17910.0, 2192.0], [17926.0, 2192.0], [17943.0, 2192.0], [17960.0, 2192.0], [17971.0, 2192.0], [17987.0, 2192.0], [18009.0, 2192.0]]
x1 = 5
y1 = -3
start = 40
end = 1030
theta = 0.47*np.pi

data = np.array(sensor_data)
time = data[start:end, 0]
tof1 = data[start:end, 1]

data5_3 = robot2global(tof1, x1, y1, theta)

# %%
import matplotlib.pyplot as plt

plt.figure()
# plt.scatter(data5_3[:, 0], data5_3[:, 1], s=1, c='blue', label='[5, -3]')  # s is size
# plt.scatter(data53[:, 0], data53[:, 1], s=1, c='red', label='[5, 3]')  # s is size
# plt.scatter(data_3_2[:, 0], data_3_2[:, 1], s=1, c='pink', label='[-3, -2]')  # s is size
# plt.scatter(data0_3[:, 0], data0_3[:, 1], s=1, c='green', label='[0, 3]')  # s is size
# plt.scatter(data00[:, 0], data00[:, 1], s=1, c='orange', label='[0, 0]')  # s is size

plt.plot(data5_3[0][:], data5_3[1][:], 'g', label='[5, -3]')  # s is size
plt.plot(data53[0][:], data53[1][:], 'r', label='[5, 3]')  # s is size
plt.plot(data_3_2[0][:], data_3_2[1][:], 'b', label='[-3, -2]')  # s is size
plt.plot(data03[0][:], data03[1][:], 'c', label='[0, 3]')  # s is size
plt.plot(data00[0][:], data00[1][:], 'k', label='[0, 0]')  # s is size

plt.axis('equal')
plt.xlabel('x (m)')
plt.ylabel('y (m)')
plt.title('ToF Scan Transformed to Global Frame')
plt.grid()
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.array(sensor_data)
time = data[start:end, 0]
tof1 = data[start:end, 1]

# %%
# Generate theta values evenly spaced around a circle
theta1 = np.linspace(theta, theta + 2 * np.pi, len(tof1))

# Create polar plot
plt.figure(figsize=(6, 6))
ax = plt.subplot(111, polar=True)
ax.plot(theta1, tof1)
ax.set_title(f"Theta vs Distance ({x1}, {y1})", va='bottom')  

plt.show()

# %%
plt.figure()
plt.plot(time, tof1, label='tof1')
plt.title(f"Tof Distance ({x1}, {y1})")
plt.xlabel('Time (s)')
plt.ylabel('Distance')
plt.legend()
plt.grid()
plt.show()

# %%
sensor_data = [[13.0, 697.0], [35.0, 697.0], [59.0, 697.0], [70.0, 697.0], [81.0, 697.0], [92.0, 697.0], [103.0, 697.0], [114.0, 696.0], [125.0, 696.0], [142.0, 696.0], [162.0, 696.0], [173.0, 696.0], [190.0, 696.0], [206.0, 696.0], [217.0, 710.0], [228.0, 710.0], [250.0, 710.0], [264.0, 710.0], [286.0, 710.0], [297.0, 710.0], [318.0, 710.0], [334.0, 737.0], [345.0, 737.0], [361.0, 737.0], [368.0, 737.0], [375.0, 737.0], [385.0, 737.0], [407.0, 737.0], [421.0, 737.0], [443.0, 755.0], [465.0, 755.0], [489.0, 755.0], [511.0, 755.0], [528.0, 755.0], [544.0, 764.0], [560.0, 764.0], [574.0, 764.0], [591.0, 764.0], [607.0, 764.0], [624.0, 764.0], [640.0, 784.0], [656.0, 784.0], [667.0, 784.0], [684.0, 784.0], [700.0, 784.0], [713.0, 784.0], [732.0, 784.0], [750.0, 816.0], [768.0, 816.0], [789.0, 816.0], [806.0, 816.0], [822.0, 816.0], [833.0, 816.0], [844.0, 828.0], [855.0, 828.0], [866.0, 828.0], [877.0, 828.0], [888.0, 828.0], [904.0, 828.0], [915.0, 828.0], [932.0, 828.0], [944.0, 856.0], [962.0, 856.0], [980.0, 856.0], [996.0, 856.0], [1007.0, 856.0], [1023.0, 856.0], [1034.0, 856.0], [1041.0, 951.0], [1058.0, 951.0], [1078.0, 951.0], [1095.0, 951.0], [1108.0, 951.0], [1126.0, 951.0], [1142.0, 951.0], [1164.0, 1749.0], [1186.0, 1749.0], [1208.0, 1749.0], [1224.0, 1749.0], [1235.0, 1749.0], [1251.0, 1566.0], [1268.0, 1566.0], [1279.0, 1566.0], [1289.0, 1566.0], [1306.0, 1566.0], [1317.0, 1566.0], [1328.0, 1566.0], [1350.0, 1566.0], [1366.0, 2078.0], [1382.0, 2078.0], [1402.0, 2078.0], [1413.0, 2078.0], [1430.0, 2078.0], [1441.0, 2078.0], [1454.0, 2078.0], [1472.0, 2068.0], [1490.0, 2068.0], [1501.0, 2068.0], [1511.0, 2068.0], [1522.0, 2068.0], [1536.0, 2068.0], [1547.0, 2068.0], [1564.0, 1890.0], [1586.0, 1890.0], [1609.0, 1890.0], [1628.0, 1890.0], [1644.0, 1890.0], [1660.0, 1890.0], [1671.0, 1909.0], [1682.0, 1909.0], [1699.0, 1909.0], [1719.0, 1909.0], [1738.0, 1909.0], [1756.0, 1909.0], [1777.0, 1845.0], [1794.0, 1845.0], [1810.0, 1845.0], [1821.0, 1845.0], [1843.0, 1845.0], [1868.0, 1845.0], [1890.0, 1755.0], [1907.0, 1755.0], [1923.0, 1755.0], [1944.0, 1755.0], [1961.0, 1755.0], [1983.0, 1755.0], [1997.0, 1673.0], [2014.0, 1673.0], [2025.0, 1673.0], [2042.0, 1673.0], [2068.0, 1673.0], [2084.0, 1673.0], [2106.0, 1644.0], [2130.0, 1644.0], [2149.0, 1644.0], [2165.0, 1644.0], [2185.0, 1644.0], [2196.0, 1598.0], [2210.0, 1598.0], [2228.0, 1598.0], [2249.0, 1598.0], [2266.0, 1598.0], [2288.0, 1598.0], [2298.0, 1549.0], [2320.0, 1549.0], [2344.0, 1549.0], [2355.0, 1549.0], [2372.0, 1549.0], [2383.0, 1549.0], [2394.0, 1529.0], [2405.0, 1529.0], [2426.0, 1529.0], [2448.0, 1529.0], [2469.0, 1529.0], [2490.0, 1529.0], [2507.0, 1522.0], [2529.0, 1522.0], [2545.0, 1522.0], [2561.0, 1522.0], [2578.0, 1522.0], [2596.0, 1522.0], [2607.0, 1502.0], [2624.0, 1502.0], [2635.0, 1502.0], [2651.0, 1502.0], [2667.0, 1502.0], [2678.0, 1502.0], [2689.0, 1502.0], [2706.0, 1470.0], [2722.0, 1470.0], [2733.0, 1470.0], [2751.0, 1470.0], [2762.0, 1470.0], [2779.0, 1470.0], [2795.0, 1470.0], [2821.0, 1446.0], [2832.0, 1446.0], [2849.0, 1446.0], [2871.0, 1446.0], [2887.0, 1446.0], [2913.0, 1446.0], [2931.0, 1446.0], [2942.0, 1442.0], [2959.0, 1442.0], [2970.0, 1442.0], [2981.0, 1442.0], [2992.0, 1442.0], [3007.0, 1442.0], [3018.0, 1442.0], [3035.0, 1442.0], [3051.0, 1412.0], [3062.0, 1412.0], [3078.0, 1412.0], [3089.0, 1412.0], [3100.0, 1412.0], [3111.0, 1412.0], [3122.0, 1412.0], [3133.0, 1412.0], [3144.0, 1394.0], [3155.0, 1394.0], [3171.0, 1394.0], [3188.0, 1394.0], [3215.0, 1394.0], [3232.0, 1394.0], [3248.0, 1387.0], [3259.0, 1387.0], [3270.0, 1387.0], [3286.0, 1387.0], [3299.0, 1387.0], [3310.0, 1387.0], [3327.0, 1387.0], [3343.0, 1387.0], [3354.0, 1387.0], [3370.0, 1387.0], [3392.0, 1387.0], [3409.0, 1387.0], [3431.0, 1387.0], [3448.0, 1384.0], [3459.0, 1384.0], [3476.0, 1384.0], [3498.0, 1384.0], [3521.0, 1384.0], [3532.0, 1384.0], [3542.0, 1375.0], [3553.0, 1375.0], [3564.0, 1375.0], [3581.0, 1375.0], [3596.0, 1375.0], [3617.0, 1375.0], [3628.0, 1375.0], [3645.0, 1375.0], [3661.0, 1375.0], [3678.0, 1375.0], [3688.0, 1375.0], [3699.0, 1375.0], [3710.0, 1375.0], [3721.0, 1375.0], [3738.0, 1375.0], [3754.0, 1365.0], [3781.0, 1365.0], [3803.0, 1365.0], [3820.0, 1365.0], [3836.0, 1365.0], [3853.0, 1364.0], [3871.0, 1364.0], [3880.0, 1364.0], [3890.0, 1364.0], [3902.0, 1364.0], [3924.0, 1364.0], [3942.0, 1364.0], [3963.0, 1366.0], [3980.0, 1366.0], [3996.0, 1366.0], [4007.0, 1366.0], [4018.0, 1366.0], [4036.0, 1366.0], [4055.0, 1368.0], [4072.0, 1368.0], [4090.0, 1368.0], [4101.0, 1368.0], [4117.0, 1368.0], [4139.0, 1368.0], [4155.0, 1370.0], [4177.0, 1370.0], [4188.0, 1370.0], [4202.0, 1370.0], [4213.0, 1370.0], [4230.0, 1370.0], [4241.0, 1370.0], [4257.0, 1385.0], [4273.0, 1385.0], [4284.0, 1385.0], [4301.0, 1385.0], [4312.0, 1385.0], [4328.0, 1385.0], [4348.0, 1385.0], [4365.0, 1401.0], [4387.0, 1401.0], [4409.0, 1401.0], [4426.0, 1401.0], [4447.0, 1401.0], [4458.0, 1411.0], [4475.0, 1411.0], [4486.0, 1411.0], [4500.0, 1411.0], [4518.0, 1411.0], [4539.0, 1411.0], [4550.0, 1411.0], [4561.0, 1413.0], [4572.0, 1413.0], [4583.0, 1413.0], [4594.0, 1413.0], [4605.0, 1413.0], [4616.0, 1413.0], [4627.0, 1413.0], [4643.0, 1413.0], [4660.0, 1431.0], [4676.0, 1431.0], [4685.0, 1431.0], [4707.0, 1431.0], [4716.0, 1431.0], [4734.0, 1431.0], [4754.0, 1431.0], [4776.0, 1453.0], [4798.0, 1453.0], [4819.0, 1453.0], [4840.0, 1453.0], [4857.0, 1453.0], [4868.0, 1459.0], [4892.0, 1459.0], [4910.0, 1459.0], [4931.0, 1459.0], [4942.0, 1459.0], [4959.0, 1459.0], [4981.0, 1456.0], [5003.0, 1456.0], [5021.0, 1456.0], [5031.0, 1456.0], [5042.0, 1456.0], [5054.0, 1456.0], [5070.0, 1454.0], [5081.0, 1454.0], [5097.0, 1454.0], [5104.0, 1454.0], [5121.0, 1454.0], [5128.0, 1454.0], [5144.0, 1454.0], [5160.0, 1454.0], [5171.0, 1400.0], [5182.0, 1400.0], [5193.0, 1400.0], [5210.0, 1400.0], [5222.0, 1400.0], [5243.0, 1400.0], [5265.0, 1400.0], [5282.0, 1391.0], [5300.0, 1391.0], [5321.0, 1391.0], [5332.0, 1391.0], [5349.0, 1391.0], [5365.0, 1391.0], [5376.0, 1386.0], [5387.0, 1386.0], [5398.0, 1386.0], [5409.0, 1386.0], [5426.0, 1386.0], [5436.0, 1386.0], [5458.0, 1386.0], [5480.0, 1271.0], [5497.0, 1271.0], [5515.0, 1271.0], [5536.0, 1271.0], [5553.0, 1271.0], [5569.0, 1271.0], [5591.0, 1271.0], [5612.0, 1060.0], [5634.0, 1060.0], [5651.0, 1060.0], [5673.0, 1060.0], [5689.0, 1060.0], [5705.0, 1046.0], [5722.0, 1046.0], [5738.0, 1046.0], [5755.0, 1046.0], [5771.0, 1046.0], [5790.0, 1046.0], [5801.0, 1040.0], [5818.0, 1040.0], [5829.0, 1040.0], [5840.0, 1040.0], [5851.0, 1040.0], [5862.0, 1040.0], [5872.0, 1040.0], [5880.0, 1040.0], [5887.0, 1040.0], [5894.0, 951.0], [5910.0, 951.0], [5924.0, 951.0], [5945.0, 951.0], [5963.0, 951.0], [5979.0, 951.0], [5995.0, 951.0], [6017.0, 890.0], [6030.0, 890.0], [6048.0, 890.0], [6069.0, 890.0], [6086.0, 890.0], [6110.0, 883.0], [6120.0, 883.0], [6131.0, 883.0], [6153.0, 883.0], [6170.0, 883.0], [6186.0, 883.0], [6208.0, 883.0], [6224.0, 872.0], [6246.0, 872.0], [6257.0, 872.0], [6277.0, 872.0], [6288.0, 872.0], [6305.0, 872.0], [6327.0, 831.0], [6338.0, 831.0], [6355.0, 831.0], [6377.0, 831.0], [6397.0, 831.0], [6416.0, 831.0], [6438.0, 790.0], [6450.0, 790.0], [6468.0, 790.0], [6484.0, 790.0], [6501.0, 790.0], [6522.0, 790.0], [6547.0, 779.0], [6558.0, 779.0], [6574.0, 779.0], [6596.0, 779.0], [6618.0, 779.0], [6639.0, 774.0], [6661.0, 774.0], [6678.0, 774.0], [6700.0, 774.0], [6723.0, 774.0], [6735.0, 743.0], [6751.0, 743.0], [6767.0, 743.0], [6784.0, 743.0], [6795.0, 743.0], [6807.0, 743.0], [6824.0, 743.0], [6836.0, 712.0], [6857.0, 712.0], [6879.0, 712.0], [6896.0, 712.0], [6912.0, 712.0], [6928.0, 712.0], [6939.0, 712.0], [6956.0, 712.0], [6978.0, 712.0], [6997.0, 712.0], [7014.0, 712.0], [7035.0, 712.0], [7057.0, 707.0], [7081.0, 707.0], [7102.0, 707.0], [7119.0, 707.0], [7135.0, 707.0], [7146.0, 688.0], [7168.0, 688.0], [7184.0, 688.0], [7201.0, 688.0], [7210.0, 688.0], [7226.0, 688.0], [7248.0, 688.0], [7274.0, 686.0], [7296.0, 686.0], [7313.0, 686.0], [7329.0, 686.0], [7345.0, 686.0], [7362.0, 687.0], [7378.0, 687.0], [7396.0, 687.0], [7407.0, 687.0], [7424.0, 687.0], [7435.0, 687.0], [7462.0, 690.0], [7484.0, 690.0], [7500.0, 690.0], [7525.0, 690.0], [7547.0, 690.0], [7571.0, 690.0], [7582.0, 719.0], [7599.0, 719.0], [7621.0, 719.0], [7637.0, 719.0], [7659.0, 719.0], [7670.0, 719.0], [7687.0, 820.0], [7703.0, 820.0], [7722.0, 820.0], [7744.0, 820.0], [7766.0, 820.0], [7783.0, 947.0], [7804.0, 947.0], [7821.0, 947.0], [7832.0, 947.0], [7843.0, 947.0], [7859.0, 947.0], [7875.0, 1197.0], [7886.0, 1197.0], [7897.0, 1197.0], [7908.0, 1197.0], [7925.0, 1197.0], [7937.0, 1197.0], [7953.0, 1197.0], [7964.0, 1197.0], [7980.0, 1484.0], [8002.0, 1484.0], [8022.0, 1484.0], [8044.0, 1484.0], [8068.0, 1484.0], [8080.0, 1552.0], [8096.0, 1552.0], [8112.0, 1552.0], [8134.0, 1552.0], [8157.0, 1552.0], [8168.0, 1552.0], [8184.0, 1558.0], [8199.0, 1558.0], [8215.0, 1558.0], [8231.0, 1558.0], [8251.0, 1558.0], [8262.0, 1558.0], [8279.0, 1565.0], [8290.0, 1565.0], [8306.0, 1565.0], [8328.0, 1565.0], [8348.0, 1565.0], [8370.0, 1565.0], [8387.0, 1568.0], [8403.0, 1568.0], [8414.0, 1568.0], [8430.0, 1568.0], [8442.0, 1568.0], [8451.0, 1568.0], [8472.0, 1568.0], [8489.0, 1590.0], [8505.0, 1590.0], [8519.0, 1590.0], [8538.0, 1590.0], [8555.0, 1590.0], [8568.0, 1590.0], [8586.0, 1597.0], [8607.0, 1597.0], [8632.0, 1597.0], [8643.0, 1597.0], [8664.0, 1597.0], [8681.0, 1598.0], [8697.0, 1598.0], [8714.0, 1598.0], [8724.0, 1598.0], [8735.0, 1598.0], [8746.0, 1598.0], [8757.0, 1598.0], [8774.0, 1621.0], [8796.0, 1621.0], [8814.0, 1621.0], [8836.0, 1621.0], [8853.0, 1621.0], [8862.0, 1621.0], [8878.0, 1651.0], [8897.0, 1651.0], [8914.0, 1651.0], [8925.0, 1651.0], [8936.0, 1651.0], [8952.0, 1651.0], [8968.0, 1651.0], [8979.0, 1673.0], [8992.0, 1673.0], [9009.0, 1673.0], [9025.0, 1673.0], [9042.0, 1673.0], [9058.0, 1673.0], [9080.0, 1673.0], [9096.0, 1682.0], [9109.0, 1682.0], [9120.0, 1682.0], [9137.0, 1682.0], [9148.0, 1682.0], [9164.0, 1682.0], [9172.0, 1682.0], [9188.0, 1739.0], [9204.0, 1739.0], [9221.0, 1739.0], [9237.0, 1739.0], [9254.0, 1739.0], [9276.0, 1739.0], [9298.0, 1768.0], [9315.0, 1768.0], [9331.0, 1768.0], [9353.0, 1768.0], [9377.0, 1768.0], [9388.0, 1777.0], [9405.0, 1777.0], [9421.0, 1777.0], [9443.0, 1777.0], [9467.0, 1777.0], [9478.0, 1777.0], [9489.0, 1793.0], [9500.0, 1793.0], [9511.0, 1793.0], [9522.0, 1793.0], [9533.0, 1793.0], [9544.0, 1793.0], [9551.0, 1793.0], [9568.0, 1793.0], [9584.0, 1793.0], [9603.0, 1875.0], [9612.0, 1875.0], [9622.0, 1875.0], [9642.0, 1875.0], [9659.0, 1875.0], [9681.0, 1875.0], [9692.0, 1936.0], [9708.0, 1936.0], [9724.0, 1936.0], [9746.0, 1936.0], [9763.0, 1936.0], [9779.0, 1936.0], [9802.0, 1943.0], [9822.0, 1943.0], [9839.0, 1943.0], [9856.0, 1943.0], [9867.0, 1943.0], [9883.0, 1943.0], [9904.0, 1954.0], [9924.0, 1954.0], [9935.0, 1954.0], [9952.0, 1954.0], [9974.0, 1954.0], [9990.0, 1954.0], [10012.0, 1982.0], [10031.0, 1982.0], [10051.0, 1982.0], [10073.0, 1982.0], [10090.0, 1982.0], [10109.0, 1990.0], [10125.0, 1990.0], [10136.0, 1990.0], [10152.0, 1990.0], [10180.0, 1990.0], [10201.0, 1990.0], [10220.0, 1956.0], [10231.0, 1956.0], [10248.0, 1956.0], [10259.0, 1956.0], [10270.0, 1956.0], [10291.0, 1956.0], [10315.0, 1956.0], [10335.0, 1926.0], [10352.0, 1926.0], [10373.0, 1926.0], [10384.0, 1926.0], [10395.0, 1926.0], [10416.0, 1926.0], [10433.0, 1695.0], [10449.0, 1695.0], [10466.0, 1695.0], [10482.0, 1695.0], [10498.0, 1695.0], [10515.0, 1695.0], [10531.0, 1643.0], [10549.0, 1643.0], [10560.0, 1643.0], [10577.0, 1643.0], [10588.0, 1643.0], [10604.0, 1643.0], [10620.0, 1644.0], [10631.0, 1644.0], [10642.0, 1644.0], [10659.0, 1644.0], [10679.0, 1644.0], [10697.0, 1644.0], [10708.0, 1644.0], [10725.0, 1628.0], [10736.0, 1628.0], [10752.0, 1628.0], [10763.0, 1628.0], [10779.0, 1628.0], [10791.0, 1628.0], [10807.0, 1628.0], [10823.0, 1542.0], [10842.0, 1542.0], [10860.0, 1542.0], [10870.0, 1542.0], [10881.0, 1542.0], [10896.0, 1542.0], [10909.0, 1542.0], [10925.0, 1493.0], [10942.0, 1493.0], [10958.0, 1493.0], [10977.0, 1493.0], [10988.0, 1493.0], [11005.0, 1493.0], [11027.0, 1486.0], [11050.0, 1486.0], [11061.0, 1486.0], [11078.0, 1486.0], [11094.0, 1486.0], [11116.0, 1486.0], [11127.0, 1495.0], [11143.0, 1495.0], [11160.0, 1495.0], [11182.0, 1495.0], [11204.0, 1495.0], [11223.0, 1495.0], [11240.0, 1446.0], [11251.0, 1446.0], [11262.0, 1446.0], [11273.0, 1446.0], [11289.0, 1446.0], [11305.0, 1446.0], [11327.0, 1446.0], [11355.0, 1403.0], [11371.0, 1403.0], [11387.0, 1403.0], [11407.0, 1403.0], [11424.0, 1403.0], [11440.0, 1251.0], [11462.0, 1251.0], [11479.0, 1251.0], [11495.0, 1251.0], [11517.0, 1251.0], [11539.0, 1195.0], [11557.0, 1195.0], [11578.0, 1195.0], [11595.0, 1195.0], [11611.0, 1195.0], [11628.0, 1195.0], [11644.0, 1195.0], [11655.0, 757.0], [11673.0, 757.0], [11689.0, 757.0], [11711.0, 757.0], [11733.0, 757.0], [11753.0, 757.0], [11773.0, 688.0], [11784.0, 688.0], [11801.0, 688.0], [11812.0, 688.0], [11828.0, 688.0], [11839.0, 688.0], [11855.0, 688.0], [11877.0, 683.0], [11901.0, 683.0], [11922.0, 683.0], [11939.0, 683.0], [11961.0, 683.0], [11984.0, 676.0], [11995.0, 676.0], [12012.0, 676.0], [12034.0, 676.0], [12048.0, 676.0], [12066.0, 676.0], [12076.0, 656.0], [12093.0, 656.0], [12103.0, 656.0], [12114.0, 656.0], [12125.0, 656.0], [12136.0, 656.0], [12147.0, 656.0], [12158.0, 656.0], [12175.0, 653.0], [12185.0, 653.0], [12196.0, 653.0], [12207.0, 653.0], [12218.0, 653.0], [12235.0, 653.0], [12246.0, 653.0], [12257.0, 653.0], [12268.0, 653.0], [12278.0, 651.0], [12289.0, 651.0], [12300.0, 651.0], [12311.0, 651.0], [12330.0, 651.0], [12348.0, 651.0], [12358.0, 651.0], [12375.0, 651.0], [12386.0, 653.0], [12397.0, 653.0], [12408.0, 653.0], [12419.0, 653.0], [12430.0, 653.0], [12440.0, 653.0], [12451.0, 653.0], [12462.0, 653.0], [12473.0, 653.0], [12484.0, 654.0], [12495.0, 654.0], [12506.0, 654.0], [12517.0, 654.0], [12533.0, 654.0], [12548.0, 654.0], [12564.0, 654.0], [12575.0, 654.0], [12592.0, 652.0], [12603.0, 652.0], [12619.0, 652.0], [12630.0, 652.0], [12641.0, 652.0], [12652.0, 652.0], [12663.0, 652.0], [12674.0, 652.0], [12685.0, 653.0], [12696.0, 653.0], [12707.0, 653.0], [12718.0, 653.0], [12728.0, 653.0], [12739.0, 653.0], [12750.0, 653.0], [12761.0, 653.0], [12772.0, 653.0], [12783.0, 651.0], [12794.0, 651.0], [12805.0, 651.0], [12816.0, 651.0], [12827.0, 651.0], [12843.0, 651.0], [12857.0, 651.0], [12874.0, 651.0], [12896.0, 652.0], [12911.0, 652.0], [12933.0, 652.0], [12955.0, 652.0], [12976.0, 652.0], [12997.0, 653.0], [13014.0, 653.0], [13036.0, 653.0], [13060.0, 653.0], [13078.0, 653.0], [13100.0, 658.0], [13124.0, 658.0], [13134.0, 658.0], [13145.0, 658.0], [13160.0, 658.0], [13173.0, 658.0], [13197.0, 667.0], [13215.0, 667.0], [13233.0, 667.0], [13254.0, 667.0], [13276.0, 667.0], [13298.0, 667.0], [13316.0, 693.0], [13334.0, 693.0], [13354.0, 693.0], [13372.0, 693.0], [13383.0, 693.0], [13400.0, 693.0], [13416.0, 710.0], [13438.0, 710.0], [13449.0, 710.0], [13465.0, 710.0], [13482.0, 710.0], [13498.0, 710.0], [13509.0, 725.0], [13520.0, 725.0], [13531.0, 725.0], [13542.0, 725.0], [13558.0, 725.0], [13569.0, 725.0], [13580.0, 725.0], [13591.0, 725.0], [13602.0, 725.0], [13613.0, 753.0], [13624.0, 753.0], [13635.0, 753.0], [13646.0, 753.0], [13657.0, 753.0], [13668.0, 753.0], [13679.0, 753.0], [13689.0, 753.0], [13700.0, 753.0], [13711.0, 794.0], [13722.0, 794.0], [13733.0, 794.0], [13744.0, 794.0], [13755.0, 794.0], [13766.0, 794.0], [13777.0, 794.0], [13788.0, 794.0], [13799.0, 794.0], [13813.0, 838.0], [13835.0, 838.0], [13852.0, 838.0], [13868.0, 838.0], [13890.0, 838.0], [13901.0, 838.0], [13912.0, 947.0], [13923.0, 947.0], [13934.0, 947.0], [13945.0, 947.0], [13956.0, 947.0], [13970.0, 947.0], [13981.0, 947.0], [13998.0, 947.0], [14014.0, 1112.0], [14025.0, 1112.0], [14041.0, 1112.0], [14058.0, 1112.0], [14080.0, 1112.0], [14103.0, 1112.0], [14122.0, 1176.0], [14138.0, 1176.0], [14154.0, 1176.0], [14165.0, 1176.0], [14176.0, 1176.0], [14193.0, 1176.0], [14215.0, 1176.0], [14232.0, 1213.0], [14248.0, 1213.0], [14266.0, 1213.0], [14284.0, 1213.0], [14300.0, 1213.0], [14322.0, 1213.0], [14344.0, 1247.0], [14360.0, 1247.0], [14371.0, 1247.0], [14382.0, 1247.0], [14393.0, 1247.0], [14404.0, 1247.0], [14415.0, 1247.0], [14426.0, 1247.0], [14437.0, 1300.0], [14448.0, 1300.0], [14458.0, 1300.0], [14469.0, 1300.0], [14480.0, 1300.0], [14497.0, 1300.0], [14517.0, 1300.0], [14528.0, 1300.0], [14545.0, 1330.0], [14556.0, 1330.0], [14583.0, 1330.0], [14605.0, 1330.0], [14629.0, 1330.0], [14640.0, 1364.0], [14657.0, 1364.0], [14668.0, 1364.0], [14683.0, 1364.0], [14704.0, 1364.0], [14721.0, 1364.0], [14743.0, 1364.0], [14754.0, 1385.0], [14765.0, 1385.0], [14776.0, 1385.0], [14786.0, 1385.0], [14812.0, 1385.0], [14823.0, 1385.0], [14833.0, 1385.0], [14844.0, 1385.0], [14861.0, 1419.0], [14873.0, 1419.0], [14889.0, 1419.0], [14900.0, 1419.0], [14918.0, 1419.0], [14936.0, 1419.0], [14954.0, 1419.0], [14975.0, 1461.0], [15000.0, 1461.0], [15011.0, 1461.0], [15032.0, 1461.0], [15049.0, 1461.0], [15065.0, 1539.0], [15087.0, 1539.0], [15098.0, 1539.0], [15109.0, 1539.0], [15120.0, 1539.0], [15131.0, 1539.0], [15142.0, 1539.0], [15153.0, 1539.0], [15169.0, 1611.0], [15191.0, 1611.0], [15207.0, 1611.0], [15224.0, 1611.0], [15246.0, 1611.0], [15262.0, 1722.0], [15280.0, 1722.0], [15291.0, 1722.0], [15308.0, 1722.0], [15319.0, 1722.0], [15335.0, 1722.0], [15346.0, 1722.0], [15362.0, 1722.0], [15374.0, 1846.0], [15390.0, 1846.0], [15401.0, 1846.0], [15423.0, 1846.0], [15444.0, 1846.0], [15461.0, 1846.0], [15483.0, 1898.0], [15499.0, 1898.0], [15521.0, 1898.0], [15545.0, 1898.0], [15567.0, 1898.0], [15593.0, 1930.0], [15612.0, 1930.0], [15633.0, 1930.0], [15657.0, 1930.0], [15678.0, 1930.0], [15704.0, 1967.0], [15721.0, 1967.0], [15745.0, 1967.0], [15755.0, 1967.0], [15767.0, 1967.0], [15787.0, 1967.0], [15798.0, 1917.0], [15815.0, 1917.0], [15826.0, 1917.0], [15842.0, 1917.0], [15853.0, 1917.0], [15864.0, 1917.0], [15886.0, 1917.0], [15898.0, 1974.0], [15919.0, 1974.0], [15941.0, 1974.0], [15960.0, 1974.0], [15977.0, 1974.0], [15999.0, 1974.0], [16025.0, 1987.0], [16044.0, 1987.0], [16064.0, 1987.0], [16082.0, 1987.0], [16093.0, 1987.0], [16109.0, 2097.0], [16131.0, 2097.0], [16154.0, 2097.0], [16165.0, 2097.0], [16187.0, 2097.0], [16204.0, 2132.0], [16220.0, 2132.0], [16236.0, 2132.0], [16247.0, 2132.0], [16264.0, 2132.0], [16286.0, 2132.0], [16308.0, 2151.0], [16326.0, 2151.0], [16336.0, 2151.0], [16347.0, 2151.0], [16369.0, 2151.0], [16386.0, 2151.0], [16412.0, 2230.0], [16430.0, 2230.0], [16441.0, 2230.0], [16458.0, 2230.0], [16483.0, 2230.0], [16503.0, 2247.0], [16523.0, 2247.0], [16545.0, 2247.0], [16558.0, 2247.0], [16579.0, 2247.0], [16601.0, 2281.0], [16618.0, 2281.0], [16634.0, 2281.0], [16655.0, 2281.0], [16666.0, 2281.0], [16682.0, 2281.0], [16704.0, 2286.0], [16727.0, 2286.0], [16738.0, 2286.0], [16755.0, 2286.0], [16771.0, 2286.0], [16788.0, 2286.0], [16798.0, 2217.0], [16809.0, 2217.0], [16826.0, 2217.0], [16837.0, 2217.0], [16848.0, 2217.0], [16864.0, 2217.0], [16875.0, 2217.0], [16886.0, 2217.0], [16897.0, 2100.0], [16913.0, 2100.0], [16928.0, 2100.0], [16949.0, 2100.0], [16971.0, 2100.0], [16985.0, 2100.0], [17006.0, 2000.0], [17032.0, 2000.0], [17052.0, 2000.0], [17063.0, 2000.0], [17080.0, 2000.0], [17091.0, 1944.0], [17107.0, 1944.0], [17123.0, 1944.0], [17134.0, 1944.0], [17145.0, 1944.0], [17162.0, 1944.0], [17178.0, 1944.0], [17200.0, 1718.0], [17216.0, 1718.0], [17233.0, 1718.0], [17249.0, 1718.0], [17271.0, 1718.0], [17283.0, 1718.0], [17301.0, 1064.0], [17322.0, 1064.0], [17339.0, 1064.0], [17350.0, 1064.0], [17361.0, 1064.0], [17372.0, 1064.0], [17388.0, 1064.0], [17410.0, 850.0], [17426.0, 850.0], [17451.0, 850.0], [17473.0, 850.0], [17497.0, 850.0], [17508.0, 784.0], [17524.0, 784.0], [17540.0, 784.0], [17562.0, 784.0], [17584.0, 784.0], [17600.0, 784.0], [17617.0, 728.0], [17633.0, 728.0], [17650.0, 728.0], [17666.0, 728.0], [17684.0, 728.0], [17695.0, 728.0], [17712.0, 697.0], [17723.0, 697.0], [17739.0, 697.0], [17750.0, 697.0], [17777.0, 697.0], [17799.0, 697.0], [17820.0, 673.0], [17841.0, 673.0], [17858.0, 673.0], [17869.0, 673.0], [17885.0, 673.0], [17902.0, 673.0], [17923.0, 659.0], [17940.0, 659.0], [17956.0, 659.0], [17973.0, 659.0], [17984.0, 659.0], [17994.0, 659.0], [18016.0, 659.0]]
x1 = 0
y1 = 0
start = 0
end = 1127
theta = 0.08*np.pi

data = np.array(sensor_data)
time = data[start:end, 0]
tof1 = data[start:end, 1]

data00 = robot2global(tof1, x1, y1, theta)

plt.figure()
plt.scatter(data00[0], data00[1], s=1, c='black')  # s is size
plt.axis('equal')
plt.xlabel('x (m)')
plt.ylabel('y (m)')
plt.title(f'ToF Global Frame {x1}, {y1}')
plt.grid()
plt.show()

# %%
sensor_data = [[17.0, 1011.0], [33.0, 1011.0], [49.0, 1011.0], [71.0, 1011.0], [88.0, 1011.0], [99.0, 1011.0], [115.0, 1008.0], [137.0, 1008.0], [153.0, 1008.0], [164.0, 1008.0], [181.0, 1008.0], [197.0, 1008.0], [213.0, 956.0], [231.0, 956.0], [242.0, 956.0], [259.0, 956.0], [281.0, 956.0], [297.0, 956.0], [313.0, 887.0], [335.0, 887.0], [346.0, 887.0], [363.0, 887.0], [389.0, 887.0], [406.0, 887.0], [422.0, 955.0], [444.0, 955.0], [460.0, 955.0], [477.0, 955.0], [488.0, 955.0], [501.0, 955.0], [519.0, 1916.0], [536.0, 1916.0], [547.0, 1916.0], [554.0, 1916.0], [572.0, 1916.0], [592.0, 1916.0], [603.0, 1916.0], [625.0, 1928.0], [641.0, 1928.0], [652.0, 1928.0], [669.0, 1928.0], [685.0, 1928.0], [696.0, 1928.0], [707.0, 1928.0], [723.0, 1934.0], [734.0, 1934.0], [760.0, 1934.0], [776.0, 1934.0], [793.0, 1934.0], [803.0, 1934.0], [820.0, 1936.0], [836.0, 1936.0], [847.0, 1936.0], [860.0, 1936.0], [878.0, 1936.0], [899.0, 1936.0], [916.0, 1931.0], [932.0, 1931.0], [945.0, 1931.0], [963.0, 1931.0], [983.0, 1931.0], [994.0, 1931.0], [1013.0, 1920.0], [1024.0, 1920.0], [1041.0, 1920.0], [1048.0, 1920.0], [1064.0, 1920.0], [1081.0, 1920.0], [1096.0, 1920.0], [1107.0, 1871.0], [1118.0, 1871.0], [1129.0, 1871.0], [1144.0, 1871.0], [1155.0, 1871.0], [1172.0, 1871.0], [1183.0, 1871.0], [1194.0, 1871.0], [1209.0, 1861.0], [1229.0, 1861.0], [1246.0, 1861.0], [1257.0, 1861.0], [1268.0, 1861.0], [1284.0, 1861.0], [1299.0, 1861.0], [1316.0, 1864.0], [1332.0, 1864.0], [1354.0, 1864.0], [1370.0, 1864.0], [1387.0, 1864.0], [1409.0, 1864.0], [1425.0, 1757.0], [1442.0, 1757.0], [1466.0, 1757.0], [1477.0, 1757.0], [1494.0, 1757.0], [1511.0, 1757.0], [1523.0, 1196.0], [1540.0, 1196.0], [1551.0, 1196.0], [1562.0, 1196.0], [1584.0, 1196.0], [1607.0, 1196.0], [1623.0, 1013.0], [1634.0, 1013.0], [1656.0, 1013.0], [1683.0, 1013.0], [1694.0, 1013.0], [1716.0, 1013.0], [1732.0, 1016.0], [1743.0, 1016.0], [1754.0, 1016.0], [1770.0, 1016.0], [1785.0, 1016.0], [1801.0, 1016.0], [1817.0, 1016.0], [1839.0, 912.0], [1847.0, 912.0], [1869.0, 912.0], [1891.0, 912.0], [1907.0, 912.0], [1924.0, 912.0], [1946.0, 788.0], [1962.0, 788.0], [1978.0, 788.0], [1998.0, 788.0], [2018.0, 788.0], [2038.0, 784.0], [2056.0, 784.0], [2073.0, 784.0], [2084.0, 784.0], [2103.0, 784.0], [2120.0, 784.0], [2136.0, 775.0], [2154.0, 775.0], [2176.0, 775.0], [2198.0, 775.0], [2221.0, 775.0], [2237.0, 729.0], [2255.0, 729.0], [2275.0, 729.0], [2293.0, 729.0], [2313.0, 729.0], [2332.0, 729.0], [2349.0, 652.0], [2367.0, 652.0], [2378.0, 652.0], [2403.0, 652.0], [2424.0, 652.0], [2441.0, 637.0], [2463.0, 637.0], [2485.0, 637.0], [2495.0, 637.0], [2517.0, 637.0], [2534.0, 637.0], [2550.0, 637.0], [2567.0, 636.0], [2583.0, 636.0], [2599.0, 636.0], [2616.0, 636.0], [2638.0, 636.0], [2659.0, 636.0], [2676.0, 586.0], [2693.0, 586.0], [2704.0, 586.0], [2720.0, 586.0], [2729.0, 586.0], [2737.0, 586.0], [2759.0, 586.0], [2778.0, 535.0], [2800.0, 535.0], [2817.0, 535.0], [2833.0, 535.0], [2849.0, 535.0], [2871.0, 535.0], [2888.0, 532.0], [2904.0, 532.0], [2926.0, 532.0], [2948.0, 532.0], [2971.0, 532.0], [2990.0, 530.0], [3008.0, 530.0], [3029.0, 530.0], [3046.0, 530.0], [3062.0, 530.0], [3081.0, 530.0], [3092.0, 501.0], [3108.0, 501.0], [3127.0, 501.0], [3148.0, 501.0], [3172.0, 501.0], [3189.0, 501.0], [3200.0, 471.0], [3218.0, 471.0], [3238.0, 471.0], [3255.0, 471.0], [3266.0, 471.0], [3288.0, 471.0], [3310.0, 469.0], [3328.0, 469.0], [3345.0, 469.0], [3361.0, 469.0], [3373.0, 469.0], [3391.0, 469.0], [3408.0, 466.0], [3419.0, 466.0], [3430.0, 466.0], [3447.0, 466.0], [3458.0, 466.0], [3485.0, 466.0], [3509.0, 441.0], [3519.0, 441.0], [3543.0, 441.0], [3560.0, 441.0], [3576.0, 441.0], [3594.0, 441.0], [3616.0, 441.0], [3634.0, 436.0], [3656.0, 436.0], [3667.0, 436.0], [3684.0, 436.0], [3700.0, 436.0], [3716.0, 436.0], [3733.0, 436.0], [3744.0, 436.0], [3760.0, 436.0], [3771.0, 436.0], [3787.0, 436.0], [3798.0, 436.0], [3815.0, 436.0], [3826.0, 433.0], [3850.0, 433.0], [3860.0, 433.0], [3877.0, 433.0], [3886.0, 433.0], [3911.0, 433.0], [3920.0, 426.0], [3936.0, 426.0], [3958.0, 426.0], [3974.0, 426.0], [3985.0, 426.0], [4002.0, 426.0], [4012.0, 426.0], [4029.0, 425.0], [4040.0, 425.0], [4060.0, 425.0], [4077.0, 425.0], [4093.0, 425.0], [4104.0, 425.0], [4126.0, 425.0], [4142.0, 426.0], [4158.0, 426.0], [4169.0, 426.0], [4186.0, 426.0], [4197.0, 426.0], [4212.0, 426.0], [4223.0, 426.0], [4240.0, 426.0], [4251.0, 426.0], [4277.0, 426.0], [4288.0, 426.0], [4307.0, 426.0], [4324.0, 426.0], [4331.0, 414.0], [4347.0, 414.0], [4364.0, 414.0], [4380.0, 414.0], [4396.0, 414.0], [4414.0, 414.0], [4431.0, 414.0], [4444.0, 408.0], [4464.0, 408.0], [4475.0, 408.0], [4485.0, 408.0], [4507.0, 408.0], [4529.0, 408.0], [4542.0, 410.0], [4560.0, 410.0], [4577.0, 410.0], [4593.0, 410.0], [4609.0, 410.0], [4626.0, 410.0], [4637.0, 408.0], [4648.0, 408.0], [4673.0, 408.0], [4690.0, 408.0], [4701.0, 408.0], [4717.0, 408.0], [4725.0, 408.0], [4741.0, 406.0], [4757.0, 406.0], [4774.0, 406.0], [4790.0, 406.0], [4807.0, 406.0], [4824.0, 406.0], [4841.0, 408.0], [4852.0, 408.0], [4871.0, 408.0], [4888.0, 408.0], [4904.0, 408.0], [4922.0, 408.0], [4933.0, 408.0], [4950.0, 408.0], [4961.0, 408.0], [4985.0, 408.0], [4995.0, 408.0], [5012.0, 408.0], [5023.0, 408.0], [5045.0, 410.0], [5067.0, 410.0], [5076.0, 410.0], [5093.0, 410.0], [5113.0, 410.0], [5131.0, 410.0], [5150.0, 418.0], [5162.0, 418.0], [5184.0, 418.0], [5202.0, 418.0], [5220.0, 418.0], [5240.0, 418.0], [5251.0, 420.0], [5261.0, 420.0], [5278.0, 420.0], [5294.0, 420.0], [5311.0, 420.0], [5332.0, 420.0], [5354.0, 420.0], [5371.0, 420.0], [5382.0, 420.0], [5404.0, 420.0], [5428.0, 420.0], [5448.0, 420.0], [5469.0, 420.0], [5493.0, 426.0], [5504.0, 426.0], [5521.0, 426.0], [5528.0, 426.0], [5545.0, 426.0], [5561.0, 426.0], [5578.0, 426.0], [5599.0, 440.0], [5616.0, 440.0], [5632.0, 440.0], [5649.0, 440.0], [5665.0, 440.0], [5676.0, 440.0], [5687.0, 447.0], [5712.0, 447.0], [5723.0, 447.0], [5740.0, 447.0], [5762.0, 447.0], [5778.0, 447.0], [5794.0, 444.0], [5811.0, 444.0], [5827.0, 444.0], [5844.0, 444.0], [5860.0, 444.0], [5871.0, 444.0], [5882.0, 460.0], [5891.0, 460.0], [5913.0, 460.0], [5924.0, 460.0], [5935.0, 460.0], [5944.0, 460.0], [5960.0, 460.0], [5977.0, 460.0], [5988.0, 480.0], [6004.0, 480.0], [6026.0, 480.0], [6048.0, 480.0], [6065.0, 480.0], [6081.0, 480.0], [6097.0, 485.0], [6114.0, 485.0], [6136.0, 485.0], [6152.0, 485.0], [6168.0, 485.0], [6185.0, 485.0], [6201.0, 486.0], [6212.0, 486.0], [6223.0, 486.0], [6239.0, 486.0], [6250.0, 486.0], [6272.0, 486.0], [6289.0, 486.0], [6304.0, 495.0], [6315.0, 495.0], [6342.0, 495.0], [6358.0, 495.0], [6369.0, 495.0], [6391.0, 495.0], [6404.0, 523.0], [6415.0, 523.0], [6431.0, 523.0], [6450.0, 523.0], [6470.0, 523.0], [6492.0, 523.0], [6503.0, 545.0], [6520.0, 545.0], [6536.0, 545.0], [6558.0, 545.0], [6583.0, 545.0], [6600.0, 545.0], [6611.0, 544.0], [6622.0, 544.0], [6638.0, 544.0], [6649.0, 544.0], [6665.0, 544.0], [6676.0, 544.0], [6687.0, 544.0], [6698.0, 544.0], [6715.0, 560.0], [6731.0, 560.0], [6742.0, 560.0], [6766.0, 560.0], [6786.0, 560.0], [6802.0, 560.0], [6818.0, 599.0], [6840.0, 599.0], [6857.0, 599.0], [6864.0, 599.0], [6880.0, 599.0], [6897.0, 599.0], [6918.0, 649.0], [6929.0, 649.0], [6940.0, 649.0], [6951.0, 649.0], [6968.0, 649.0], [6989.0, 649.0], [7006.0, 649.0], [7017.0, 655.0], [7033.0, 655.0], [7055.0, 655.0], [7077.0, 655.0], [7093.0, 655.0], [7115.0, 655.0], [7140.0, 692.0], [7151.0, 692.0], [7168.0, 692.0], [7182.0, 692.0], [7203.0, 692.0], [7218.0, 692.0], [7234.0, 762.0], [7250.0, 762.0], [7272.0, 762.0], [7289.0, 762.0], [7300.0, 762.0], [7316.0, 762.0], [7338.0, 768.0], [7352.0, 768.0], [7368.0, 768.0], [7384.0, 768.0], [7401.0, 768.0], [7412.0, 768.0], [7428.0, 768.0], [7439.0, 768.0], [7450.0, 768.0], [7472.0, 768.0], [7495.0, 768.0], [7516.0, 768.0], [7533.0, 774.0], [7555.0, 774.0], [7577.0, 774.0], [7587.0, 774.0], [7598.0, 774.0], [7614.0, 774.0], [7637.0, 771.0], [7645.0, 771.0], [7656.0, 771.0], [7672.0, 771.0], [7692.0, 771.0], [7710.0, 771.0], [7732.0, 756.0], [7743.0, 756.0], [7767.0, 756.0], [7785.0, 756.0], [7802.0, 756.0], [7813.0, 756.0], [7823.0, 754.0], [7840.0, 754.0], [7862.0, 754.0], [7884.0, 754.0], [7902.0, 754.0], [7913.0, 754.0], [7930.0, 744.0], [7941.0, 744.0], [7965.0, 744.0], [7985.0, 744.0], [8001.0, 744.0], [8017.0, 744.0], [8034.0, 722.0], [8056.0, 722.0], [8070.0, 722.0], [8081.0, 722.0], [8098.0, 722.0], [8113.0, 722.0], [8129.0, 705.0], [8140.0, 705.0], [8162.0, 705.0], [8183.0, 705.0], [8194.0, 705.0], [8210.0, 705.0], [8226.0, 705.0], [8237.0, 705.0], [8248.0, 705.0], [8259.0, 705.0], [8278.0, 705.0], [8295.0, 705.0], [8311.0, 705.0], [8327.0, 701.0], [8347.0, 701.0], [8369.0, 701.0], [8386.0, 701.0], [8393.0, 701.0], [8409.0, 701.0], [8426.0, 687.0], [8442.0, 687.0], [8464.0, 687.0], [8478.0, 687.0], [8494.0, 687.0], [8521.0, 687.0], [8543.0, 683.0], [8557.0, 683.0], [8573.0, 683.0], [8589.0, 683.0], [8606.0, 683.0], [8622.0, 683.0], [8639.0, 684.0], [8665.0, 684.0], [8682.0, 684.0], [8698.0, 684.0], [8715.0, 684.0], [8736.0, 678.0], [8753.0, 678.0], [8769.0, 678.0], [8791.0, 678.0], [8810.0, 678.0], [8821.0, 678.0], [8831.0, 678.0], [8839.0, 677.0], [8862.0, 677.0], [8879.0, 677.0], [8895.0, 677.0], [8906.0, 677.0], [8917.0, 677.0], [8933.0, 677.0], [8944.0, 678.0], [8961.0, 678.0], [8971.0, 678.0], [8988.0, 678.0], [9010.0, 678.0], [9026.0, 678.0], [9037.0, 678.0], [9048.0, 676.0], [9073.0, 676.0], [9084.0, 676.0], [9101.0, 676.0], [9117.0, 676.0], [9134.0, 676.0], [9150.0, 680.0], [9157.0, 680.0], [9173.0, 680.0], [9184.0, 680.0], [9199.0, 680.0], [9210.0, 680.0], [9221.0, 680.0], [9232.0, 680.0], [9248.0, 688.0], [9256.0, 688.0], [9272.0, 688.0], [9288.0, 688.0], [9306.0, 688.0], [9326.0, 688.0], [9343.0, 691.0], [9359.0, 691.0], [9379.0, 691.0], [9397.0, 691.0], [9419.0, 691.0], [9436.0, 691.0], [9458.0, 688.0], [9479.0, 688.0], [9490.0, 688.0], [9501.0, 688.0], [9520.0, 688.0], [9541.0, 688.0], [9562.0, 688.0], [9578.0, 700.0], [9594.0, 700.0], [9614.0, 700.0], [9631.0, 700.0], [9647.0, 700.0], [9656.0, 700.0], [9678.0, 721.0], [9694.0, 721.0], [9714.0, 721.0], [9731.0, 721.0], [9747.0, 721.0], [9759.0, 721.0], [9777.0, 721.0], [9787.0, 720.0], [9804.0, 720.0], [9820.0, 720.0], [9843.0, 720.0], [9860.0, 720.0], [9882.0, 720.0], [9898.0, 719.0], [9914.0, 719.0], [9938.0, 719.0], [9949.0, 719.0], [9959.0, 719.0], [9976.0, 719.0], [9998.0, 738.0], [10014.0, 738.0], [10028.0, 738.0], [10050.0, 738.0], [10066.0, 738.0], [10088.0, 738.0], [10110.0, 772.0], [10127.0, 772.0], [10144.0, 772.0], [10160.0, 772.0], [10171.0, 772.0], [10188.0, 772.0], [10199.0, 782.0], [10210.0, 782.0], [10231.0, 782.0], [10255.0, 782.0], [10271.0, 782.0], [10287.0, 782.0], [10304.0, 781.0], [10326.0, 781.0], [10340.0, 781.0], [10351.0, 781.0], [10373.0, 781.0], [10390.0, 781.0], [10406.0, 809.0], [10428.0, 809.0], [10447.0, 809.0], [10454.0, 809.0], [10470.0, 809.0], [10492.0, 809.0], [10503.0, 858.0], [10519.0, 858.0], [10530.0, 858.0], [10547.0, 858.0], [10568.0, 858.0], [10594.0, 858.0], [10611.0, 862.0], [10627.0, 862.0], [10649.0, 862.0], [10665.0, 862.0], [10676.0, 862.0], [10693.0, 862.0], [10709.0, 863.0], [10720.0, 863.0], [10742.0, 863.0], [10765.0, 863.0], [10776.0, 863.0], [10786.0, 863.0], [10803.0, 888.0], [10819.0, 888.0], [10830.0, 888.0], [10841.0, 888.0], [10863.0, 888.0], [10870.0, 888.0], [10887.0, 888.0], [10905.0, 975.0], [10922.0, 975.0], [10933.0, 975.0], [10955.0, 975.0], [10978.0, 975.0], [10996.0, 975.0], [11016.0, 1003.0], [11027.0, 1003.0], [11037.0, 1003.0], [11059.0, 1003.0], [11076.0, 1003.0], [11087.0, 1003.0], [11103.0, 1003.0], [11114.0, 999.0], [11130.0, 999.0], [11141.0, 999.0], [11156.0, 999.0], [11173.0, 999.0], [11184.0, 999.0], [11195.0, 999.0], [11207.0, 999.0], [11229.0, 1292.0], [11246.0, 1292.0], [11267.0, 1292.0], [11283.0, 1292.0], [11300.0, 1292.0], [11324.0, 1292.0], [11341.0, 2465.0], [11352.0, 2465.0], [11363.0, 2465.0], [11379.0, 2465.0], [11390.0, 2465.0], [11406.0, 2465.0], [11426.0, 2465.0], [11443.0, 2435.0], [11459.0, 2435.0], [11475.0, 2435.0], [11501.0, 2435.0], [11518.0, 2435.0], [11529.0, 2435.0], [11540.0, 2451.0], [11562.0, 2451.0], [11579.0, 2451.0], [11596.0, 2451.0], [11612.0, 2451.0], [11628.0, 2451.0], [11645.0, 2561.0], [11667.0, 2561.0], [11675.0, 2561.0], [11686.0, 2561.0], [11705.0, 2561.0], [11722.0, 2561.0], [11738.0, 2612.0], [11749.0, 2612.0], [11764.0, 2612.0], [11790.0, 2612.0], [11810.0, 2612.0], [11821.0, 2612.0], [11838.0, 2612.0], [11854.0, 2557.0], [11871.0, 2557.0], [11887.0, 2557.0], [11898.0, 2557.0], [11909.0, 2557.0], [11920.0, 2557.0], [11936.0, 2557.0], [11953.0, 2572.0], [11969.0, 2572.0], [11995.0, 2572.0], [12006.0, 2572.0], [12016.0, 2572.0], [12033.0, 2572.0], [12044.0, 2464.0], [12060.0, 2464.0], [12071.0, 2464.0], [12082.0, 2464.0], [12106.0, 2464.0], [12116.0, 2464.0], [12137.0, 2464.0], [12153.0, 2313.0], [12171.0, 2313.0], [12191.0, 2313.0], [12202.0, 2313.0], [12219.0, 2313.0], [12230.0, 2313.0], [12246.0, 2313.0], [12257.0, 2282.0], [12268.0, 2282.0], [12279.0, 2282.0], [12290.0, 2282.0], [12306.0, 2282.0], [12324.0, 2282.0], [12335.0, 2282.0], [12346.0, 2282.0], [12363.0, 2304.0], [12379.0, 2304.0], [12395.0, 2304.0], [12406.0, 2304.0], [12417.0, 2304.0], [12439.0, 2304.0], [12456.0, 2250.0], [12472.0, 2250.0], [12494.0, 2250.0], [12513.0, 2250.0], [12531.0, 2250.0], [12542.0, 2250.0], [12559.0, 2141.0], [12570.0, 2141.0], [12594.0, 2141.0], [12604.0, 2141.0], [12621.0, 2141.0], [12632.0, 2141.0], [12654.0, 2141.0], [12676.0, 2135.0], [12692.0, 2135.0], [12714.0, 2135.0], [12730.0, 2135.0], [12747.0, 2135.0], [12768.0, 2135.0], [12785.0, 2118.0], [12807.0, 2118.0], [12823.0, 2118.0], [12834.0, 2118.0], [12854.0, 2118.0], [12865.0, 2118.0], [12882.0, 1962.0], [12893.0, 1962.0], [12909.0, 1962.0], [12920.0, 1962.0], [12936.0, 1962.0], [12964.0, 1962.0], [12980.0, 1699.0], [13000.0, 1699.0], [13012.0, 1699.0], [13029.0, 1699.0], [13040.0, 1699.0], [13062.0, 1699.0], [13078.0, 1648.0], [13094.0, 1648.0], [13111.0, 1648.0], [13128.0, 1648.0], [13144.0, 1648.0], [13160.0, 1648.0], [13177.0, 1659.0], [13188.0, 1659.0], [13199.0, 1659.0], [13215.0, 1659.0], [13229.0, 1659.0], [13245.0, 1659.0], [13261.0, 1659.0], [13278.0, 1647.0], [13294.0, 1647.0], [13305.0, 1647.0], [13314.0, 1647.0], [13325.0, 1647.0], [13342.0, 1647.0], [13358.0, 1647.0], [13375.0, 1684.0], [13393.0, 1684.0], [13415.0, 1684.0], [13432.0, 1684.0], [13451.0, 1684.0], [13471.0, 1694.0], [13488.0, 1694.0], [13504.0, 1694.0], [13526.0, 1694.0], [13543.0, 1694.0], [13554.0, 1694.0], [13565.0, 1694.0], [13590.0, 1687.0], [13601.0, 1687.0], [13618.0, 1687.0], [13629.0, 1687.0], [13645.0, 1687.0], [13656.0, 1687.0], [13672.0, 1687.0], [13683.0, 1687.0], [13700.0, 1687.0], [13722.0, 1778.0], [13743.0, 1778.0], [13762.0, 1778.0], [13784.0, 1778.0], [13795.0, 1778.0], [13812.0, 1924.0], [13828.0, 1924.0], [13844.0, 1924.0], [13861.0, 1924.0], [13872.0, 1924.0], [13894.0, 1924.0], [13905.0, 2149.0], [13922.0, 2149.0], [13938.0, 2149.0], [13960.0, 2149.0], [13976.0, 2149.0], [13998.0, 2149.0], [14023.0, 2219.0], [14034.0, 2219.0], [14051.0, 2219.0], [14073.0, 2219.0], [14089.0, 2219.0], [14105.0, 2219.0], [14125.0, 2200.0], [14142.0, 2200.0], [14153.0, 2200.0], [14172.0, 2200.0], [14193.0, 2200.0], [14210.0, 2200.0], [14226.0, 2263.0], [14244.0, 2263.0], [14266.0, 2263.0], [14281.0, 2263.0], [14297.0, 2263.0], [14308.0, 2263.0], [14325.0, 2263.0], [14336.0, 2263.0], [14347.0, 2263.0], [14358.0, 2263.0], [14374.0, 2263.0], [14390.0, 2263.0], [14407.0, 2263.0], [14429.0, 2290.0], [14450.0, 2290.0], [14467.0, 2290.0], [14478.0, 2290.0], [14494.0, 2290.0], [14516.0, 2290.0], [14538.0, 2300.0], [14554.0, 2300.0], [14571.0, 2300.0], [14587.0, 2300.0], [14594.0, 2300.0], [14605.0, 2300.0], [14619.0, 2300.0], [14641.0, 2047.0], [14663.0, 2047.0], [14679.0, 2047.0], [14695.0, 2047.0], [14717.0, 2047.0], [14734.0, 1722.0], [14750.0, 1722.0], [14772.0, 1722.0], [14783.0, 1722.0], [14794.0, 1722.0], [14809.0, 1722.0], [14831.0, 1722.0], [14845.0, 1655.0], [14861.0, 1655.0], [14877.0, 1655.0], [14894.0, 1655.0], [14910.0, 1655.0], [14921.0, 1655.0], [14943.0, 1655.0], [14965.0, 1268.0], [14981.0, 1268.0], [15000.0, 1268.0], [15010.0, 1268.0], [15026.0, 1268.0], [15042.0, 1268.0], [15058.0, 1100.0], [15080.0, 1100.0], [15102.0, 1100.0], [15118.0, 1100.0], [15135.0, 1100.0], [15154.0, 1100.0], [15171.0, 1078.0], [15182.0, 1078.0], [15198.0, 1078.0], [15215.0, 1078.0], [15235.0, 1078.0], [15246.0, 1078.0], [15267.0, 1077.0], [15289.0, 1077.0], [15306.0, 1077.0], [15322.0, 1077.0], [15333.0, 1077.0], [15349.0, 1077.0], [15357.0, 1077.0], [15367.0, 1077.0], [15384.0, 1007.0], [15406.0, 1007.0], [15425.0, 1007.0], [15445.0, 1007.0], [15467.0, 1007.0], [15489.0, 956.0], [15505.0, 956.0], [15527.0, 956.0], [15544.0, 956.0], [15556.0, 956.0], [15567.0, 956.0], [15584.0, 958.0], [15595.0, 958.0], [15611.0, 958.0], [15633.0, 958.0], [15655.0, 958.0], [15671.0, 958.0], [15693.0, 948.0], [15715.0, 948.0], [15731.0, 948.0], [15748.0, 948.0], [15765.0, 948.0], [15787.0, 888.0], [15796.0, 888.0], [15812.0, 888.0], [15831.0, 888.0], [15851.0, 888.0], [15862.0, 888.0], [15872.0, 841.0], [15883.0, 841.0], [15894.0, 841.0], [15911.0, 841.0], [15927.0, 841.0], [15938.0, 841.0], [15955.0, 841.0], [15972.0, 837.0], [15988.0, 837.0], [16004.0, 837.0], [16021.0, 837.0], [16037.0, 837.0], [16059.0, 837.0], [16075.0, 837.0], [16100.0, 839.0], [16122.0, 839.0], [16133.0, 839.0], [16150.0, 839.0], [16176.0, 839.0], [16193.0, 850.0], [16204.0, 850.0], [16222.0, 850.0], [16244.0, 850.0], [16261.0, 850.0], [16277.0, 850.0], [16293.0, 891.0], [16304.0, 891.0], [16321.0, 891.0], [16337.0, 891.0], [16354.0, 891.0], [16377.0, 891.0], [16394.0, 894.0], [16405.0, 894.0], [16427.0, 894.0], [16448.0, 894.0], [16465.0, 894.0], [16481.0, 894.0], [16498.0, 908.0], [16520.0, 908.0], [16536.0, 908.0], [16547.0, 908.0], [16565.0, 908.0], [16577.0, 908.0], [16593.0, 1439.0], [16609.0, 1439.0], [16627.0, 1439.0], [16644.0, 1439.0], [16655.0, 1439.0], [16664.0, 1439.0], [16675.0, 1439.0], [16697.0, 1890.0], [16714.0, 1890.0], [16730.0, 1890.0], [16741.0, 1890.0], [16757.0, 1890.0], [16768.0, 1890.0], [16783.0, 1890.0], [16794.0, 1900.0], [16811.0, 1900.0], [16822.0, 1900.0], [16846.0, 1900.0], [16856.0, 1900.0], [16873.0, 1900.0], [16884.0, 1900.0], [16900.0, 1903.0], [16917.0, 1903.0], [16933.0, 1903.0], [16951.0, 1903.0], [16973.0, 1903.0], [16990.0, 1923.0], [17002.0, 1923.0], [17024.0, 1923.0], [17041.0, 1923.0], [17057.0, 1923.0], [17081.0, 1923.0], [17092.0, 1923.0], [17109.0, 1921.0], [17125.0, 1921.0], [17142.0, 1921.0], [17152.0, 1921.0], [17174.0, 1921.0], [17191.0, 1921.0], [17211.0, 1918.0], [17231.0, 1918.0], [17253.0, 1918.0], [17264.0, 1918.0], [17289.0, 1918.0], [17311.0, 1918.0], [17322.0, 1918.0], [17347.0, 1918.0], [17364.0, 1918.0], [17386.0, 1918.0], [17408.0, 1909.0], [17430.0, 1909.0], [17452.0, 1909.0], [17468.0, 1909.0], [17479.0, 1909.0], [17498.0, 1909.0], [17514.0, 1909.0], [17531.0, 1909.0], [17547.0, 1909.0], [17565.0, 1909.0], [17582.0, 1909.0], [17593.0, 1909.0], [17615.0, 1910.0], [17631.0, 1910.0], [17647.0, 1910.0], [17658.0, 1910.0], [17669.0, 1910.0], [17686.0, 1910.0], [17700.0, 1910.0], [17716.0, 1911.0], [17741.0, 1911.0], [17761.0, 1911.0], [17777.0, 1911.0], [17793.0, 1911.0], [17810.0, 1921.0], [17831.0, 1921.0], [17848.0, 1921.0], [17870.0, 1921.0], [17886.0, 1921.0], [17902.0, 1921.0], [17919.0, 1917.0], [17935.0, 1917.0], [17956.0, 1917.0], [17967.0, 1917.0], [17983.0, 1917.0], [17999.0, 1917.0], [18035.0, 1914.0]]
x1 = 0
y1 = 3
start = 0
end = 1010
theta = -0.08*np.pi

data = np.array(sensor_data)
time = data[start:end, 0]
tof1 = data[start:end, 1]

data03 = robot2global(tof1, x1, y1, theta)

plt.figure()
plt.scatter(data03[0], data03[1], s=1, c='green')  # s is size
plt.axis('equal')
plt.xlabel('x (m)')
plt.ylabel('y (m)')
plt.title(f'ToF Global Frame {x1}, {y1}')
plt.grid()
plt.show()

# %%
sensor_data = [[10.0, 1034.0], [26.0, 1034.0], [42.0, 1034.0], [59.0, 1034.0], [76.0, 1034.0], [98.0, 1034.0], [120.0, 593.0], [131.0, 593.0], [147.0, 593.0], [158.0, 593.0], [184.0, 593.0], [206.0, 593.0], [223.0, 1131.0], [245.0, 1131.0], [255.0, 1131.0], [273.0, 1131.0], [289.0, 1131.0], [300.0, 1131.0], [311.0, 1428.0], [327.0, 1428.0], [338.0, 1428.0], [355.0, 1428.0], [371.0, 1428.0], [393.0, 1428.0], [409.0, 1428.0], [420.0, 1445.0], [447.0, 1445.0], [468.0, 1445.0], [479.0, 1445.0], [489.0, 1445.0], [506.0, 1445.0], [517.0, 236.0], [542.0, 236.0], [553.0, 236.0], [570.0, 236.0], [586.0, 236.0], [603.0, 236.0], [625.0, 232.0], [649.0, 232.0], [666.0, 232.0], [673.0, 232.0], [689.0, 232.0], [696.0, 232.0], [713.0, 499.0], [724.0, 499.0], [741.0, 499.0], [763.0, 499.0], [779.0, 499.0], [796.0, 499.0], [817.0, 563.0], [839.0, 563.0], [853.0, 563.0], [869.0, 563.0], [885.0, 563.0], [907.0, 563.0], [924.0, 575.0], [940.0, 575.0], [956.0, 575.0], [974.0, 575.0], [985.0, 575.0], [1002.0, 575.0], [1013.0, 797.0], [1029.0, 797.0], [1045.0, 797.0], [1071.0, 797.0], [1091.0, 797.0], [1102.0, 797.0], [1118.0, 1214.0], [1128.0, 1214.0], [1145.0, 1214.0], [1155.0, 1214.0], [1172.0, 1214.0], [1183.0, 1214.0], [1199.0, 1214.0], [1210.0, 1280.0], [1221.0, 1280.0], [1239.0, 1280.0], [1260.0, 1280.0], [1282.0, 1280.0], [1304.0, 1280.0], [1326.0, 1662.0], [1342.0, 1662.0], [1353.0, 1662.0], [1364.0, 1662.0], [1375.0, 1662.0], [1392.0, 1662.0], [1413.0, 1662.0], [1435.0, 1516.0], [1443.0, 1516.0], [1465.0, 1516.0], [1484.0, 1516.0], [1506.0, 1516.0], [1523.0, 713.0], [1539.0, 713.0], [1555.0, 713.0], [1577.0, 713.0], [1594.0, 713.0], [1610.0, 713.0], [1621.0, 713.0], [1637.0, 716.0], [1648.0, 716.0], [1659.0, 716.0], [1681.0, 716.0], [1692.0, 716.0], [1703.0, 716.0], [1714.0, 716.0], [1730.0, 725.0], [1745.0, 725.0], [1767.0, 725.0], [1784.0, 725.0], [1795.0, 725.0], [1802.0, 725.0], [1818.0, 725.0], [1836.0, 673.0], [1858.0, 673.0], [1875.0, 673.0], [1882.0, 673.0], [1889.0, 673.0], [1906.0, 673.0], [1917.0, 673.0], [1934.0, 654.0], [1949.0, 654.0], [1965.0, 654.0], [1981.0, 654.0], [2003.0, 654.0], [2025.0, 654.0], [2041.0, 652.0], [2058.0, 652.0], [2074.0, 652.0], [2085.0, 652.0], [2102.0, 652.0], [2118.0, 652.0], [2129.0, 652.0], [2140.0, 652.0], [2162.0, 652.0], [2178.0, 652.0], [2200.0, 652.0], [2216.0, 652.0], [2229.0, 652.0], [2246.0, 648.0], [2262.0, 648.0], [2273.0, 648.0], [2284.0, 648.0], [2295.0, 648.0], [2311.0, 648.0], [2322.0, 648.0], [2339.0, 648.0], [2350.0, 647.0], [2366.0, 647.0], [2388.0, 647.0], [2404.0, 647.0], [2421.0, 647.0], [2437.0, 647.0], [2448.0, 647.0], [2465.0, 647.0], [2476.0, 647.0], [2487.0, 647.0], [2498.0, 647.0], [2508.0, 647.0], [2525.0, 647.0], [2541.0, 647.0], [2563.0, 646.0], [2577.0, 646.0], [2593.0, 646.0], [2609.0, 646.0], [2626.0, 646.0], [2648.0, 646.0], [2662.0, 649.0], [2678.0, 649.0], [2685.0, 649.0], [2701.0, 649.0], [2723.0, 649.0], [2748.0, 649.0], [2765.0, 657.0], [2776.0, 657.0], [2792.0, 657.0], [2809.0, 657.0], [2819.0, 657.0], [2836.0, 657.0], [2847.0, 657.0], [2858.0, 658.0], [2874.0, 658.0], [2891.0, 658.0], [2907.0, 658.0], [2929.0, 658.0], [2945.0, 658.0], [2962.0, 661.0], [2978.0, 661.0], [2989.0, 661.0], [3015.0, 661.0], [3032.0, 661.0], [3043.0, 661.0], [3064.0, 671.0], [3086.0, 671.0], [3112.0, 671.0], [3132.0, 671.0], [3148.0, 671.0], [3158.0, 680.0], [3175.0, 680.0], [3185.0, 680.0], [3207.0, 680.0], [3224.0, 680.0], [3235.0, 680.0], [3246.0, 680.0], [3257.0, 687.0], [3284.0, 687.0], [3300.0, 687.0], [3311.0, 687.0], [3328.0, 687.0], [3349.0, 687.0], [3366.0, 687.0], [3377.0, 687.0], [3388.0, 687.0], [3406.0, 687.0], [3427.0, 687.0], [3444.0, 687.0], [3460.0, 710.0], [3477.0, 710.0], [3495.0, 710.0], [3512.0, 710.0], [3523.0, 710.0], [3535.0, 710.0], [3553.0, 710.0], [3563.0, 710.0], [3580.0, 731.0], [3591.0, 731.0], [3602.0, 731.0], [3613.0, 731.0], [3629.0, 731.0], [3651.0, 731.0], [3673.0, 731.0], [3689.0, 732.0], [3709.0, 732.0], [3730.0, 732.0], [3747.0, 732.0], [3758.0, 732.0], [3774.0, 732.0], [3785.0, 741.0], [3811.0, 741.0], [3828.0, 741.0], [3844.0, 741.0], [3861.0, 741.0], [3878.0, 741.0], [3900.0, 799.0], [3916.0, 799.0], [3932.0, 799.0], [3954.0, 799.0], [3974.0, 799.0], [3991.0, 816.0], [4007.0, 816.0], [4026.0, 816.0], [4046.0, 816.0], [4066.0, 816.0], [4077.0, 816.0], [4094.0, 819.0], [4105.0, 819.0], [4121.0, 819.0], [4143.0, 819.0], [4159.0, 819.0], [4176.0, 819.0], [4187.0, 830.0], [4212.0, 830.0], [4223.0, 830.0], [4240.0, 830.0], [4251.0, 830.0], [4266.0, 830.0], [4287.0, 830.0], [4308.0, 876.0], [4319.0, 876.0], [4329.0, 876.0], [4340.0, 876.0], [4352.0, 876.0], [4370.0, 876.0], [4391.0, 876.0], [4402.0, 880.0], [4413.0, 880.0], [4424.0, 880.0], [4438.0, 880.0], [4456.0, 880.0], [4478.0, 880.0], [4493.0, 880.0], [4509.0, 884.0], [4525.0, 884.0], [4547.0, 884.0], [4569.0, 884.0], [4585.0, 884.0], [4605.0, 884.0], [4627.0, 881.0], [4646.0, 881.0], [4656.0, 881.0], [4673.0, 881.0], [4684.0, 881.0], [4696.0, 881.0], [4719.0, 845.0], [4739.0, 845.0], [4756.0, 845.0], [4767.0, 845.0], [4774.0, 845.0], [4790.0, 845.0], [4808.0, 845.0], [4828.0, 845.0], [4845.0, 805.0], [4861.0, 805.0], [4878.0, 805.0], [4899.0, 805.0], [4917.0, 805.0], [4938.0, 805.0], [4949.0, 806.0], [4960.0, 806.0], [4977.0, 806.0], [4991.0, 806.0], [5009.0, 806.0], [5030.0, 806.0], [5047.0, 788.0], [5063.0, 788.0], [5080.0, 788.0], [5096.0, 788.0], [5114.0, 788.0], [5125.0, 788.0], [5134.0, 788.0], [5150.0, 788.0], [5161.0, 752.0], [5184.0, 752.0], [5195.0, 752.0], [5205.0, 752.0], [5216.0, 752.0], [5227.0, 752.0], [5244.0, 752.0], [5260.0, 745.0], [5277.0, 745.0], [5287.0, 745.0], [5303.0, 745.0], [5315.0, 745.0], [5339.0, 745.0], [5357.0, 742.0], [5375.0, 742.0], [5395.0, 742.0], [5417.0, 742.0], [5432.0, 742.0], [5448.0, 742.0], [5464.0, 729.0], [5486.0, 729.0], [5508.0, 729.0], [5530.0, 729.0], [5557.0, 729.0], [5579.0, 707.0], [5601.0, 707.0], [5617.0, 707.0], [5639.0, 707.0], [5653.0, 707.0], [5669.0, 707.0], [5685.0, 700.0], [5707.0, 700.0], [5732.0, 700.0], [5749.0, 700.0], [5765.0, 700.0], [5787.0, 700.0], [5803.0, 700.0], [5825.0, 700.0], [5842.0, 700.0], [5858.0, 700.0], [5875.0, 700.0], [5896.0, 694.0], [5918.0, 694.0], [5944.0, 694.0], [5964.0, 694.0], [5975.0, 694.0], [5992.0, 688.0], [6008.0, 688.0], [6023.0, 688.0], [6040.0, 688.0], [6051.0, 688.0], [6062.0, 688.0], [6078.0, 688.0], [6089.0, 688.0], [6111.0, 688.0], [6133.0, 688.0], [6149.0, 688.0], [6169.0, 688.0], [6187.0, 688.0], [6213.0, 687.0], [6231.0, 687.0], [6249.0, 687.0], [6270.0, 687.0], [6292.0, 687.0], [6309.0, 684.0], [6320.0, 684.0], [6331.0, 684.0], [6347.0, 684.0], [6358.0, 684.0], [6383.0, 684.0], [6394.0, 684.0], [6411.0, 684.0], [6422.0, 684.0], [6438.0, 684.0], [6449.0, 684.0], [6465.0, 684.0], [6482.0, 684.0], [6493.0, 684.0], [6505.0, 686.0], [6525.0, 686.0], [6542.0, 686.0], [6558.0, 686.0], [6569.0, 686.0], [6585.0, 686.0], [6602.0, 686.0], [6613.0, 689.0], [6634.0, 689.0], [6645.0, 689.0], [6656.0, 689.0], [6673.0, 689.0], [6689.0, 689.0], [6700.0, 689.0], [6716.0, 690.0], [6733.0, 690.0], [6745.0, 690.0], [6766.0, 690.0], [6788.0, 690.0], [6808.0, 690.0], [6819.0, 693.0], [6836.0, 693.0], [6863.0, 693.0], [6879.0, 693.0], [6895.0, 693.0], [6907.0, 693.0], [6918.0, 699.0], [6934.0, 699.0], [6949.0, 699.0], [6971.0, 699.0], [6982.0, 699.0], [6999.0, 699.0], [7020.0, 699.0], [7043.0, 708.0], [7059.0, 708.0], [7075.0, 708.0], [7092.0, 708.0], [7108.0, 708.0], [7119.0, 708.0], [7135.0, 725.0], [7152.0, 725.0], [7168.0, 725.0], [7179.0, 725.0], [7195.0, 725.0], [7215.0, 725.0], [7235.0, 740.0], [7246.0, 740.0], [7262.0, 740.0], [7284.0, 740.0], [7300.0, 740.0], [7317.0, 740.0], [7333.0, 746.0], [7344.0, 746.0], [7360.0, 746.0], [7377.0, 746.0], [7393.0, 746.0], [7409.0, 746.0], [7420.0, 746.0], [7446.0, 747.0], [7468.0, 747.0], [7479.0, 747.0], [7496.0, 747.0], [7512.0, 747.0], [7528.0, 747.0], [7545.0, 761.0], [7556.0, 761.0], [7574.0, 761.0], [7594.0, 761.0], [7610.0, 761.0], [7628.0, 761.0], [7638.0, 781.0], [7655.0, 781.0], [7667.0, 781.0], [7683.0, 781.0], [7694.0, 781.0], [7705.0, 781.0], [7721.0, 781.0], [7736.0, 798.0], [7758.0, 798.0], [7775.0, 798.0], [7791.0, 798.0], [7806.0, 798.0], [7817.0, 798.0], [7834.0, 801.0], [7845.0, 801.0], [7856.0, 801.0], [7867.0, 801.0], [7885.0, 801.0], [7896.0, 801.0], [7913.0, 801.0], [7929.0, 817.0], [7946.0, 817.0], [7956.0, 817.0], [7967.0, 817.0], [7989.0, 817.0], [8006.0, 817.0], [8028.0, 817.0], [8044.0, 849.0], [8068.0, 849.0], [8089.0, 849.0], [8106.0, 849.0], [8117.0, 849.0], [8128.0, 849.0], [8147.0, 873.0], [8167.0, 873.0], [8184.0, 873.0], [8195.0, 873.0], [8206.0, 873.0], [8222.0, 873.0], [8238.0, 871.0], [8249.0, 871.0], [8271.0, 871.0], [8282.0, 871.0], [8293.0, 871.0], [8310.0, 871.0], [8326.0, 871.0], [8348.0, 913.0], [8364.0, 913.0], [8371.0, 913.0], [8388.0, 913.0], [8399.0, 913.0], [8424.0, 913.0], [8435.0, 962.0], [8452.0, 962.0], [8463.0, 962.0], [8479.0, 962.0], [8490.0, 962.0], [8510.0, 962.0], [8527.0, 962.0], [8538.0, 967.0], [8549.0, 967.0], [8565.0, 967.0], [8580.0, 967.0], [8598.0, 967.0], [8615.0, 967.0], [8626.0, 967.0], [8645.0, 968.0], [8665.0, 968.0], [8685.0, 968.0], [8696.0, 968.0], [8713.0, 968.0], [8729.0, 968.0], [8746.0, 971.0], [8762.0, 971.0], [8784.0, 971.0], [8799.0, 971.0], [8815.0, 971.0], [8831.0, 971.0], [8841.0, 943.0], [8865.0, 943.0], [8885.0, 943.0], [8896.0, 943.0], [8913.0, 943.0], [8924.0, 943.0], [8940.0, 943.0], [8951.0, 920.0], [8978.0, 920.0], [8995.0, 920.0], [9011.0, 920.0], [9028.0, 920.0], [9038.0, 920.0], [9064.0, 917.0], [9075.0, 917.0], [9092.0, 917.0], [9103.0, 917.0], [9114.0, 917.0], [9130.0, 917.0], [9148.0, 917.0], [9167.0, 860.0], [9184.0, 860.0], [9199.0, 860.0], [9210.0, 860.0], [9220.0, 860.0], [9237.0, 860.0], [9248.0, 860.0], [9264.0, 803.0], [9281.0, 803.0], [9292.0, 803.0], [9302.0, 803.0], [9313.0, 803.0], [9332.0, 803.0], [9343.0, 803.0], [9365.0, 806.0], [9382.0, 806.0], [9398.0, 806.0], [9409.0, 806.0], [9425.0, 806.0], [9442.0, 806.0], [9453.0, 807.0], [9479.0, 807.0], [9496.0, 807.0], [9512.0, 807.0], [9529.0, 807.0], [9545.0, 807.0], [9556.0, 777.0], [9572.0, 777.0], [9594.0, 777.0], [9601.0, 777.0], [9623.0, 777.0], [9640.0, 777.0], [9656.0, 737.0], [9672.0, 737.0], [9689.0, 737.0], [9706.0, 737.0], [9717.0, 737.0], [9728.0, 737.0], [9744.0, 737.0], [9759.0, 736.0], [9776.0, 736.0], [9792.0, 736.0], [9809.0, 736.0], [9830.0, 736.0], [9852.0, 736.0], [9869.0, 734.0], [9887.0, 734.0], [9905.0, 734.0], [9922.0, 734.0], [9938.0, 734.0], [9949.0, 734.0], [9960.0, 734.0], [9986.0, 722.0], [10008.0, 722.0], [10019.0, 722.0], [10044.0, 722.0], [10055.0, 722.0], [10072.0, 713.0], [10083.0, 713.0], [10099.0, 713.0], [10110.0, 713.0], [10126.0, 713.0], [10143.0, 713.0], [10154.0, 713.0], [10165.0, 704.0], [10178.0, 704.0], [10199.0, 704.0], [10216.0, 704.0], [10232.0, 704.0], [10249.0, 704.0], [10265.0, 703.0], [10287.0, 703.0], [10310.0, 703.0], [10326.0, 703.0], [10342.0, 703.0], [10364.0, 703.0], [10392.0, 698.0], [10413.0, 698.0], [10430.0, 698.0], [10447.0, 698.0], [10468.0, 698.0], [10490.0, 691.0], [10504.0, 691.0], [10520.0, 691.0], [10536.0, 691.0], [10553.0, 691.0], [10575.0, 691.0], [10591.0, 686.0], [10602.0, 686.0], [10616.0, 686.0], [10638.0, 686.0], [10660.0, 686.0], [10676.0, 686.0], [10692.0, 680.0], [10709.0, 680.0], [10731.0, 680.0], [10747.0, 680.0], [10758.0, 680.0], [10769.0, 680.0], [10791.0, 680.0], [10813.0, 682.0], [10835.0, 682.0], [10856.0, 682.0], [10873.0, 682.0], [10889.0, 682.0], [10908.0, 682.0], [10918.0, 682.0], [10935.0, 682.0], [10946.0, 682.0], [10962.0, 682.0], [10979.0, 682.0], [10995.0, 682.0], [11006.0, 682.0], [11017.0, 682.0], [11044.0, 682.0], [11061.0, 682.0], [11072.0, 682.0], [11082.0, 682.0], [11099.0, 682.0], [11110.0, 681.0], [11136.0, 681.0], [11147.0, 681.0], [11158.0, 681.0], [11169.0, 681.0], [11186.0, 681.0], [11204.0, 681.0], [11224.0, 688.0], [11235.0, 688.0], [11252.0, 688.0], [11268.0, 688.0], [11285.0, 688.0], [11306.0, 688.0], [11328.0, 692.0], [11345.0, 692.0], [11361.0, 692.0], [11383.0, 692.0], [11399.0, 692.0], [11410.0, 692.0], [11422.0, 692.0], [11440.0, 692.0], [11461.0, 692.0], [11478.0, 692.0], [11494.0, 692.0], [11511.0, 692.0], [11527.0, 694.0], [11549.0, 694.0], [11571.0, 694.0], [11590.0, 694.0], [11607.0, 694.0], [11623.0, 704.0], [11640.0, 704.0], [11654.0, 704.0], [11671.0, 704.0], [11691.0, 704.0], [11708.0, 704.0], [11730.0, 720.0], [11752.0, 720.0], [11774.0, 720.0], [11790.0, 720.0], [11807.0, 720.0], [11829.0, 720.0], [11851.0, 720.0], [11872.0, 720.0], [11889.0, 720.0], [11905.0, 720.0], [11916.0, 720.0], [11932.0, 720.0], [11946.0, 720.0], [11956.0, 720.0], [11978.0, 720.0], [12000.0, 720.0], [12017.0, 735.0], [12033.0, 735.0], [12050.0, 735.0], [12061.0, 735.0], [12078.0, 735.0], [12093.0, 735.0], [12109.0, 735.0], [12125.0, 750.0], [12142.0, 750.0], [12159.0, 750.0], [12170.0, 750.0], [12192.0, 750.0], [12204.0, 750.0], [12221.0, 788.0], [12237.0, 788.0], [12259.0, 788.0], [12281.0, 788.0], [12303.0, 788.0], [12319.0, 807.0], [12335.0, 807.0], [12352.0, 807.0], [12375.0, 807.0], [12395.0, 807.0], [12415.0, 807.0], [12432.0, 826.0], [12443.0, 826.0], [12459.0, 826.0], [12476.0, 826.0], [12497.0, 826.0], [12514.0, 826.0], [12525.0, 844.0], [12542.0, 844.0], [12561.0, 844.0], [12583.0, 844.0], [12600.0, 844.0], [12616.0, 844.0], [12630.0, 848.0], [12641.0, 848.0], [12652.0, 848.0], [12669.0, 848.0], [12682.0, 848.0], [12698.0, 848.0], [12709.0, 848.0], [12725.0, 862.0], [12736.0, 862.0], [12753.0, 862.0], [12769.0, 862.0], [12791.0, 862.0], [12805.0, 862.0], [12821.0, 862.0], [12837.0, 863.0], [12854.0, 863.0], [12876.0, 863.0], [12892.0, 863.0], [12919.0, 863.0], [12941.0, 860.0], [12958.0, 860.0], [12969.0, 860.0], [12985.0, 860.0], [12996.0, 860.0], [13007.0, 860.0], [13018.0, 860.0], [13034.0, 845.0], [13045.0, 845.0], [13061.0, 845.0], [13072.0, 845.0], [13083.0, 845.0], [13094.0, 845.0], [13111.0, 845.0], [13127.0, 821.0], [13139.0, 821.0], [13159.0, 821.0], [13181.0, 821.0], [13192.0, 821.0], [13220.0, 821.0], [13236.0, 779.0], [13252.0, 779.0], [13269.0, 779.0], [13280.0, 779.0], [13305.0, 779.0], [13322.0, 779.0], [13338.0, 779.0], [13355.0, 739.0], [13371.0, 739.0], [13393.0, 739.0], [13407.0, 739.0], [13423.0, 739.0], [13439.0, 739.0], [13456.0, 727.0], [13467.0, 727.0], [13483.0, 727.0], [13500.0, 727.0], [13510.0, 727.0], [13521.0, 727.0], [13543.0, 727.0], [13560.0, 713.0], [13581.0, 713.0], [13598.0, 713.0], [13620.0, 713.0], [13642.0, 713.0], [13658.0, 697.0], [13674.0, 697.0], [13691.0, 697.0], [13713.0, 697.0], [13729.0, 697.0], [13740.0, 697.0], [13751.0, 681.0], [13769.0, 681.0], [13790.0, 681.0], [13807.0, 681.0], [13823.0, 681.0], [13840.0, 681.0], [13856.0, 666.0], [13872.0, 666.0], [13889.0, 666.0], [13913.0, 666.0], [13933.0, 666.0], [13949.0, 666.0], [13965.0, 651.0], [13987.0, 651.0], [14013.0, 651.0], [14032.0, 651.0], [14054.0, 651.0], [14071.0, 638.0], [14087.0, 638.0], [14098.0, 638.0], [14111.0, 638.0], [14129.0, 638.0], [14146.0, 638.0], [14157.0, 638.0], [14168.0, 633.0], [14179.0, 633.0], [14201.0, 633.0], [14217.0, 633.0], [14234.0, 633.0], [14256.0, 633.0], [14272.0, 628.0], [14289.0, 628.0], [14305.0, 628.0], [14322.0, 628.0], [14344.0, 628.0], [14359.0, 628.0], [14375.0, 625.0], [14391.0, 625.0], [14408.0, 625.0], [14419.0, 625.0], [14445.0, 625.0], [14462.0, 625.0], [14478.0, 625.0], [14498.0, 625.0], [14516.0, 625.0], [14536.0, 625.0], [14558.0, 625.0], [14575.0, 626.0], [14591.0, 626.0], [14608.0, 626.0], [14624.0, 626.0], [14640.0, 626.0], [14657.0, 626.0], [14668.0, 628.0], [14679.0, 628.0], [14690.0, 628.0], [14706.0, 628.0], [14717.0, 628.0], [14728.0, 628.0], [14750.0, 628.0], [14772.0, 628.0], [14788.0, 626.0], [14814.0, 626.0], [14831.0, 626.0], [14847.0, 626.0], [14858.0, 626.0], [14869.0, 626.0], [14895.0, 627.0], [14906.0, 627.0], [14923.0, 627.0], [14934.0, 627.0], [14950.0, 627.0], [14961.0, 627.0], [14977.0, 627.0], [14988.0, 637.0], [15005.0, 637.0], [15016.0, 637.0], [15032.0, 637.0], [15043.0, 637.0], [15054.0, 637.0], [15065.0, 637.0], [15081.0, 637.0], [15093.0, 637.0], [15103.0, 637.0], [15120.0, 637.0], [15145.0, 637.0], [15156.0, 637.0], [15173.0, 637.0], [15184.0, 637.0], [15195.0, 309.0], [15210.0, 309.0], [15232.0, 309.0], [15247.0, 309.0], [15263.0, 309.0], [15274.0, 309.0], [15296.0, 309.0], [15313.0, 449.0], [15324.0, 449.0], [15340.0, 449.0], [15356.0, 449.0], [15367.0, 449.0], [15384.0, 449.0], [15395.0, 449.0], [15411.0, 735.0], [15427.0, 735.0], [15444.0, 735.0], [15455.0, 735.0], [15466.0, 735.0], [15477.0, 735.0], [15493.0, 735.0], [15504.0, 753.0], [15520.0, 753.0], [15540.0, 753.0], [15557.0, 753.0], [15573.0, 753.0], [15589.0, 753.0], [15615.0, 612.0], [15635.0, 612.0], [15646.0, 612.0], [15671.0, 612.0], [15691.0, 612.0], [15708.0, 842.0], [15719.0, 842.0], [15730.0, 842.0], [15752.0, 842.0], [15762.0, 842.0], [15779.0, 842.0], [15790.0, 842.0], [15816.0, 1422.0], [15833.0, 1422.0], [15844.0, 1422.0], [15855.0, 1422.0], [15877.0, 1422.0], [15893.0, 1422.0], [15909.0, 839.0], [15920.0, 839.0], [15946.0, 839.0], [15963.0, 839.0], [15974.0, 839.0], [15991.0, 839.0], [16006.0, 1547.0], [16022.0, 1547.0], [16042.0, 1547.0], [16064.0, 1547.0], [16081.0, 1547.0], [16100.0, 1547.0], [16111.0, 1378.0], [16132.0, 1378.0], [16149.0, 1378.0], [16165.0, 1378.0], [16182.0, 1378.0], [16198.0, 1378.0], [16214.0, 1459.0], [16225.0, 1459.0], [16236.0, 1459.0], [16247.0, 1459.0], [16264.0, 1459.0], [16285.0, 1459.0], [16307.0, 1459.0], [16324.0, 1464.0], [16340.0, 1464.0], [16357.0, 1464.0], [16373.0, 1464.0], [16389.0, 1464.0], [16406.0, 1464.0], [16422.0, 1422.0], [16447.0, 1422.0], [16467.0, 1422.0], [16484.0, 1422.0], [16495.0, 1422.0], [16514.0, 1422.0], [16531.0, 1498.0], [16547.0, 1498.0], [16563.0, 1498.0], [16580.0, 1498.0], [16596.0, 1498.0], [16607.0, 1498.0], [16623.0, 1480.0], [16640.0, 1480.0], [16658.0, 1480.0], [16680.0, 1480.0], [16691.0, 1480.0], [16702.0, 1480.0], [16713.0, 1480.0], [16729.0, 1480.0], [16744.0, 1420.0], [16766.0, 1420.0], [16788.0, 1420.0], [16808.0, 1420.0], [16829.0, 1420.0], [16851.0, 1476.0], [16868.0, 1476.0], [16879.0, 1476.0], [16903.0, 1476.0], [16924.0, 1476.0], [16941.0, 1449.0], [16952.0, 1449.0], [16963.0, 1449.0], [16982.0, 1449.0], [17002.0, 1449.0], [17019.0, 1449.0], [17030.0, 1493.0], [17041.0, 1493.0], [17057.0, 1493.0], [17079.0, 1493.0], [17101.0, 1493.0], [17117.0, 1493.0], [17134.0, 1516.0], [17145.0, 1516.0], [17161.0, 1516.0], [17183.0, 1516.0], [17199.0, 1516.0], [17216.0, 1516.0], [17233.0, 1495.0], [17255.0, 1495.0], [17266.0, 1495.0], [17283.0, 1495.0], [17309.0, 1495.0], [17329.0, 856.0], [17349.0, 856.0], [17367.0, 856.0], [17378.0, 856.0], [17390.0, 856.0], [17400.0, 856.0], [17417.0, 856.0], [17428.0, 613.0], [17450.0, 613.0], [17472.0, 613.0], [17488.0, 613.0], [17507.0, 613.0], [17528.0, 613.0], [17545.0, 282.0], [17561.0, 282.0], [17572.0, 282.0], [17583.0, 282.0], [17602.0, 282.0], [17622.0, 282.0], [17639.0, 170.0], [17650.0, 170.0], [17661.0, 170.0], [17677.0, 170.0], [17699.0, 170.0], [17721.0, 170.0], [17741.0, 135.0], [17761.0, 135.0], [17772.0, 135.0], [17789.0, 135.0], [17800.0, 135.0], [17814.0, 135.0], [17832.0, 135.0], [17854.0, 160.0], [17876.0, 160.0], [17901.0, 160.0], [17912.0, 160.0], [17929.0, 160.0], [17940.0, 214.0], [17956.0, 214.0], [17972.0, 214.0], [17988.0, 214.0], [18016.0, 214.0]]
x1 = -3
y1 = -2
start = 40
end = 1104
theta = 0.31*np.pi

data = np.array(sensor_data)
time = data[start:end, 0]
tof1 = data[start:end, 1]

data_3_2 = robot2global(tof1, x1, y1, theta)

plt.figure()
plt.scatter(data_3_2[0], data_3_2[1], s=1, c='purple')  # s is size
plt.axis('equal')
plt.xlabel('x (m)')
plt.ylabel('y (m)')
plt.title(f'ToF Global Frame {x1}, {y1}')
plt.grid()
plt.show()

# %%
sensor_data = [[19.0, 378.0], [35.0, 378.0], [52.0, 378.0], [68.0, 378.0], [95.0, 378.0], [117.0, 378.0], [139.0, 380.0], [161.0, 380.0], [188.0, 380.0], [205.0, 380.0], [220.0, 380.0], [240.0, 380.0], [258.0, 380.0], [274.0, 380.0], [293.0, 380.0], [313.0, 380.0], [333.0, 380.0], [343.0, 397.0], [364.0, 397.0], [380.0, 397.0], [397.0, 397.0], [413.0, 397.0], [429.0, 397.0], [442.0, 427.0], [464.0, 427.0], [486.0, 427.0], [505.0, 427.0], [523.0, 427.0], [542.0, 427.0], [552.0, 445.0], [570.0, 445.0], [586.0, 445.0], [608.0, 445.0], [628.0, 445.0], [645.0, 445.0], [661.0, 475.0], [683.0, 475.0], [705.0, 475.0], [727.0, 475.0], [749.0, 475.0], [767.0, 477.0], [789.0, 477.0], [810.0, 477.0], [830.0, 477.0], [841.0, 477.0], [851.0, 477.0], [868.0, 477.0], [895.0, 477.0], [914.0, 477.0], [930.0, 477.0], [952.0, 477.0], [968.0, 490.0], [990.0, 490.0], [1006.0, 490.0], [1032.0, 490.0], [1043.0, 490.0], [1060.0, 490.0], [1077.0, 536.0], [1099.0, 536.0], [1125.0, 536.0], [1137.0, 536.0], [1145.0, 536.0], [1163.0, 536.0], [1183.0, 550.0], [1205.0, 550.0], [1218.0, 550.0], [1239.0, 550.0], [1261.0, 550.0], [1281.0, 554.0], [1301.0, 554.0], [1321.0, 554.0], [1338.0, 554.0], [1348.0, 554.0], [1374.0, 554.0], [1385.0, 569.0], [1401.0, 569.0], [1417.0, 569.0], [1439.0, 569.0], [1449.0, 569.0], [1465.0, 569.0], [1481.0, 569.0], [1498.0, 635.0], [1520.0, 635.0], [1542.0, 635.0], [1563.0, 635.0], [1583.0, 635.0], [1594.0, 651.0], [1610.0, 651.0], [1621.0, 651.0], [1637.0, 651.0], [1648.0, 651.0], [1665.0, 651.0], [1681.0, 651.0], [1697.0, 655.0], [1719.0, 655.0], [1732.0, 655.0], [1750.0, 655.0], [1770.0, 655.0], [1781.0, 655.0], [1798.0, 679.0], [1820.0, 679.0], [1843.0, 679.0], [1862.0, 679.0], [1872.0, 679.0], [1898.0, 772.0], [1916.0, 772.0], [1936.0, 772.0], [1958.0, 772.0], [1969.0, 772.0], [1989.0, 772.0], [2009.0, 772.0], [2020.0, 830.0], [2037.0, 830.0], [2053.0, 830.0], [2075.0, 830.0], [2091.0, 830.0], [2117.0, 830.0], [2137.0, 830.0], [2159.0, 830.0], [2181.0, 830.0], [2198.0, 830.0], [2214.0, 830.0], [2230.0, 929.0], [2248.0, 929.0], [2267.0, 929.0], [2283.0, 929.0], [2303.0, 929.0], [2323.0, 929.0], [2341.0, 1084.0], [2361.0, 1084.0], [2383.0, 1084.0], [2396.0, 1084.0], [2414.0, 1084.0], [2433.0, 1084.0], [2443.0, 1147.0], [2466.0, 1147.0], [2482.0, 1147.0], [2504.0, 1147.0], [2529.0, 1147.0], [2539.0, 1138.0], [2565.0, 1138.0], [2585.0, 1138.0], [2603.0, 1138.0], [2614.0, 1138.0], [2631.0, 1138.0], [2653.0, 1350.0], [2678.0, 1350.0], [2696.0, 1350.0], [2713.0, 1350.0], [2723.0, 1350.0], [2739.0, 1350.0], [2761.0, 2051.0], [2783.0, 2051.0], [2805.0, 2051.0], [2826.0, 2051.0], [2843.0, 2051.0], [2865.0, 2128.0], [2881.0, 2128.0], [2907.0, 2128.0], [2927.0, 2128.0], [2938.0, 2128.0], [2954.0, 2136.0], [2965.0, 2136.0], [2992.0, 2136.0], [3014.0, 2136.0], [3033.0, 2136.0], [3044.0, 2195.0], [3060.0, 2195.0], [3071.0, 2195.0], [3087.0, 2195.0], [3098.0, 2195.0], [3115.0, 2195.0], [3131.0, 2195.0], [3147.0, 2252.0], [3169.0, 2252.0], [3182.0, 2252.0], [3200.0, 2252.0], [3220.0, 2252.0], [3242.0, 2252.0], [3255.0, 2274.0], [3273.0, 2274.0], [3292.0, 2274.0], [3302.0, 2274.0], [3328.0, 2274.0], [3348.0, 2274.0], [3366.0, 2291.0], [3383.0, 2291.0], [3405.0, 2291.0], [3431.0, 2291.0], [3449.0, 2291.0], [3468.0, 2288.0], [3478.0, 2288.0], [3506.0, 2288.0], [3528.0, 2288.0], [3544.0, 2288.0], [3566.0, 2293.0], [3577.0, 2293.0], [3588.0, 2293.0], [3605.0, 2293.0], [3627.0, 2293.0], [3648.0, 2293.0], [3667.0, 2329.0], [3677.0, 2329.0], [3694.0, 2329.0], [3710.0, 2329.0], [3727.0, 2329.0], [3738.0, 2329.0], [3765.0, 2326.0], [3787.0, 2326.0], [3803.0, 2326.0], [3825.0, 2326.0], [3847.0, 2326.0], [3858.0, 2326.0], [3884.0, 2326.0], [3906.0, 2330.0], [3923.0, 2330.0], [3950.0, 2330.0], [3975.0, 2330.0], [3995.0, 2330.0], [4017.0, 2399.0], [4027.0, 2399.0], [4049.0, 2399.0], [4075.0, 2399.0], [4095.0, 2399.0], [4117.0, 2459.0], [4139.0, 2459.0], [4165.0, 2459.0], [4185.0, 2459.0], [4206.0, 2459.0], [4228.0, 2457.0], [4250.0, 2457.0], [4275.0, 2457.0], [4295.0, 2457.0], [4316.0, 2457.0], [4333.0, 2728.0], [4355.0, 2728.0], [4377.0, 2728.0], [4398.0, 2728.0], [4418.0, 2728.0], [4427.0, 3156.0], [4449.0, 3156.0], [4465.0, 3156.0], [4481.0, 3156.0], [4498.0, 3156.0], [4513.0, 3156.0], [4533.0, 3017.0], [4555.0, 3017.0], [4577.0, 3017.0], [4603.0, 3017.0], [4623.0, 3017.0], [4644.0, 2690.0], [4661.0, 2690.0], [4683.0, 2690.0], [4696.0, 2690.0], [4714.0, 2690.0], [4734.0, 2690.0], [4745.0, 1000.0], [4762.0, 1000.0], [4778.0, 1000.0], [4795.0, 1000.0], [4816.0, 1000.0], [4834.0, 1000.0], [4855.0, 764.0], [4875.0, 764.0], [4886.0, 764.0], [4902.0, 764.0], [4918.0, 764.0], [4929.0, 764.0], [4946.0, 743.0], [4961.0, 743.0], [4979.0, 743.0], [4999.0, 743.0], [5021.0, 743.0], [5038.0, 743.0], [5049.0, 736.0], [5065.0, 736.0], [5087.0, 736.0], [5109.0, 736.0], [5132.0, 736.0], [5151.0, 694.0], [5161.0, 694.0], [5177.0, 694.0], [5199.0, 694.0], [5209.0, 694.0], [5225.0, 694.0], [5236.0, 651.0], [5253.0, 651.0], [5269.0, 651.0], [5291.0, 651.0], [5313.0, 651.0], [5335.0, 651.0], [5351.0, 645.0], [5370.0, 645.0], [5390.0, 645.0], [5407.0, 645.0], [5423.0, 645.0], [5445.0, 645.0], [5467.0, 635.0], [5493.0, 635.0], [5513.0, 635.0], [5533.0, 635.0], [5554.0, 635.0], [5565.0, 573.0], [5587.0, 573.0], [5611.0, 573.0], [5632.0, 573.0], [5654.0, 573.0], [5671.0, 547.0], [5686.0, 547.0], [5708.0, 547.0], [5734.0, 547.0], [5754.0, 547.0], [5773.0, 549.0], [5783.0, 549.0], [5809.0, 549.0], [5829.0, 549.0], [5850.0, 549.0], [5872.0, 536.0], [5889.0, 536.0], [5909.0, 536.0], [5927.0, 536.0], [5947.0, 536.0], [5967.0, 500.0], [5989.0, 500.0], [6011.0, 500.0], [6032.0, 500.0], [6052.0, 500.0], [6074.0, 485.0], [6096.0, 485.0], [6113.0, 485.0], [6134.0, 485.0], [6156.0, 485.0], [6180.0, 489.0], [6199.0, 489.0], [6209.0, 489.0], [6235.0, 489.0], [6255.0, 489.0], [6273.0, 477.0], [6285.0, 477.0], [6297.0, 477.0], [6319.0, 477.0], [6336.0, 477.0], [6352.0, 477.0], [6374.0, 455.0], [6386.0, 455.0], [6411.0, 455.0], [6429.0, 455.0], [6445.0, 455.0], [6464.0, 455.0], [6484.0, 448.0], [6504.0, 448.0], [6524.0, 448.0], [6544.0, 448.0], [6564.0, 448.0], [6584.0, 450.0], [6595.0, 450.0], [6611.0, 450.0], [6622.0, 450.0], [6649.0, 450.0], [6671.0, 450.0], [6695.0, 448.0], [6715.0, 448.0], [6737.0, 448.0], [6754.0, 448.0], [6771.0, 448.0], [6788.0, 459.0], [6809.0, 459.0], [6831.0, 459.0], [6850.0, 459.0], [6861.0, 459.0], [6882.0, 459.0], [6907.0, 465.0], [6917.0, 465.0], [6934.0, 465.0], [6956.0, 465.0], [6978.0, 465.0], [6996.0, 464.0], [7014.0, 464.0], [7033.0, 464.0], [7043.0, 464.0], [7071.0, 464.0], [7093.0, 464.0], [7112.0, 477.0], [7130.0, 477.0], [7150.0, 477.0], [7162.0, 477.0], [7184.0, 477.0], [7206.0, 477.0], [7217.0, 612.0], [7239.0, 612.0], [7261.0, 612.0], [7277.0, 612.0], [7299.0, 612.0], [7315.0, 676.0], [7337.0, 676.0], [7359.0, 676.0], [7381.0, 676.0], [7397.0, 676.0], [7419.0, 676.0], [7436.0, 690.0], [7452.0, 690.0], [7463.0, 690.0], [7490.0, 690.0], [7507.0, 690.0], [7518.0, 690.0], [7534.0, 847.0], [7546.0, 847.0], [7557.0, 847.0], [7568.0, 847.0], [7578.0, 847.0], [7594.0, 847.0], [7610.0, 847.0], [7629.0, 847.0], [7647.0, 2084.0], [7663.0, 2084.0], [7682.0, 2084.0], [7703.0, 2084.0], [7725.0, 2084.0], [7745.0, 2069.0], [7756.0, 2069.0], [7772.0, 2069.0], [7783.0, 2069.0], [7799.0, 2069.0], [7810.0, 2069.0], [7821.0, 2069.0], [7832.0, 2077.0], [7848.0, 2077.0], [7860.0, 2077.0], [7870.0, 2077.0], [7881.0, 2077.0], [7898.0, 2077.0], [7925.0, 2077.0], [7943.0, 2174.0], [7963.0, 2174.0], [7983.0, 2174.0], [8002.0, 2174.0], [8024.0, 2174.0], [8040.0, 2171.0], [8057.0, 2171.0], [8073.0, 2171.0], [8084.0, 2171.0], [8100.0, 2171.0], [8111.0, 2171.0], [8122.0, 2171.0], [8144.0, 2190.0], [8165.0, 2190.0], [8183.0, 2190.0], [8199.0, 2190.0], [8218.0, 2190.0], [8236.0, 2168.0], [8252.0, 2168.0], [8268.0, 2168.0], [8279.0, 2168.0], [8296.0, 2168.0], [8307.0, 2168.0], [8322.0, 2115.0], [8338.0, 2115.0], [8356.0, 2115.0], [8370.0, 2115.0], [8388.0, 2115.0], [8405.0, 2115.0], [8427.0, 2115.0], [8443.0, 1690.0], [8459.0, 1690.0], [8476.0, 1690.0], [8487.0, 1690.0], [8503.0, 1690.0], [8514.0, 1690.0], [8531.0, 1690.0], [8541.0, 1726.0], [8569.0, 1726.0], [8582.0, 1726.0], [8599.0, 1726.0], [8609.0, 1726.0], [8626.0, 1726.0], [8637.0, 1658.0], [8648.0, 1658.0], [8664.0, 1658.0], [8681.0, 1658.0], [8701.0, 1658.0], [8721.0, 1658.0], [8741.0, 1444.0], [8759.0, 1444.0], [8778.0, 1444.0], [8785.0, 1444.0], [8807.0, 1444.0], [8823.0, 1444.0], [8837.0, 1108.0], [8855.0, 1108.0], [8875.0, 1108.0], [8886.0, 1108.0], [8903.0, 1108.0], [8919.0, 1108.0], [8941.0, 1016.0], [8957.0, 1016.0], [8977.0, 1016.0], [8987.0, 1016.0], [9013.0, 1016.0], [9033.0, 1023.0], [9051.0, 1023.0], [9067.0, 1023.0], [9086.0, 1023.0], [9104.0, 1023.0], [9124.0, 1023.0], [9144.0, 1023.0], [9166.0, 977.0], [9179.0, 977.0], [9199.0, 977.0], [9210.0, 977.0], [9221.0, 977.0], [9239.0, 977.0], [9250.0, 828.0], [9266.0, 828.0], [9277.0, 828.0], [9293.0, 828.0], [9304.0, 828.0], [9315.0, 828.0], [9342.0, 828.0], [9359.0, 802.0], [9375.0, 802.0], [9397.0, 802.0], [9416.0, 802.0], [9432.0, 802.0], [9454.0, 802.0], [9476.0, 807.0], [9498.0, 807.0], [9514.0, 807.0], [9531.0, 807.0], [9547.0, 807.0], [9564.0, 754.0], [9574.0, 754.0], [9591.0, 754.0], [9607.0, 754.0], [9624.0, 754.0], [9646.0, 754.0], [9672.0, 754.0], [9695.0, 661.0], [9723.0, 661.0], [9739.0, 661.0], [9750.0, 661.0], [9766.0, 661.0], [9788.0, 661.0], [9814.0, 631.0], [9834.0, 631.0], [9856.0, 631.0], [9873.0, 631.0], [9895.0, 631.0], [9916.0, 628.0], [9937.0, 628.0], [9957.0, 628.0], [9978.0, 628.0], [9995.0, 628.0], [10017.0, 605.0], [10030.0, 605.0], [10050.0, 605.0], [10070.0, 605.0], [10088.0, 605.0], [10107.0, 605.0], [10117.0, 576.0], [10145.0, 576.0], [10167.0, 576.0], [10191.0, 576.0], [10211.0, 576.0], [10233.0, 554.0], [10255.0, 554.0], [10272.0, 554.0], [10294.0, 554.0], [10316.0, 554.0], [10340.0, 531.0], [10350.0, 531.0], [10367.0, 531.0], [10383.0, 531.0], [10394.0, 531.0], [10422.0, 531.0], [10438.0, 512.0], [10449.0, 512.0], [10471.0, 512.0], [10487.0, 512.0], [10509.0, 512.0], [10520.0, 512.0], [10536.0, 490.0], [10555.0, 490.0], [10573.0, 490.0], [10590.0, 490.0], [10612.0, 490.0], [10628.0, 490.0], [10644.0, 471.0], [10661.0, 471.0], [10683.0, 471.0], [10699.0, 471.0], [10724.0, 471.0], [10735.0, 466.0], [10751.0, 466.0], [10762.0, 466.0], [10789.0, 466.0], [10811.0, 466.0], [10827.0, 466.0], [10844.0, 458.0], [10855.0, 458.0], [10871.0, 458.0], [10888.0, 458.0], [10901.0, 458.0], [10917.0, 458.0], [10934.0, 458.0], [10950.0, 444.0], [10967.0, 444.0], [10977.0, 444.0], [10993.0, 444.0], [11010.0, 444.0], [11032.0, 444.0], [11043.0, 438.0], [11059.0, 438.0], [11076.0, 438.0], [11092.0, 438.0], [11109.0, 438.0], [11125.0, 438.0], [11144.0, 438.0], [11155.0, 438.0], [11171.0, 438.0], [11182.0, 438.0], [11209.0, 438.0], [11231.0, 438.0], [11250.0, 438.0], [11261.0, 431.0], [11277.0, 431.0], [11288.0, 431.0], [11304.0, 431.0], [11315.0, 431.0], [11332.0, 431.0], [11348.0, 431.0], [11370.0, 420.0], [11386.0, 420.0], [11408.0, 420.0], [11433.0, 420.0], [11443.0, 420.0], [11471.0, 418.0], [11496.0, 418.0], [11506.0, 418.0], [11532.0, 418.0], [11552.0, 418.0], [11570.0, 416.0], [11591.0, 416.0], [11605.0, 416.0], [11627.0, 416.0], [11649.0, 416.0], [11666.0, 411.0], [11687.0, 411.0], [11709.0, 411.0], [11735.0, 411.0], [11755.0, 411.0], [11775.0, 408.0], [11786.0, 408.0], [11805.0, 408.0], [11826.0, 408.0], [11848.0, 408.0], [11868.0, 408.0], [11889.0, 401.0], [11906.0, 401.0], [11928.0, 401.0], [11950.0, 401.0], [11976.0, 401.0], [11996.0, 400.0], [12018.0, 400.0], [12040.0, 400.0], [12062.0, 400.0], [12081.0, 400.0], [12102.0, 395.0], [12124.0, 395.0], [12141.0, 395.0], [12163.0, 395.0], [12188.0, 395.0], [12198.0, 389.0], [12224.0, 389.0], [12245.0, 389.0], [12267.0, 389.0], [12283.0, 389.0], [12305.0, 386.0], [12322.0, 386.0], [12337.0, 386.0], [12359.0, 386.0], [12381.0, 386.0], [12405.0, 385.0], [12425.0, 385.0], [12447.0, 385.0], [12464.0, 385.0], [12475.0, 385.0], [12502.0, 387.0], [12528.0, 387.0], [12547.0, 387.0], [12563.0, 387.0], [12584.0, 387.0], [12601.0, 387.0], [12623.0, 390.0], [12636.0, 390.0], [12654.0, 390.0], [12673.0, 390.0], [12683.0, 390.0], [12707.0, 390.0], [12718.0, 391.0], [12735.0, 391.0], [12751.0, 391.0], [12773.0, 391.0], [12795.0, 391.0], [12817.0, 391.0], [12835.0, 390.0], [12856.0, 390.0], [12878.0, 390.0], [12895.0, 390.0], [12911.0, 390.0], [12927.0, 403.0], [12954.0, 403.0], [12974.0, 403.0], [12994.0, 403.0], [13016.0, 403.0], [13038.0, 403.0], [13064.0, 407.0], [13084.0, 407.0], [13105.0, 407.0], [13122.0, 407.0], [13144.0, 407.0], [13155.0, 409.0], [13171.0, 409.0], [13187.0, 409.0], [13204.0, 409.0], [13215.0, 409.0], [13231.0, 409.0], [13242.0, 409.0], [13258.0, 412.0], [13275.0, 412.0], [13291.0, 412.0], [13313.0, 412.0], [13326.0, 412.0], [13344.0, 412.0], [13363.0, 428.0], [13373.0, 428.0], [13399.0, 428.0], [13410.0, 428.0], [13431.0, 428.0], [13453.0, 428.0], [13475.0, 432.0], [13497.0, 432.0], [13515.0, 432.0], [13537.0, 432.0], [13554.0, 432.0], [13576.0, 432.0], [13592.0, 432.0], [13608.0, 432.0], [13625.0, 432.0], [13636.0, 432.0], [13652.0, 432.0], [13663.0, 434.0], [13679.0, 434.0], [13696.0, 434.0], [13712.0, 434.0], [13734.0, 434.0], [13750.0, 434.0], [13778.0, 456.0], [13794.0, 456.0], [13820.0, 456.0], [13840.0, 456.0], [13862.0, 456.0], [13878.0, 484.0], [13900.0, 484.0], [13913.0, 484.0], [13933.0, 484.0], [13951.0, 484.0], [13972.0, 484.0], [13984.0, 484.0], [14004.0, 484.0], [14024.0, 484.0], [14035.0, 484.0], [14052.0, 484.0], [14068.0, 484.0], [14090.0, 493.0], [14106.0, 493.0], [14123.0, 493.0], [14139.0, 493.0], [14156.0, 493.0], [14172.0, 493.0], [14183.0, 515.0], [14206.0, 515.0], [14216.0, 515.0], [14233.0, 515.0], [14249.0, 515.0], [14271.0, 515.0], [14284.0, 518.0], [14302.0, 518.0], [14318.0, 518.0], [14340.0, 518.0], [14356.0, 518.0], [14373.0, 518.0], [14387.0, 521.0], [14403.0, 521.0], [14421.0, 521.0], [14442.0, 521.0], [14456.0, 521.0], [14477.0, 521.0], [14499.0, 522.0], [14516.0, 522.0], [14538.0, 522.0], [14554.0, 522.0], [14577.0, 522.0], [14594.0, 506.0], [14612.0, 506.0], [14633.0, 506.0], [14655.0, 506.0], [14680.0, 506.0], [14700.0, 472.0], [14722.0, 472.0], [14744.0, 472.0], [14769.0, 472.0], [14779.0, 472.0], [14796.0, 473.0], [14818.0, 473.0], [14838.0, 473.0], [14858.0, 473.0], [14878.0, 473.0], [14896.0, 458.0], [14915.0, 458.0], [14925.0, 458.0], [14951.0, 458.0], [14971.0, 458.0], [14989.0, 458.0], [15005.0, 422.0], [15016.0, 422.0], [15042.0, 422.0], [15064.0, 422.0], [15077.0, 422.0], [15095.0, 422.0], [15114.0, 414.0], [15124.0, 414.0], [15148.0, 414.0], [15169.0, 414.0], [15181.0, 414.0], [15197.0, 414.0], [15216.0, 414.0], [15233.0, 414.0], [15243.0, 414.0], [15260.0, 414.0], [15276.0, 414.0], [15293.0, 414.0], [15319.0, 404.0], [15341.0, 404.0], [15363.0, 404.0], [15380.0, 404.0], [15402.0, 404.0], [15422.0, 391.0], [15438.0, 391.0], [15449.0, 391.0], [15471.0, 391.0], [15490.0, 391.0], [15507.0, 391.0], [15523.0, 390.0], [15539.0, 390.0], [15556.0, 390.0], [15574.0, 390.0], [15590.0, 390.0], [15612.0, 390.0], [15639.0, 387.0], [15650.0, 387.0], [15666.0, 387.0], [15683.0, 387.0], [15699.0, 387.0], [15721.0, 387.0], [15741.0, 383.0], [15759.0, 383.0], [15775.0, 383.0], [15786.0, 383.0], [15796.0, 383.0], [15818.0, 383.0], [15834.0, 383.0], [15845.0, 374.0], [15862.0, 374.0], [15878.0, 374.0], [15891.0, 374.0], [15907.0, 374.0], [15918.0, 374.0], [15940.0, 374.0], [15959.0, 369.0], [15977.0, 369.0], [15993.0, 369.0], [16015.0, 369.0], [16031.0, 369.0], [16053.0, 369.0], [16069.0, 371.0], [16093.0, 371.0], [16115.0, 371.0], [16132.0, 371.0], [16143.0, 371.0], [16159.0, 366.0], [16170.0, 366.0], [16186.0, 366.0], [16203.0, 366.0], [16219.0, 366.0], [16241.0, 366.0], [16254.0, 366.0], [16272.0, 359.0], [16291.0, 359.0], [16301.0, 359.0], [16325.0, 359.0], [16341.0, 359.0], [16358.0, 359.0], [16374.0, 359.0], [16393.0, 361.0], [16414.0, 361.0], [16431.0, 361.0], [16454.0, 361.0], [16470.0, 361.0], [16486.0, 361.0], [16497.0, 361.0], [16514.0, 361.0], [16530.0, 361.0], [16552.0, 361.0], [16574.0, 361.0], [16599.0, 357.0], [16619.0, 357.0], [16636.0, 357.0], [16647.0, 357.0], [16663.0, 357.0], [16674.0, 357.0], [16685.0, 362.0], [16696.0, 362.0], [16703.0, 362.0], [16725.0, 362.0], [16747.0, 362.0], [16763.0, 362.0], [16781.0, 362.0], [16802.0, 364.0], [16824.0, 364.0], [16850.0, 364.0], [16870.0, 364.0], [16892.0, 364.0], [16905.0, 365.0], [16923.0, 365.0], [16939.0, 365.0], [16950.0, 365.0], [16966.0, 365.0], [16983.0, 365.0], [16994.0, 365.0], [17010.0, 369.0], [17026.0, 369.0], [17043.0, 369.0], [17059.0, 369.0], [17069.0, 369.0], [17077.0, 369.0], [17093.0, 369.0], [17115.0, 372.0], [17132.0, 372.0], [17154.0, 372.0], [17176.0, 372.0], [17202.0, 372.0], [17222.0, 376.0], [17243.0, 376.0], [17267.0, 376.0], [17278.0, 376.0], [17306.0, 376.0], [17328.0, 378.0], [17352.0, 378.0], [17371.0, 378.0], [17382.0, 378.0], [17399.0, 378.0], [17415.0, 378.0], [17428.0, 385.0], [17444.0, 385.0], [17463.0, 385.0], [17481.0, 385.0], [17491.0, 385.0], [17499.0, 385.0], [17510.0, 385.0], [17533.0, 395.0], [17548.0, 395.0], [17570.0, 395.0], [17586.0, 395.0], [17597.0, 395.0], [17613.0, 395.0], [17630.0, 395.0], [17643.0, 398.0], [17659.0, 398.0], [17670.0, 398.0], [17692.0, 398.0], [17709.0, 398.0], [17728.0, 398.0], [17750.0, 405.0], [17772.0, 405.0], [17798.0, 405.0], [17817.0, 405.0], [17827.0, 405.0], [17844.0, 420.0], [17853.0, 420.0], [17870.0, 420.0], [17880.0, 420.0], [17897.0, 420.0], [17908.0, 420.0], [17924.0, 420.0], [17941.0, 433.0], [17957.0, 433.0], [17973.0, 433.0], [17990.0, 433.0], [18013.0, 433.0]]
x1 = 5
y1 = 3
start = 40
end = 999
theta = 0.69*np.pi

data = np.array(sensor_data)
time = data[start:end, 0]
tof1 = data[start:end, 1]

data53 = robot2global(tof1, x1, y1, theta)

plt.figure()
plt.scatter(data53[0], data53[1], s=1, c='red')  # s is size
plt.axis('equal')
plt.xlabel('x (m)')
plt.ylabel('y (m)')
plt.title(f'ToF Global Frame {x1}, {y1}')
plt.grid()
plt.show()

# %%
sensor_data = [[13.0, 2207.0], [35.0, 2207.0], [54.0, 2207.0], [72.0, 2207.0], [88.0, 2207.0], [104.0, 2207.0], [121.0, 2241.0], [139.0, 2241.0], [150.0, 2241.0], [167.0, 2241.0], [183.0, 2241.0], [194.0, 2241.0], [216.0, 2241.0], [227.0, 2262.0], [243.0, 2262.0], [260.0, 2262.0], [276.0, 2262.0], [292.0, 2262.0], [314.0, 2262.0], [331.0, 2270.0], [342.0, 2270.0], [367.0, 2270.0], [389.0, 2270.0], [411.0, 2270.0], [433.0, 2236.0], [452.0, 2236.0], [474.0, 2236.0], [491.0, 2236.0], [513.0, 2236.0], [535.0, 2295.0], [555.0, 2295.0], [567.0, 2295.0], [577.0, 2295.0], [594.0, 2295.0], [610.0, 2295.0], [627.0, 2269.0], [643.0, 2269.0], [659.0, 2269.0], [681.0, 2269.0], [698.0, 2269.0], [710.0, 2269.0], [730.0, 2275.0], [741.0, 2275.0], [758.0, 2275.0], [771.0, 2275.0], [787.0, 2275.0], [809.0, 2275.0], [821.0, 2229.0], [840.0, 2229.0], [861.0, 2229.0], [882.0, 2229.0], [899.0, 2229.0], [921.0, 2229.0], [943.0, 2224.0], [959.0, 2224.0], [976.0, 2224.0], [997.0, 2224.0], [1016.0, 2224.0], [1026.0, 988.0], [1043.0, 988.0], [1059.0, 988.0], [1074.0, 988.0], [1090.0, 988.0], [1107.0, 988.0], [1123.0, 988.0], [1139.0, 739.0], [1156.0, 739.0], [1172.0, 739.0], [1183.0, 739.0], [1200.0, 739.0], [1216.0, 739.0], [1232.0, 731.0], [1243.0, 731.0], [1260.0, 731.0], [1282.0, 731.0], [1307.0, 731.0], [1324.0, 731.0], [1344.0, 723.0], [1366.0, 723.0], [1383.0, 723.0], [1399.0, 723.0], [1421.0, 723.0], [1437.0, 710.0], [1459.0, 710.0], [1468.0, 710.0], [1481.0, 710.0], [1503.0, 710.0], [1524.0, 710.0], [1546.0, 720.0], [1557.0, 720.0], [1568.0, 720.0], [1584.0, 720.0], [1601.0, 720.0], [1617.0, 720.0], [1634.0, 721.0], [1650.0, 721.0], [1666.0, 721.0], [1680.0, 721.0], [1700.0, 721.0], [1717.0, 721.0], [1739.0, 721.0], [1755.0, 724.0], [1773.0, 724.0], [1794.0, 724.0], [1810.0, 724.0], [1827.0, 724.0], [1849.0, 724.0], [1871.0, 749.0], [1893.0, 749.0], [1909.0, 749.0], [1926.0, 749.0], [1948.0, 749.0], [1959.0, 779.0], [1981.0, 779.0], [1993.0, 779.0], [2013.0, 779.0], [2029.0, 779.0], [2041.0, 779.0], [2057.0, 779.0], [2079.0, 792.0], [2090.0, 792.0], [2112.0, 792.0], [2134.0, 792.0], [2150.0, 792.0], [2172.0, 792.0], [2197.0, 804.0], [2214.0, 804.0], [2236.0, 804.0], [2258.0, 804.0], [2274.0, 804.0], [2283.0, 837.0], [2294.0, 837.0], [2316.0, 837.0], [2333.0, 837.0], [2353.0, 837.0], [2369.0, 837.0], [2381.0, 869.0], [2397.0, 869.0], [2419.0, 869.0], [2435.0, 869.0], [2452.0, 869.0], [2468.0, 869.0], [2485.0, 869.0], [2506.0, 869.0], [2523.0, 869.0], [2537.0, 869.0], [2554.0, 869.0], [2570.0, 869.0], [2592.0, 880.0], [2610.0, 880.0], [2620.0, 880.0], [2637.0, 880.0], [2653.0, 880.0], [2670.0, 880.0], [2692.0, 910.0], [2708.0, 910.0], [2718.0, 910.0], [2735.0, 910.0], [2751.0, 910.0], [2763.0, 910.0], [2779.0, 953.0], [2796.0, 953.0], [2812.0, 953.0], [2828.0, 953.0], [2840.0, 953.0], [2850.0, 953.0], [2872.0, 953.0], [2897.0, 962.0], [2914.0, 962.0], [2940.0, 962.0], [2957.0, 962.0], [2973.0, 962.0], [2990.0, 975.0], [3006.0, 975.0], [3022.0, 975.0], [3039.0, 975.0], [3055.0, 975.0], [3072.0, 975.0], [3083.0, 1039.0], [3096.0, 1039.0], [3112.0, 1039.0], [3129.0, 1039.0], [3139.0, 1039.0], [3150.0, 1039.0], [3166.0, 1039.0], [3174.0, 1908.0], [3190.0, 1908.0], [3206.0, 1908.0], [3223.0, 1908.0], [3245.0, 1908.0], [3262.0, 1908.0], [3279.0, 2705.0], [3295.0, 2705.0], [3311.0, 2705.0], [3328.0, 2705.0], [3354.0, 2705.0], [3371.0, 2705.0], [3387.0, 2647.0], [3404.0, 2647.0], [3415.0, 2647.0], [3436.0, 2647.0], [3458.0, 2647.0], [3475.0, 2647.0], [3497.0, 2669.0], [3518.0, 2669.0], [3540.0, 2669.0], [3551.0, 2669.0], [3572.0, 2669.0], [3583.0, 2776.0], [3594.0, 2776.0], [3605.0, 2776.0], [3622.0, 2776.0], [3638.0, 2776.0], [3650.0, 2776.0], [3667.0, 2776.0], [3687.0, 2799.0], [3708.0, 2799.0], [3725.0, 2799.0], [3747.0, 2799.0], [3758.0, 2799.0], [3774.0, 2861.0], [3790.0, 2861.0], [3801.0, 2861.0], [3823.0, 2861.0], [3845.0, 2861.0], [3861.0, 2861.0], [3880.0, 2861.0], [3897.0, 3057.0], [3905.0, 3057.0], [3913.0, 3057.0], [3929.0, 3057.0], [3951.0, 3057.0], [3976.0, 3057.0], [3995.0, 3168.0], [4013.0, 3168.0], [4029.0, 3168.0], [4041.0, 3168.0], [4057.0, 3168.0], [4074.0, 3168.0], [4090.0, 3148.0], [4101.0, 3148.0], [4123.0, 3148.0], [4139.0, 3148.0], [4154.0, 3148.0], [4171.0, 3148.0], [4187.0, 3178.0], [4210.0, 3178.0], [4226.0, 3178.0], [4248.0, 3178.0], [4264.0, 3178.0], [4296.0, 3193.0], [4322.0, 3193.0], [4339.0, 3193.0], [4355.0, 3193.0], [4372.0, 3193.0], [4383.0, 2430.0], [4400.0, 2430.0], [4418.0, 2430.0], [4435.0, 2430.0], [4453.0, 2430.0], [4469.0, 2430.0], [4486.0, 1496.0], [4502.0, 1496.0], [4520.0, 1496.0], [4536.0, 1496.0], [4548.0, 1496.0], [4559.0, 1496.0], [4581.0, 1496.0], [4597.0, 1493.0], [4611.0, 1493.0], [4628.0, 1493.0], [4641.0, 1493.0], [4662.0, 1493.0], [4670.0, 1493.0], [4686.0, 1493.0], [4702.0, 1371.0], [4719.0, 1371.0], [4730.0, 1371.0], [4746.0, 1371.0], [4768.0, 1371.0], [4779.0, 1371.0], [4790.0, 1358.0], [4812.0, 1358.0], [4836.0, 1358.0], [4847.0, 1358.0], [4864.0, 1358.0], [4888.0, 1358.0], [4904.0, 1353.0], [4916.0, 1353.0], [4932.0, 1353.0], [4949.0, 1353.0], [4964.0, 1353.0], [4981.0, 1353.0], [4997.0, 1353.0], [5008.0, 1346.0], [5019.0, 1346.0], [5035.0, 1346.0], [5052.0, 1346.0], [5069.0, 1346.0], [5079.0, 1346.0], [5091.0, 1346.0], [5108.0, 1343.0], [5130.0, 1343.0], [5152.0, 1343.0], [5169.0, 1343.0], [5189.0, 1343.0], [5211.0, 1340.0], [5228.0, 1340.0], [5239.0, 1340.0], [5255.0, 1340.0], [5271.0, 1340.0], [5288.0, 1340.0], [5310.0, 1339.0], [5327.0, 1339.0], [5347.0, 1339.0], [5369.0, 1339.0], [5386.0, 1339.0], [5404.0, 1342.0], [5422.0, 1342.0], [5444.0, 1342.0], [5461.0, 1342.0], [5474.0, 1342.0], [5483.0, 1342.0], [5499.0, 1350.0], [5521.0, 1350.0], [5543.0, 1350.0], [5554.0, 1350.0], [5576.0, 1350.0], [5583.0, 1319.0], [5599.0, 1319.0], [5615.0, 1319.0], [5640.0, 1319.0], [5651.0, 1319.0], [5668.0, 1319.0], [5684.0, 1319.0], [5706.0, 1295.0], [5728.0, 1295.0], [5750.0, 1295.0], [5766.0, 1295.0], [5788.0, 1295.0], [5812.0, 1299.0], [5828.0, 1299.0], [5840.0, 1299.0], [5856.0, 1299.0], [5873.0, 1299.0], [5880.0, 1299.0], [5889.0, 1299.0], [5905.0, 1165.0], [5927.0, 1165.0], [5939.0, 1165.0], [5949.0, 1165.0], [5971.0, 1165.0], [5989.0, 1165.0], [6009.0, 913.0], [6025.0, 913.0], [6037.0, 913.0], [6064.0, 913.0], [6075.0, 913.0], [6095.0, 913.0], [6117.0, 911.0], [6131.0, 911.0], [6151.0, 911.0], [6168.0, 911.0], [6190.0, 911.0], [6213.0, 920.0], [6234.0, 920.0], [6255.0, 920.0], [6272.0, 920.0], [6294.0, 920.0], [6305.0, 762.0], [6325.0, 762.0], [6336.0, 762.0], [6353.0, 762.0], [6374.0, 762.0], [6394.0, 762.0], [6412.0, 635.0], [6428.0, 635.0], [6445.0, 635.0], [6464.0, 635.0], [6481.0, 635.0], [6498.0, 635.0], [6514.0, 631.0], [6531.0, 631.0], [6541.0, 631.0], [6563.0, 631.0], [6585.0, 631.0], [6596.0, 631.0], [6612.0, 632.0], [6629.0, 632.0], [6645.0, 632.0], [6662.0, 632.0], [6678.0, 632.0], [6694.0, 632.0], [6712.0, 564.0], [6734.0, 564.0], [6751.0, 564.0], [6764.0, 564.0], [6781.0, 564.0], [6803.0, 564.0], [6825.0, 523.0], [6842.0, 523.0], [6863.0, 523.0], [6888.0, 523.0], [6908.0, 523.0], [6925.0, 525.0], [6944.0, 525.0], [6961.0, 525.0], [6983.0, 525.0], [6999.0, 525.0], [7015.0, 525.0], [7037.0, 522.0], [7061.0, 522.0], [7081.0, 522.0], [7098.0, 522.0], [7114.0, 522.0], [7131.0, 481.0], [7156.0, 481.0], [7167.0, 481.0], [7185.0, 481.0], [7194.0, 481.0], [7210.0, 481.0], [7234.0, 439.0], [7250.0, 439.0], [7272.0, 439.0], [7294.0, 439.0], [7316.0, 439.0], [7328.0, 434.0], [7338.0, 434.0], [7360.0, 434.0], [7382.0, 434.0], [7393.0, 434.0], [7409.0, 434.0], [7426.0, 434.0], [7449.0, 433.0], [7467.0, 433.0], [7493.0, 433.0], [7510.0, 433.0], [7532.0, 433.0], [7554.0, 409.0], [7570.0, 409.0], [7592.0, 409.0], [7601.0, 409.0], [7626.0, 409.0], [7646.0, 409.0], [7668.0, 378.0], [7685.0, 378.0], [7697.0, 378.0], [7717.0, 378.0], [7737.0, 378.0], [7748.0, 378.0], [7759.0, 375.0], [7770.0, 375.0], [7792.0, 375.0], [7814.0, 375.0], [7832.0, 375.0], [7853.0, 375.0], [7869.0, 375.0], [7886.0, 375.0], [7903.0, 375.0], [7914.0, 375.0], [7930.0, 375.0], [7946.0, 375.0], [7957.0, 375.0], [7972.0, 362.0], [7990.0, 362.0], [8006.0, 362.0], [8023.0, 362.0], [8041.0, 362.0], [8052.0, 362.0], [8069.0, 348.0], [8085.0, 348.0], [8102.0, 348.0], [8118.0, 348.0], [8140.0, 348.0], [8158.0, 348.0], [8178.0, 345.0], [8189.0, 345.0], [8211.0, 345.0], [8228.0, 345.0], [8248.0, 345.0], [8268.0, 345.0], [8279.0, 344.0], [8296.0, 344.0], [8320.0, 344.0], [8331.0, 344.0], [8348.0, 344.0], [8371.0, 344.0], [8389.0, 333.0], [8409.0, 333.0], [8426.0, 333.0], [8442.0, 333.0], [8464.0, 333.0], [8486.0, 333.0], [8504.0, 328.0], [8523.0, 328.0], [8540.0, 328.0], [8562.0, 328.0], [8575.0, 328.0], [8595.0, 328.0], [8612.0, 325.0], [8634.0, 325.0], [8656.0, 325.0], [8673.0, 325.0], [8699.0, 325.0], [8726.0, 324.0], [8744.0, 324.0], [8766.0, 324.0], [8778.0, 324.0], [8788.0, 324.0], [8810.0, 324.0], [8832.0, 319.0], [8843.0, 319.0], [8869.0, 319.0], [8881.0, 319.0], [8888.0, 319.0], [8904.0, 319.0], [8926.0, 319.0], [8943.0, 313.0], [8959.0, 313.0], [8979.0, 313.0], [8999.0, 313.0], [9021.0, 313.0], [9033.0, 317.0], [9053.0, 317.0], [9069.0, 317.0], [9081.0, 317.0], [9097.0, 317.0], [9123.0, 317.0], [9134.0, 317.0], [9145.0, 317.0], [9167.0, 317.0], [9184.0, 317.0], [9198.0, 317.0], [9215.0, 317.0], [9231.0, 317.0], [9248.0, 318.0], [9269.0, 318.0], [9281.0, 318.0], [9303.0, 318.0], [9326.0, 318.0], [9342.0, 322.0], [9364.0, 322.0], [9381.0, 322.0], [9397.0, 322.0], [9423.0, 322.0], [9440.0, 322.0], [9462.0, 322.0], [9478.0, 322.0], [9494.0, 322.0], [9513.0, 322.0], [9534.0, 322.0], [9553.0, 323.0], [9573.0, 323.0], [9584.0, 323.0], [9595.0, 323.0], [9606.0, 323.0], [9628.0, 323.0], [9644.0, 323.0], [9663.0, 323.0], [9680.0, 323.0], [9691.0, 323.0], [9702.0, 323.0], [9718.0, 323.0], [9740.0, 323.0], [9756.0, 324.0], [9778.0, 324.0], [9795.0, 324.0], [9811.0, 324.0], [9827.0, 324.0], [9844.0, 324.0], [9860.0, 329.0], [9877.0, 329.0], [9895.0, 329.0], [9916.0, 329.0], [9933.0, 329.0], [9955.0, 329.0], [9977.0, 327.0], [9998.0, 327.0], [10015.0, 327.0], [10026.0, 327.0], [10042.0, 327.0], [10059.0, 327.0], [10069.0, 333.0], [10091.0, 333.0], [10108.0, 333.0], [10123.0, 333.0], [10140.0, 333.0], [10150.0, 333.0], [10166.0, 333.0], [10188.0, 340.0], [10205.0, 340.0], [10224.0, 340.0], [10244.0, 340.0], [10263.0, 340.0], [10280.0, 343.0], [10290.0, 343.0], [10307.0, 343.0], [10323.0, 343.0], [10340.0, 343.0], [10356.0, 343.0], [10372.0, 343.0], [10389.0, 345.0], [10400.0, 345.0], [10423.0, 345.0], [10439.0, 345.0], [10446.0, 345.0], [10455.0, 345.0], [10463.0, 345.0], [10479.0, 345.0], [10505.0, 357.0], [10522.0, 357.0], [10538.0, 357.0], [10555.0, 357.0], [10566.0, 357.0], [10576.0, 357.0], [10587.0, 366.0], [10609.0, 366.0], [10626.0, 366.0], [10642.0, 366.0], [10658.0, 366.0], [10675.0, 366.0], [10691.0, 365.0], [10708.0, 365.0], [10724.0, 365.0], [10744.0, 365.0], [10755.0, 365.0], [10772.0, 365.0], [10796.0, 368.0], [10814.0, 368.0], [10830.0, 368.0], [10842.0, 368.0], [10858.0, 368.0], [10875.0, 368.0], [10891.0, 390.0], [10914.0, 390.0], [10937.0, 390.0], [10958.0, 390.0], [10984.0, 390.0], [11001.0, 399.0], [11017.0, 399.0], [11042.0, 399.0], [11059.0, 399.0], [11070.0, 399.0], [11085.0, 399.0], [11107.0, 399.0], [11128.0, 399.0], [11145.0, 399.0], [11162.0, 399.0], [11183.0, 399.0], [11200.0, 406.0], [11211.0, 406.0], [11233.0, 406.0], [11251.0, 406.0], [11271.0, 406.0], [11282.0, 406.0], [11302.0, 440.0], [11324.0, 440.0], [11345.0, 440.0], [11367.0, 440.0], [11384.0, 440.0], [11402.0, 454.0], [11413.0, 454.0], [11430.0, 454.0], [11446.0, 454.0], [11468.0, 454.0], [11490.0, 454.0], [11506.0, 453.0], [11523.0, 453.0], [11545.0, 453.0], [11561.0, 453.0], [11581.0, 453.0], [11601.0, 453.0], [11612.0, 468.0], [11623.0, 468.0], [11633.0, 468.0], [11641.0, 468.0], [11657.0, 468.0], [11673.0, 468.0], [11690.0, 468.0], [11701.0, 468.0], [11718.0, 503.0], [11734.0, 503.0], [11745.0, 503.0], [11766.0, 503.0], [11787.0, 503.0], [11804.0, 503.0], [11826.0, 505.0], [11842.0, 505.0], [11859.0, 505.0], [11876.0, 505.0], [11898.0, 505.0], [11909.0, 505.0], [11925.0, 503.0], [11941.0, 503.0], [11958.0, 503.0], [11974.0, 503.0], [11996.0, 503.0], [12015.0, 503.0], [12035.0, 504.0], [12056.0, 504.0], [12079.0, 504.0], [12087.0, 504.0], [12109.0, 504.0], [12130.0, 504.0], [12152.0, 480.0], [12163.0, 480.0], [12182.0, 480.0], [12203.0, 480.0], [12223.0, 480.0], [12243.0, 480.0], [12264.0, 471.0], [12283.0, 471.0], [12303.0, 471.0], [12314.0, 471.0], [12336.0, 471.0], [12353.0, 470.0], [12370.0, 470.0], [12388.0, 470.0], [12404.0, 470.0], [12426.0, 470.0], [12448.0, 470.0], [12471.0, 451.0], [12491.0, 451.0], [12509.0, 451.0], [12525.0, 451.0], [12537.0, 451.0], [12553.0, 451.0], [12575.0, 430.0], [12583.0, 430.0], [12594.0, 430.0], [12605.0, 430.0], [12627.0, 430.0], [12644.0, 430.0], [12665.0, 430.0], [12684.0, 415.0], [12704.0, 415.0], [12715.0, 415.0], [12732.0, 415.0], [12748.0, 415.0], [12770.0, 415.0], [12788.0, 414.0], [12804.0, 414.0], [12816.0, 414.0], [12827.0, 414.0], [12849.0, 414.0], [12865.0, 414.0], [12881.0, 399.0], [12900.0, 399.0], [12925.0, 399.0], [12942.0, 399.0], [12958.0, 399.0], [12975.0, 399.0], [12991.0, 394.0], [13002.0, 394.0], [13019.0, 394.0], [13041.0, 394.0], [13063.0, 394.0], [13075.0, 394.0], [13092.0, 389.0], [13108.0, 389.0], [13125.0, 389.0], [13141.0, 389.0], [13163.0, 389.0], [13189.0, 389.0], [13211.0, 388.0], [13233.0, 388.0], [13250.0, 388.0], [13272.0, 388.0], [13282.0, 388.0], [13304.0, 388.0], [13326.0, 379.0], [13343.0, 379.0], [13360.0, 379.0], [13376.0, 379.0], [13398.0, 379.0], [13420.0, 372.0], [13436.0, 372.0], [13458.0, 372.0], [13482.0, 372.0], [13502.0, 372.0], [13519.0, 372.0], [13541.0, 372.0], [13566.0, 372.0], [13586.0, 372.0], [13608.0, 372.0], [13620.0, 370.0], [13640.0, 370.0], [13656.0, 370.0], [13673.0, 370.0], [13690.0, 370.0], [13708.0, 370.0], [13725.0, 368.0], [13748.0, 368.0], [13760.0, 368.0], [13768.0, 368.0], [13784.0, 368.0], [13800.0, 368.0], [13817.0, 368.0], [13842.0, 371.0], [13859.0, 371.0], [13881.0, 371.0], [13903.0, 371.0], [13919.0, 371.0], [13937.0, 371.0], [13959.0, 371.0], [13971.0, 371.0], [13981.0, 371.0], [14003.0, 371.0], [14028.0, 371.0], [14050.0, 372.0], [14072.0, 372.0], [14080.0, 372.0], [14097.0, 372.0], [14105.0, 372.0], [14126.0, 372.0], [14148.0, 378.0], [14170.0, 378.0], [14188.0, 378.0], [14209.0, 378.0], [14225.0, 378.0], [14242.0, 380.0], [14259.0, 380.0], [14270.0, 380.0], [14286.0, 380.0], [14302.0, 380.0], [14319.0, 380.0], [14335.0, 380.0], [14357.0, 381.0], [14373.0, 381.0], [14395.0, 381.0], [14412.0, 381.0], [14432.0, 381.0], [14454.0, 382.0], [14471.0, 382.0], [14487.0, 382.0], [14507.0, 382.0], [14523.0, 382.0], [14535.0, 382.0], [14559.0, 393.0], [14570.0, 393.0], [14581.0, 393.0], [14592.0, 393.0], [14614.0, 393.0], [14630.0, 393.0], [14649.0, 399.0], [14666.0, 399.0], [14676.0, 399.0], [14698.0, 399.0], [14726.0, 399.0], [14747.0, 401.0], [14773.0, 401.0], [14793.0, 401.0], [14815.0, 401.0], [14827.0, 401.0], [14847.0, 404.0], [14863.0, 404.0], [14875.0, 404.0], [14891.0, 404.0], [14917.0, 404.0], [14928.0, 404.0], [14939.0, 419.0], [14950.0, 419.0], [14961.0, 419.0], [14974.0, 419.0], [14991.0, 419.0], [15007.0, 419.0], [15023.0, 419.0], [15049.0, 441.0], [15066.0, 441.0], [15082.0, 441.0], [15099.0, 441.0], [15118.0, 441.0], [15135.0, 441.0], [15145.0, 441.0], [15167.0, 441.0], [15184.0, 441.0], [15200.0, 441.0], [15216.0, 441.0], [15243.0, 441.0], [15255.0, 450.0], [15271.0, 450.0], [15288.0, 450.0], [15297.0, 450.0], [15313.0, 450.0], [15324.0, 450.0], [15341.0, 450.0], [15357.0, 477.0], [15379.0, 477.0], [15401.0, 477.0], [15417.0, 477.0], [15434.0, 477.0], [15456.0, 477.0], [15472.0, 486.0], [15494.0, 486.0], [15519.0, 486.0], [15539.0, 486.0], [15561.0, 486.0], [15573.0, 487.0], [15593.0, 487.0], [15604.0, 487.0], [15621.0, 487.0], [15637.0, 487.0], [15659.0, 487.0], [15681.0, 500.0], [15697.0, 500.0], [15714.0, 500.0], [15736.0, 500.0], [15752.0, 500.0], [15768.0, 500.0], [15785.0, 532.0], [15797.0, 532.0], [15811.0, 532.0], [15827.0, 532.0], [15846.0, 532.0], [15863.0, 532.0], [15879.0, 532.0], [15896.0, 571.0], [15917.0, 571.0], [15934.0, 571.0], [15948.0, 571.0], [15968.0, 571.0], [15985.0, 571.0], [16007.0, 570.0], [16029.0, 570.0], [16045.0, 570.0], [16063.0, 570.0], [16074.0, 570.0], [16096.0, 570.0], [16113.0, 592.0], [16140.0, 592.0], [16166.0, 592.0], [16183.0, 592.0], [16205.0, 592.0], [16227.0, 632.0], [16244.0, 632.0], [16256.0, 632.0], [16266.0, 632.0], [16288.0, 632.0], [16314.0, 632.0], [16331.0, 678.0], [16341.0, 678.0], [16358.0, 678.0], [16380.0, 678.0], [16402.0, 678.0], [16424.0, 683.0], [16441.0, 683.0], [16467.0, 683.0], [16484.0, 683.0], [16506.0, 683.0], [16528.0, 683.0], [16544.0, 735.0], [16566.0, 735.0], [16583.0, 735.0], [16599.0, 735.0], [16614.0, 735.0], [16631.0, 735.0], [16648.0, 813.0], [16670.0, 813.0], [16693.0, 813.0], [16703.0, 813.0], [16725.0, 813.0], [16747.0, 858.0], [16758.0, 858.0], [16774.0, 858.0], [16802.0, 858.0], [16824.0, 858.0], [16835.0, 868.0], [16852.0, 868.0], [16863.0, 868.0], [16879.0, 868.0], [16895.0, 868.0], [16908.0, 868.0], [16927.0, 868.0], [16948.0, 927.0], [16973.0, 927.0], [16984.0, 927.0], [16995.0, 927.0], [17017.0, 927.0], [17034.0, 927.0], [17055.0, 1018.0], [17073.0, 1018.0], [17085.0, 1018.0], [17095.0, 1018.0], [17117.0, 1018.0], [17134.0, 1018.0], [17154.0, 1176.0], [17176.0, 1176.0], [17193.0, 1176.0], [17204.0, 1176.0], [17215.0, 1176.0], [17236.0, 1176.0], [17253.0, 1208.0], [17275.0, 1208.0], [17292.0, 1208.0], [17312.0, 1208.0], [17334.0, 1208.0], [17351.0, 1593.0], [17364.0, 1593.0], [17381.0, 1593.0], [17400.0, 1593.0], [17411.0, 1593.0], [17428.0, 1593.0], [17444.0, 2192.0], [17461.0, 2192.0], [17472.0, 2192.0], [17491.0, 2192.0], [17501.0, 2192.0], [17518.0, 2192.0], [17534.0, 2192.0], [17551.0, 2192.0], [17562.0, 2192.0], [17585.0, 2192.0], [17601.0, 2192.0], [17618.0, 2192.0], [17638.0, 2192.0], [17654.0, 2192.0], [17671.0, 2192.0], [17693.0, 2192.0], [17717.0, 2192.0], [17737.0, 2192.0], [17754.0, 2192.0], [17762.0, 2192.0], [17789.0, 2192.0], [17811.0, 2192.0], [17833.0, 2192.0], [17849.0, 2192.0], [17871.0, 2192.0], [17889.0, 2192.0], [17910.0, 2192.0], [17926.0, 2192.0], [17943.0, 2192.0], [17960.0, 2192.0], [17971.0, 2192.0], [17987.0, 2192.0], [18009.0, 2192.0]]
x1 = 5
y1 = -3
start = 40
end = 1030
theta = 0.47*np.pi

data = np.array(sensor_data)
time = data[start:end, 0]
tof1 = data[start:end, 1]

data5_3 = robot2global(tof1, x1, y1, theta)

plt.figure()
plt.scatter(data5_3[0], data5_3[1], s=1, c='blue')  # s is size
plt.axis('equal')
plt.xlabel('x (m)')
plt.ylabel('y (m)')
plt.title(f'ToF Global Frame {x1}, {y1}')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.scatter(data5_3[0], data5_3[1], s=1, c='blue', label='[5, -3]')  # s is size
plt.scatter(data53[0], data53[1], s=1, c='red', label='[5, 3]')  # s is size
plt.scatter(data_3_2[0], data_3_2[1], s=1, c='purple', label='[-3, -2]')  # s is size
plt.scatter(data03[0], data03[1], s=1, c='green', label='[0, 3]')  # s is size
plt.scatter(data00[0], data00[1], s=1, c='orange', label='[0, 0]')  # s is size

# plt.plot(data5_3[0][:], data5_3[1][:], 'g', label='[5, -3]')  # s is size
# plt.plot(data53[0][:], data53[1][:], 'r', label='[5, 3]')  # s is size
# plt.plot(data_3_2[0][:], data_3_2[1][:], 'b', label='[-3, -2]')  # s is size
# plt.plot(data03[0][:], data03[1][:], 'c', label='[0, 3]')  # s is size
# plt.plot(data00[0][:], data00[1][:], 'k', label='[0, 0]')  # s is size

plt.axis('equal')
plt.xlabel('x (m)')
plt.ylabel('y (m)')
plt.title('ToF Scan Transformed to Global Frame')
plt.grid()
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
walls = np.array([[6.4, -4.2, 6.4, 4.3], 
                  [6.4, 4.3, -2.4, 4.3], 
                  [-2.4, 4.3, -2.4, 0.4], 
                  [-2.4, 0.4, -5.5, 0.4], 
                  [-5.5, 0.4, -5.5, -4.2], 
                  [-5.5, -4.2, -0.8, -4.2], 
                  [-0.8, -4.2, -0.8, -2.1], 
                  [-0.8, -2.1, 0.9, -2.1], 
                  [0.9, -2.1, 0.9, -4.2], 
                  [0.9, -4.2, 6.4, -4.2],
                  [2.3, 2.2, 2.3, -0.3], 
                  [2.3, -0.3, 4.8, -0.3], 
                  [4.8, -0.3, 4.8, 2.2], 
                  [4.8, 2.2, 2.3, 2.2],])

plt.figure()
plt.scatter(data5_3[0], data5_3[1], s=1, c='blue', label='[5, -3]')  # s is size
plt.scatter(data53[0], data53[1], s=1, c='red', label='[5, 3]')  # s is size
plt.scatter(data_3_2[0], data_3_2[1], s=1, c='purple', label='[-3, -2]')  # s is size
plt.scatter(data03[0], data03[1], s=1, c='green', label='[0, 3]')  # s is size
plt.scatter(data00[0], data00[1], s=1, c='orange', label='[0, 0]')  # s is size

for i in range(len(walls)):
    plt.plot([walls[i, 0], walls[i, 2]], [walls[i, 1], walls[i, 3]], 'k') 

plt.axis('equal')
plt.xlabel('x (m)')
plt.ylabel('y (m)')
plt.title('ToF Scan Transformed to Global Frame')
plt.grid()
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

walls = np.array([[6.4, -4.2, 6.4, 4.3], 
                  [6.4, 4.3, -2.4, 4.3], 
                  [-2.4, 4.3, -2.4, 0.4], 
                  [-2.4, 0.4, -5.5, 0.4], 
                  [-5.5, 0.4, -5.5, -4.2], 
                  [-5.5, -4.2, -0.8, -4.2], 
                  [-0.8, -4.2, -0.8, -2.1], 
                  [-0.8, -2.1, 0.9, -2.1], 
                  [0.9, -2.1, 0.9, -4.2], 
                  [0.9, -4.2, 6.4, -4.2],
                  [2.3, 2.2, 2.3, -0.3], 
                  [2.3, -0.3, 4.8, -0.3], 
                  [4.8, -0.3, 4.8, 2.2], 
                  [4.8, 2.2, 2.3, 2.2],])

plt.figure()
for i in range(len(walls)):
    plt.plot([walls[i, 0], walls[i, 2]], [walls[i, 1], walls[i, 3]], 'k', label='[0, 0]') 

plt.axis('equal')
plt.xlabel('x (m)')
plt.ylabel('y (m)')
plt.title('ToF Scan Transformed to Global Frame')
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
wall1 = np.array([[6.4, -4], [6.4, 4.3], [-2.4, 4.3], [-2.4, 0.4], [-5.5, 0.4], [-5.5, -4.2], [-0.8, -4.2], [-0.8, -2.1], [0.9, -2.1], [0.9, -4], [6.2, -4]])
wall2 = np.array([[2.3, 2.2], [2.3, -0.3], [4.8, -0.3], [4.8, 2.2], [2.3, 2.2]])

plt.figure()
plt.plot(data5_3[0][:], data5_3[1][:], 'g', label='[5, -3]')  # s is size
plt.plot(data53[0][:], data53[1][:], 'r', label='[5, 3]')  # s is size
plt.plot(data_3_2[0][:], data_3_2[1][:], 'b', label='[-3, -2]')  # s is size
plt.plot(data03[0][:], data03[1][:], 'c', label='[0, 3]')  # s is size
plt.plot(data00[0][:], data00[1][:], 'k', label='[0, 0]')  # s is size

plt.plot(wall1[:, 0], wall1[:, 1], 'k', label='[0, 0]')  
plt.plot(wall2[:, 0], wall2[:, 1], 'k', label='[0, 0]')  

plt.axis('equal')
plt.xlabel('x (m)')
plt.ylabel('y (m)')
plt.title('ToF Scan Transformed to Global Frame')
plt.grid()
plt.legend()
plt.show()
